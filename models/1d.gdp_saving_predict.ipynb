# %% [markdown]
# ### Linear Regression to predict GDP and saving rate for future 5 years

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

gdp = pd.read_csv('../data/curated/gdp_with_saving_rate.csv').iloc[:, 1:]
gdp.rename({'gdp(USD Millioins)': 'gdp_USD'}, axis=1, inplace=True)
gdp
# Out:
#     year  gdp_USD  saving_rate(% of GDP)
# 0   1970    36910              13.965180
# 1   1971    40379              13.867941
# 2   1972    44556              14.922438
# 3   1973    49831              15.803160
# 4   1974    60374              12.301303
# 5   1975    71277              10.800341
# 6   1976    83377               9.912091
# 7   1977    96236               7.450473
# 8   1978   105094               9.405753
# 9   1979   118789              10.342062
# 10  1980   134654              10.282790
# 11  1981   152410               8.796762
# 12  1982   175917               5.169911
# 13  1983   189481               7.637791
# 14  1984   213766               8.559389
# 15  1985   235414               6.457267
# 16  1986   260714               5.345850
# 17  1987   286222               7.962422
# 18  1988   324449               9.031767
# 19  1989   368145               7.687440
# 20  1990   404569               3.734530
# 21  1991   415233               0.993805
# 22  1992   423222               2.846125
# 23  1993   444218               4.346810
# 24  1994   466618               3.604576
# 25  1995   495509               4.336632
# 26  1996   528636               5.733141
# 27  1997   556257               5.296158
# 28  1998   588842               4.162345
# 29  1999   620924               4.841157
# 30  2000   661722               3.908633
# 31  2001   706385               5.170472
# 32  2002   755579               4.611407
# 33  2003   802510               5.413050
# 34  2004   863395               4.605181
# 35  2005   924589               5.285867
# 36  2006   998436               4.986287
# 37  2007  1087683               5.671076
# 38  2008  1178577               7.644383
# 39  2009  1260468               5.234108
# 40  2010  1302858               7.265403
# 41  2011  1417898               8.508645
# 42  2012  1499804               7.571069
# 43  2013  1536454               6.861393
# 44  2014  1598553               4.911388
# 45  2015  1623207               2.497491
# 46  2016  1657744               4.164464
# 47  2017  1759314               4.183031
# 48  2018  1842946               5.238132
# 49  2019  1946228               6.425977
# 50  2020  1980866               8.466190

# %%
gdp['log_year'] = np.log(gdp['year'])
gdp['log_gdp'] = np.log(gdp['gdp_USD'])
gdp['log_saving'] = np.log(gdp['saving_rate(% of GDP)'])

# %%
sns.pairplot(gdp)

# %% [markdown]
# ### LR Model1: Log Year vs Log GDP (use log Year to predict log GDP)

# %%
x = sm.add_constant(gdp['log_year'])
results = sm.OLS(gdp['log_gdp'], x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                log_gdp   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     1365.
# Date:                Fri, 23 Sep 2022   Prob (F-statistic):           1.94e-37
# Time:                        14:59:47   Log-Likelihood:                 5.8675
# No. Observations:                  51   AIC:                            -7.735
# Df Residuals:                      49   BIC:                            -3.871
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1159.2104     31.729    -36.535      0.000   -1222.971   -1095.449
# log_year     154.2625      4.176     36.943      0.000     145.871     162.654
# ==============================================================================
# Omnibus:                        3.310   Durbin-Watson:                   0.034
# Prob(Omnibus):                  0.191   Jarque-Bera (JB):                3.171
# Skew:                          -0.569   Prob(JB):                        0.205
# Kurtosis:                       2.555   Cond. No.                     7.96e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.96e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
intercept = results.params[0]
coef = results.params[1]

predictions = intercept + coef * gdp['log_year']
#predictions = np.exp(predictions)
predictions
plt.scatter(gdp['log_year'], gdp['log_gdp'])
fig = plt.plot(gdp['log_year'], predictions, lw=4, c='orange')
plt.xlabel('Log Year')
plt.ylabel('Log GDP')
# Out:
# Text(0, 0.5, 'Log GDP')

# %%
YEARS = [2021, 2022, 2023, 2024, 2025, 2026, 2027]

future_years = list(gdp['year']) + [x for x in YEARS]

future_log_years = list(gdp['log_year']) + [np.log(x) for x in YEARS]
print(f"Future Log Years list, length = {len(future_log_years)}")
print(future_log_years)

future_log_gdp = list(gdp['log_gdp']) + [(intercept+coef*np.log(x)) for x in YEARS]
print(f"Future Log GDP list, length = {len(future_log_gdp)}")
print(future_log_gdp)
# Out:
# Future Log Years list, length = 58
# [7.585788821732034, 7.58629630715272, 7.586803535162581, 7.587310506022615, 7.587817219993427, 7.5883236773352225, 7.588829878307813, 7.589335823170617, 7.589841512182657, 7.590346945602565, 7.590852123688581, 7.591357046698551, 7.591861714889934, 7.592366128519796, 7.592870287844818, 7.59337419312129, 7.593877844605118, 7.594381242551817, 7.59488438721652, 7.5953872788539725, 7.595889917718538, 7.596392304064196, 7.596894438144544, 7.597396320212795, 7.597897950521784, 7.598399329323964, 7.59890045687141, 7.599401333415815, 7.599901959208498, 7.6004023345004, 7.600902459542082, 7.601402334583733, 7.601901959875166, 7.602401335665818, 7.602900462204755, 7.60339933974067, 7.603897968521881, 7.604396348796338, 7.60489448081162, 7.605392364814935, 7.605890001053122, 7.606387389772652, 7.60688453121963, 7.607381425639791, 7.607878073278507, 7.608374474380783, 7.60887062919126, 7.6093665379542115, 7.609862200913554, 7.610357618312838, 7.61085279039525, 7.611347717403621, 7.611842399580417, 7.612336837167746, 7.6128310304073565, 7.613324979540639, 7.613818684808629, 7.614312146452]
# Future Log GDP list, length = 58
# [10.516237796024043, 10.60606512682516, 10.70450210396508, 10.816392559306074, 11.008313827670705, 11.174328973716898, 11.331127770936215, 11.474558787025037, 11.562610466748279, 11.68510408903113, 11.810463804445373, 11.934329536879895, 12.077767571877233, 12.15204403462562, 12.27263723779877, 12.369100945276895, 12.471179300052404, 12.564523012472344, 12.68988363790556, 12.816232161284018, 12.910577581897558, 12.936595087444253, 12.955652143052186, 13.004070711908716, 13.053266214764959, 13.113340796058466, 13.178055383260112, 13.22898569665307, 13.28591317537457, 13.338963970173356, 13.40260080714279, 13.467915693618348, 13.535239621740478, 13.59549959496786, 13.668627571028141, 13.737104593428935, 13.813945333639545, 13.89956030365025, 13.979818336517104, 14.046993638536573, 14.08007087088972, 14.164686051187946, 14.22084499086814, 14.244987721933352, 14.28460940301621, 14.29991437995364, 14.32096819986097, 14.380434518305927, 14.426875936168447, 14.481403698277118, 14.499044680788078, 14.934864436715088, 15.011175327586443, 15.08744848748438, 15.163683953701366, 15.239881763475069, 15.316041953988133, 15.392164562367498]

# %% [markdown]
# ### LR Model2: Log GDP vs Log Saving (Trial only)

# %%
x = sm.add_constant(gdp['log_gdp'])
results = sm.OLS(gdp['log_saving'], x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             log_saving   R-squared:                       0.329
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     24.00
# Date:                Fri, 23 Sep 2022   Prob (F-statistic):           1.09e-05
# Time:                        14:59:47   Log-Likelihood:                -26.053
# No. Observations:                  51   AIC:                             56.11
# Df Residuals:                      49   BIC:                             59.97
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.9787      0.646      7.710      0.000       3.681       6.276
# log_gdp       -0.2436      0.050     -4.899      0.000      -0.344      -0.144
# ==============================================================================
# Omnibus:                       35.492   Durbin-Watson:                   0.770
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              114.335
# Skew:                          -1.824   Prob(JB):                     1.49e-25
# Kurtosis:                       9.364   Cond. No.                         146.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
intercept = results.params[0]
coef = results.params[1]

predictions = intercept + coef * gdp['log_gdp']
#predictions = np.exp(predictions)
predictions
plt.scatter(gdp['log_gdp'], gdp['log_saving'])
fig = plt.plot(gdp['log_gdp'], predictions, lw=4, c='orange')
plt.xlabel('Log GDP')
plt.ylabel('Log Saving')
# Out:
# Text(0, 0.5, 'Log Saving')

# %%
future_log_saving = list(gdp['log_saving']) + [intercept+coef*x for x in future_log_gdp[-7:]]
print(f"Future Log Saving list, length = {len(future_log_saving)}")
print(future_log_saving)
# Out:
# Future Log Saving list, length = 58
# [2.636567082970115, 2.6295798070839878, 2.702865975523354, 2.7602099390692296, 2.5097052214589897, 2.3795776726619313, 2.293755336108262, 2.008277508224663, 2.2413215295042996, 2.3362192570452143, 2.3304716087325685, 2.174383711663656, 1.6428555694345304, 2.0331084063154856, 2.1470288080860267, 1.8652062175308617, 1.6763206382375593, 2.0747332808744923, 2.2007480707880736, 2.0395878560817553, 1.3176219124079882, -0.006214600801449525, 1.045958455391274, 1.4694423469819209, 1.2822042338341069, 1.4670980998526435, 1.7462636066398916, 1.6669815657583522, 1.4260786534448757, 1.5771537129184252, 1.363187797293944, 1.6429639640913603, 1.5285329539417651, 1.6888126395874725, 1.5271820455265233, 1.6650366732512532, 1.606691617812158, 1.7353789095303644, 2.0339711140835393, 1.6551965143659637, 1.983123729753766, 2.1410827207010175, 2.0243343373349787, 1.9259104491316026, 1.5915566678538142, 0.9152864539524234, 1.4265876007432408, 1.4310360710399015, 1.6559650280247875, 1.860348732064492, 2.1360806193080903, 1.3400402724205978, 1.3214482233516538, 1.3028653668907522, 1.284291693952122, 1.2657271954633416, 1.247171862365395, 1.2286256856128386]

# %% [markdown]
# ### Quadratic Regression Model3: Year vs Saving (use Year to predict Saving Rate)

# %%
def quadratic(x0, x1, beta1, beta2):
    return x0+beta1*(x1**2)-beta2*x1

def climax(a):
    b = 2*a*1996
    c = (13.5*a+b**2)/(4*a)
    #print(f"a = {a}, b = {b}, c = {c}")
    return [b, c]

# %%
predictions = quadratic(climax(0.014)[1], gdp['year'], 0.014, climax(0.014)[0])
#predictions = np.exp(predictions)
#print(predictions)
plt.scatter(gdp['year'], gdp['saving_rate(% of GDP)'])
fig = plt.plot(gdp['year'], predictions, lw=4, c='orange')
plt.xlabel('Year')
plt.ylabel('Saving')
# Out:
# Text(0, 0.5, 'Saving')

# %%
errors = np.array(predictions - gdp['saving_rate(% of GDP)'])
squared_errors = errors**2
mean_squared_error = squared_errors.mean()

print(f'MSE: {mean_squared_error}')

tot_sum_squares = (np.array(gdp['saving_rate(% of GDP)'] - gdp['saving_rate(% of GDP)'].mean())**2).sum()
r2 = 1 - (squared_errors.sum() / tot_sum_squares)
print(f'Model R^2: {r2:.4f}')
# Out:
# MSE: 6.419891025673194
# Model R^2: 0.3795

# %%
future_saving = list(gdp['saving_rate(% of GDP)']) + [quadratic(climax(0.014)[1], x, 0.014, climax(0.014)[0]) for x in YEARS]
print(f"Future Saving list, length = {len(future_saving)}")
print(future_saving)
# Out:
# Future Saving list, length = 58
# [13.9651799202556, 13.867941466918, 14.9224378398989, 15.8031603007917, 12.3013033657421, 10.8003406215143, 9.91209110935617, 7.45047290996632, 9.40575305794308, 10.3420618771073, 10.2827898431861, 8.79676210940387, 5.16991149508394, 7.63779085542135, 8.55938899130893, 6.45726735042997, 5.34585042379691, 7.96242244543827, 9.03176737426829, 7.68744021415383, 3.73452977003273, 0.993804669889562, 2.84612510073883, 4.34681045309011, 3.60457630436581, 4.33663238977292, 5.73314133574948, 5.29615754311004, 4.1623451501311, 4.84115686043384, 3.90863339397071, 5.17047191623907, 4.61140671144285, 5.41304964703293, 4.60518132921763, 5.28586709613836, 4.98628736497674, 5.67107622157907, 7.64438288000965, 5.2341083986129, 7.2654027299566, 8.50864512963027, 7.57106948857564, 6.86139277208826, 4.91138838114917, 2.49749056549142, 4.16446410362221, 4.18303086471334, 5.2381324284719, 6.42597732506893, 8.46619029419306, 12.124999999985448, 12.839000000007218, 13.581000000005588, 14.351000000009662, 15.148999999990338, 15.974999999991269, 16.828999999997905]

# %%
import os
if not os.path.exists('../data/curated/feature_prediction'):
    os.makedirs('../data/curated/feature_prediction')

future_gdp_dict = {"year": future_years, "gdp": np.exp(future_log_gdp).astype('int64'), "saving": future_saving}
future_gdp = pd.DataFrame(future_gdp_dict)
future_gdp.to_csv('../data/curated/feature_prediction/21_27_gdp_with_saving_predicted.csv',index=False)

# %% [markdown]
# ## Export Model for Web (Flask)

# %%
import pickle
pickle.dump(predictions, open('../web/gdp_model.pkl','wb'))
model = pickle.load(open('../web/gdp_model.pkl','rb'))
