# %%
"""
A very simple and basic web scraping script. Feel free to
use this as a source of inspiration, but, make sure to attribute
it if you do so.

This is by no means production code.
"""
# built-in imports
import re
from json import dump

from collections import defaultdict

# user packages
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests

# %%
# constants
BASE_URL = "https://www.domain.com.au"
N_PAGES = range(1, 6) # update this to your liking

# begin code
url_links = []
property_metadata = defaultdict(dict)

# generate list of urls to visit
for page in N_PAGES:
    headers = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}
    url = BASE_URL + f"/rent/melbourne-region-vic/?sort=price-desc&page={page}"
    bs_object = BeautifulSoup(requests.get(url, headers=headers).text, "html.parser")

    # find the unordered list (ul) elements which are the results, then
    # find all href (a) tags that are from the base_url website.
    index_links = bs_object \
        .find(
            "ul",
            {"data-testid": "results"}
        ) \
        .findAll(
            "a",
            href=re.compile(f"{BASE_URL}/*") # the `*` denotes wildcard any
        )

    for link in index_links:
        # if its a property address, add it to the list
        if 'address' in link['class']:
            url_links.append(link['href'])

# %%
url_links
# Out:
# ['https://www.domain.com.au/667-glenhuntly-road-caulfield-vic-3162-11598047',
#  'https://www.domain.com.au/upstairs-2c-staley-street-brunswick-vic-3056-13168913',
#  'https://www.domain.com.au/level-3-302-13-15-lake-street-caroline-springs-vic-3023-15994395',
#  'https://www.domain.com.au/3502-14-16-the-esplanade-st-kilda-vic-3182-16002767',
#  'https://www.domain.com.au/9-lansdowne-street-blairgowrie-vic-3942-12127675',
#  'https://www.domain.com.au/52-black-st-brighton-vic-3186-15410646',
#  'https://www.domain.com.au/4203-35-spring-street-melbourne-vic-3000-15939303',
#  'https://www.domain.com.au/335-the-esplanade-indented-head-vic-3223-12688424',
#  'https://www.domain.com.au/50-south-wharf-drive-docklands-vic-3008-16048359',
#  'https://www.domain.com.au/901-902-85-market-street-south-melbourne-vic-3205-14089455',
#  'https://www.domain.com.au/9-keith-court-brighton-vic-3186-16058214',
#  'https://www.domain.com.au/7-haverbrack-avenue-malvern-vic-3144-16041473',
#  'https://www.domain.com.au/27-moffat-street-brighton-vic-3186-16024852',
#  'https://www.domain.com.au/brighton-vic-3186-14427083',
#  'https://www.domain.com.au/7302-462-elizabeth-street-melbourne-vic-3000-15631154',
#  'https://www.domain.com.au/2b-mulgoa-street-brighton-vic-3186-16031980',
#  'https://www.domain.com.au/5-wellington-street-brighton-vic-3186-15950472',
#  'https://www.domain.com.au/1-bronte-court-hampton-vic-3188-16043802',
#  'https://www.domain.com.au/3607-80-a-beckett-street-melbourne-vic-3000-11696896',
#  'https://www.domain.com.au/2202-14-16-the-esplanade-st-kilda-vic-3182-15969170',
#  'https://www.domain.com.au/brighton-vic-3186-9287841',
#  'https://www.domain.com.au/251-350-st-kilda-road-melbourne-vic-3000-15951316',
#  'https://www.domain.com.au/2601-14-16-the-esplanade-st-kilda-vic-3182-16047323',
#  'https://www.domain.com.au/42-dendy-street-brighton-vic-3186-15988734',
#  'https://www.domain.com.au/119-121-palmerston-street-carlton-vic-3053-13973576',
#  'https://www.domain.com.au/231-299-queen-street-melbourne-vic-3000-15986804',
#  'https://www.domain.com.au/15-webster-street-malvern-east-vic-3145-13350636',
#  'https://www.domain.com.au/46-48-wells-road-beaumaris-vic-3193-16001198',
#  'https://www.domain.com.au/blairgowrie-vic-3942-15804425',
#  'https://www.domain.com.au/133-north-road-brighton-vic-3186-16017654',
#  'https://www.domain.com.au/3-knight-street-elwood-vic-3184-16014388',
#  'https://www.domain.com.au/3-stonecutters-road-portsea-vic-3944-15839853',
#  'https://www.domain.com.au/richmond-vic-3121-13533466',
#  'https://www.domain.com.au/62-william-street-st-albans-vic-3021-15862727',
#  'https://www.domain.com.au/3203-14-16-the-esplanade-st-kilda-vic-3182-15986065',
#  'https://www.domain.com.au/46-leviens-road-st-leonards-vic-3223-11326066',
#  'https://www.domain.com.au/21-mathoura-road-toorak-vic-3142-15987977',
#  'https://www.domain.com.au/21-iona-avenue-toorak-vic-3142-15808965',
#  'https://www.domain.com.au/12-clendon-court-toorak-vic-3142-14238687',
#  'https://www.domain.com.au/4a-fetherston-street-armadale-vic-3143-15975645',
#  'https://www.domain.com.au/27-grandview-road-brighton-vic-3186-15993971',
#  'https://www.domain.com.au/1-2-shandford-avenue-brighton-vic-3186-15995849',
#  'https://www.domain.com.au/241-299-queen-street-melbourne-vic-3000-15998618',
#  'https://www.domain.com.au/142-nelson-road-south-melbourne-vic-3205-16006557',
#  'https://www.domain.com.au/23-bay-street-brighton-vic-3186-15865642',
#  'https://www.domain.com.au/unit-2707-35-spring-street-melbourne-vic-3000-16044913',
#  'https://www.domain.com.au/478-new-street-brighton-vic-3186-15992205',
#  'https://www.domain.com.au/2105-368-st-kilda-road-melbourne-vic-3004-15990663',
#  'https://www.domain.com.au/12-the-heights-sorrento-vic-3943-15951991',
#  'https://www.domain.com.au/4-cowper-street-sandringham-vic-3191-16043512',
#  'https://www.domain.com.au/4-cowper-street-sandringham-vic-3191-16043282',
#  'https://www.domain.com.au/8-champion-street-brighton-vic-3186-16048073',
#  'https://www.domain.com.au/2a-omar-street-caulfield-south-vic-3162-16036419',
#  'https://www.domain.com.au/22-campbell-street-frankston-vic-3199-15959231',
#  'https://www.domain.com.au/802-181-fitzroy-st-st-kilda-vic-3182-15915050',
#  'https://www.domain.com.au/19-iona-street-black-rock-vic-3193-16018912',
#  'https://www.domain.com.au/4-19-birdwood-avenue-brighton-vic-3186-15875170',
#  'https://www.domain.com.au/2-winmarleigh-close-brighton-vic-3186-15954363',
#  'https://www.domain.com.au/8-st-finbars-crescent-brighton-east-vic-3187-15969436',
#  'https://www.domain.com.au/8-st-finbars-crescent-brighton-east-vic-3187-16046548',
#  'https://www.domain.com.au/25-26-little-cardigan-street-carlton-vic-3053-15895702',
#  'https://www.domain.com.au/163-victoria-parade-fitzroy-vic-3065-15870974',
#  'https://www.domain.com.au/3803-483-swanston-street-melbourne-vic-3000-15680157',
#  'https://www.domain.com.au/12-786-esplanade-mornington-vic-3931-14113631',
#  'https://www.domain.com.au/8-canadian-bay-road-mount-eliza-vic-3930-15933451',
#  'https://www.domain.com.au/rye-vic-3941-15680121',
#  'https://www.domain.com.au/85-market-street-south-melbourne-vic-3205-14089206',
#  'https://www.domain.com.au/1002-243-toorak-road-south-yarra-vic-3141-16056057',
#  'https://www.domain.com.au/23a-bruce-street-toorak-vic-3142-16012345',
#  'https://www.domain.com.au/5-brently-close-narre-warren-north-vic-3804-15484129',
#  'https://www.domain.com.au/73-gardenvale-road-gardenvale-vic-3185-15971850',
#  'https://www.domain.com.au/52-sargood-street-hampton-vic-3188-16053158',
#  'https://www.domain.com.au/2301-1-almeida-crescent-south-yarra-vic-3141-14425729',
#  'https://www.domain.com.au/1203-57-city-road-southbank-vic-3006-15631603',
#  'https://www.domain.com.au/4-9-trawalla-avenue-toorak-vic-3142-16019262',
#  'https://www.domain.com.au/7-wagstaff-court-brighton-vic-3186-15967461',
#  'https://www.domain.com.au/51-were-street-brighton-vic-3186-16051892',
#  'https://www.domain.com.au/2-10-asling-street-brighton-vic-3186-16043580',
#  'https://www.domain.com.au/120-glen-huntly-road-elwood-vic-3184-16058926',
#  'https://www.domain.com.au/21-belair-avenue-glenroy-vic-3046-15904917',
#  'https://www.domain.com.au/22-ethel-street-malvern-vic-3144-16026921',
#  'https://www.domain.com.au/70-queens-road-pearcedale-vic-3912-16004210',
#  'https://www.domain.com.au/9-exon-street-brighton-vic-3186-16020106',
#  'https://www.domain.com.au/11-hansens-lane-balnarring-beach-vic-3926-16017546',
#  'https://www.domain.com.au/140-dendy-street-brighton-east-vic-3187-16006734',
#  'https://www.domain.com.au/21-spring-street-fitzroy-vic-3065-15091824',
#  'https://www.domain.com.au/5-alimar-court-brighton-vic-3186-15910332',
#  'https://www.domain.com.au/19-moule-avenue-brighton-vic-3186-15981059',
#  'https://www.domain.com.au/1302-1-powlett-street-east-melbourne-vic-3002-15984037',
#  'https://www.domain.com.au/7-126-wellington-parade-east-melbourne-vic-3002-16061003',
#  'https://www.domain.com.au/1901-368-st-kilda-road-melbourne-vic-3004-15987815',
#  'https://www.domain.com.au/1501-601-st-kilda-road-melbourne-vic-3004-14868412',
#  'https://www.domain.com.au/904-201-collins-street-melbourne-vic-3000-16037951',
#  'https://www.domain.com.au/112-harold-st-middle-park-vic-3206-16049514',
#  'https://www.domain.com.au/24-dreadnought-street-sandringham-vic-3191-16037409',
#  'https://www.domain.com.au/417-250-st-kilda-road-southbank-vic-3006-16052549',
#  'https://www.domain.com.au/1-125-high-st-prahran-vic-3181-15340091',
#  'https://www.domain.com.au/102-carpenter-street-brighton-vic-3186-15934953',
#  'https://www.domain.com.au/1307-14-queens-road-melbourne-vic-3004-15596752',
#  'https://www.domain.com.au/301-130-bay-street-port-melbourne-vic-3207-16014905']

# %%
# from htmldate import find_date
# for each url, scrape some basic metadata
for property_url in url_links[1:]:
    bs_object = BeautifulSoup(requests.get(property_url, headers=headers).text, "html.parser")

    # get the date this property was published
    # property_metadata[property_url]['date'] = find_date(property_url)

    # looks for the header class to get property name
    property_metadata[property_url]['name'] = bs_object \
        .find("h1", {"class": "css-164r41r"}) \
        .text

    # looks for the div containing a summary title for cost
    property_metadata[property_url]['cost_text'] = bs_object \
        .find("div", {"data-testid": "listing-details__summary-title"}) \
        .text

    # extract coordinates from the hyperlink provided
    # i'll let you figure out what this does :P
    property_metadata[property_url]['coordinates'] = [
        float(coord) for coord in re.findall(
            r'destination=([-\s,\d\.]+)', # use regex101.com here if you need to
            bs_object \
                .find(
                    "a",
                    {"target": "_blank", 'rel': "noopener noreferer"}
                ) \
                .attrs['href']
        )[0].split(',')
    ]

    #property_metadata[property_url]['rooms'] = [
    #    re.findall(r'\d\s[A-Za-z]+', feature.text)[0] for feature in bs_object \
    #        .find("div", {"data-testid": "property-features"}) \
    #        .findAll("span", {"data-testid": "property-features-text-container"})
    #]

    property_metadata[property_url]['desc'] = re \
        .sub(r'<br\/>', '\n', str(bs_object.find("p"))) \
        .strip('</p>')

# output to example json in data/raw/
with open('../data/raw/example.json', 'w') as f:
    dump(property_metadata, f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape.ipynb Cell 5 in <cell line: 3>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> bs_object = BeautifulSoup(requests.get(property_url, headers=headers).text, "html.parser")
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # get the date this property was published
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> property_metadata[property_url]['date'] = find_date(property_url)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> # looks for the header class to get property name
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> property_metadata[property_url]['name'] = bs_object \
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     .find("h1", {"class": "css-164r41r"}) \
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     .text
#
# File ~/.local/lib/python3.8/site-packages/htmldate/core.py:921, in find_date(htmlobject, extensive_search, original_date, outputformat, url, verbose, min_date, max_date)
#     919 if verbose:
#     920     logging.basicConfig(level=logging.DEBUG)
# --> 921 tree = load_html(htmlobject)
#     922 # unclear what this line is for and it impedes type checking:
#     923 # find_date.extensive_search = extensive_search
#     924 min_date, max_date = get_min_date(min_date), get_max_date(max_date)
#
# File ~/.local/lib/python3.8/site-packages/htmldate/utils.py:177, in load_html(htmlobject)
#     175     # log the error and quit
#     176     if htmltext is None:
# --> 177         raise ValueError("URL couldn't be processed: %s", htmlobject)
#     178 # start processing
#     179 tree = None
#
# ValueError: ("URL couldn't be processed: %s", 'https://www.domain.com.au/upstairs-2c-staley-street-brunswick-vic-3056-13168913')

# %% [markdown]
# ### Convert json to csv style

# %%
import json
import csv
example_json = open('../data/raw/example.json')
data = json.load(example_json)
#for item in data:
#    print(item)
# print(data)
headers = ['name', 'cost_text', 'coordinates', 'rooms', 'desc']
output_csv = open('../data/raw/property.csv', 'w')
# create the csv writer object
csv_writer = csv.writer(output_csv)
# first write the headers
csv_writer.writerow(headers)

for link in data:
    csv_writer.writerow(data[link].values())

output_csv.close()
example_json.close()
# Out:
# {'https://www.domain.com.au/upstairs-2c-staley-street-brunswick-vic-3056-13168913': {'name': 'Upstairs 2C Staley Street Brunswick VIC 3056', 'cost_text': '$35,000 Annually', 'coordinates': [-37.7655919, 144.9633048], 'desc': '1st floor offices/studios\nEasy walking distance to Sydney Road and public transport\nIdeal offices, dance studio, fitness studio, art studio\nIncludes tearoom, toilets, 2 undercover car-spaces\nApprox 337sqm'}, 'https://www.domain.com.au/level-3-302-13-15-lake-street-caroline-springs-vic-3023-15994395': {'name': 'Level 3, 302/13-15 Lake Street Caroline Springs VIC 3023', 'cost_text': '4125000 pw', 'coordinates': [-37.7316459, 144.7446886], 'desc': '- Centrally located with tranquil views.\n- Lettable area from 110m2 approximately \n- partitioned throughout\n- Ample staff and client parking\n- Excellent main road exposure\n- Fully air-conditioned throughout (heating and cooling)\n- Major growth corridor location with enormous catchment\n- Rare opportunity to lease in a desirable location.\n- Centrally positioned abutting Caroline Springs Square and'}, 'https://www.domain.com.au/3502-14-16-the-esplanade-st-kilda-vic-3182-16002767': {'name': '3502/14-16 The Esplanade St Kilda VIC 3182', 'cost_text': '$6,000', 'coordinates': [-37.8650177, 144.9746821], 'desc': 'Inspired by the interplay of timeless design and beach ambiance, Melbourne joins the ranks of Miami, Santa Monica, Saint-Tropez and Cannes with Saint Moritz Beachfront Residences. \nThe brand-new development by GURNER reaches a level of architectural detail, amenity and service level that is the first of its kind on the global stage.'}, 'https://www.domain.com.au/9-lansdowne-street-blairgowrie-vic-3942-12127675': {'name': '9 Lansdowne Street Blairgowrie VIC 3942', 'cost_text': '$5,000 per week', 'coordinates': [-38.372703, 144.7856897], 'desc': 'Phone enquiry code for this property : 2751'}, 'https://www.domain.com.au/52-black-st-brighton-vic-3186-15410646': {'name': '52 Black St Brighton VIC 3186', 'cost_text': 'From $5500 per week', 'coordinates': [-37.9159452, 144.9989003], 'desc': ' class="css-dxogle">* Unverified feature<svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 18 18"><circle cx="9.5" cy="9.5" fill="none" r="6.5" stroke="currentColor" stroke-width="2"></circle><path d="M9.5 11.5v-3" fill="none" stroke="currentColor"></path><circle cx="9.5" cy="6.5" fill="currentColor" r=".5"></circle></svg'}, 'https://www.domain.com.au/4203-35-spring-street-melbourne-vic-3000-15939303': {'name': '4203/35 Spring Street Melbourne VIC 3000', 'cost_text': '$4500 Per Week', 'coordinates': [-37.8141725, 144.9740049], 'desc': "Possibly the most prestigious CBD address in the heart of the world's most liveable city, this unrivalled penthouse apartment is a residence of exceptional calibre and features unsurpassed views of the iconic Fitzroy Gardens, sporting precincts, river, ocean and beyond. Luxuriously appointed, the accommodation consists of an entry foyer capturing panoramic landmark aspects of the city, a spacious"}, 'https://www.domain.com.au/335-the-esplanade-indented-head-vic-3223-12688424': {'name': '335 The Esplanade Indented Head VIC 3223', 'cost_text': '$3,775 wk $545 pn', 'coordinates': [-38.1439923, 144.7147899], 'desc': 'This stylish 4 bedroom home will surely make your holiday one to remember.'}, 'https://www.domain.com.au/50-south-wharf-drive-docklands-vic-3008-16048359': {'name': '50 South Wharf Drive Docklands VIC 3008', 'cost_text': '$3750 per week', 'coordinates': [-37.8223967, 144.938237], 'desc': "This spectacular five bedroom freehold waterfront residence can only be described as 'exceptional'. Designed over several levels to maximise the water views and its immediate wow factor, this impressive showpiece provides an imposing entry, a first class Miele kitchen with coffee machine, steamer oven, induction cooking, wine fridge &amp; integrated fridge/freezer with Italian Carrera marble benchtops"}, 'https://www.domain.com. ...
