# %% [markdown]
# ### Web Scraping from domain.com.au

# %%
"""
A very simple and basic web scraping script. Feel free to
use this as a source of inspiration, but, make sure to attribute
it if you do so.

This is by no means production code.
"""
# built-in imports
import re
from json import dump

from collections import defaultdict

# user packages
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests

# %%
# constants
BASE_URL = "https://www.domain.com.au"
N_PAGES = range(1, 11) # update this to your liking

# begin code
url_links = []
property_metadata = defaultdict(dict)

# generate list of urls to visit
for page in N_PAGES:
    headers = {"User-Agent": "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"}
    url = BASE_URL + f"/rent/melbourne-region-vic/?sort=price-desc&page={page}"
    bs_object = BeautifulSoup(requests.get(url, headers=headers).text, "html.parser")

    # find the unordered list (ul) elements which are the results, then
    # find all href (a) tags that are from the base_url website.
    index_links = bs_object \
        .find(
            "ul",
            {"data-testid": "results"}
        ) \
        .findAll(
            "a",
            href=re.compile(f"{BASE_URL}/*") # the `*` denotes wildcard any
        )

    for link in index_links:
        # if its a property address, add it to the list
        if 'address' in link['class']:
            url_links.append(link['href'])

# %%
url_links
# Out:
# ['https://www.domain.com.au/667-glenhuntly-road-caulfield-vic-3162-11598047',
#  'https://www.domain.com.au/upstairs-2c-staley-street-brunswick-vic-3056-13168913',
#  'https://www.domain.com.au/level-3-302-13-15-lake-street-caroline-springs-vic-3023-15994395',
#  'https://www.domain.com.au/3502-14-16-the-esplanade-st-kilda-vic-3182-16002767',
#  'https://www.domain.com.au/9-lansdowne-street-blairgowrie-vic-3942-12127675',
#  'https://www.domain.com.au/52-black-st-brighton-vic-3186-15410646',
#  'https://www.domain.com.au/4203-35-spring-street-melbourne-vic-3000-15939303',
#  'https://www.domain.com.au/335-the-esplanade-indented-head-vic-3223-12688424',
#  'https://www.domain.com.au/50-south-wharf-drive-docklands-vic-3008-16048359',
#  'https://www.domain.com.au/901-902-85-market-street-south-melbourne-vic-3205-14089455',
#  'https://www.domain.com.au/9-keith-court-brighton-vic-3186-16058214',
#  'https://www.domain.com.au/7-haverbrack-avenue-malvern-vic-3144-16041473',
#  'https://www.domain.com.au/27-moffat-street-brighton-vic-3186-16024852',
#  'https://www.domain.com.au/brighton-vic-3186-14427083',
#  'https://www.domain.com.au/7302-462-elizabeth-street-melbourne-vic-3000-15631154',
#  'https://www.domain.com.au/2b-mulgoa-street-brighton-vic-3186-16031980',
#  'https://www.domain.com.au/5-wellington-street-brighton-vic-3186-15950472',
#  'https://www.domain.com.au/1-bronte-court-hampton-vic-3188-16043802',
#  'https://www.domain.com.au/3607-80-a-beckett-street-melbourne-vic-3000-11696896',
#  'https://www.domain.com.au/2202-14-16-the-esplanade-st-kilda-vic-3182-15969170',
#  'https://www.domain.com.au/brighton-vic-3186-9287841',
#  'https://www.domain.com.au/251-350-st-kilda-road-melbourne-vic-3000-15951316',
#  'https://www.domain.com.au/2601-14-16-the-esplanade-st-kilda-vic-3182-16047323',
#  'https://www.domain.com.au/42-dendy-street-brighton-vic-3186-15988734',
#  'https://www.domain.com.au/119-121-palmerston-street-carlton-vic-3053-13973576',
#  'https://www.domain.com.au/brighton-vic-3186-15937027',
#  'https://www.domain.com.au/brighton-vic-3186-9660178',
#  'https://www.domain.com.au/brighton-vic-3186-10609315',
#  'https://www.domain.com.au/brighton-vic-3186-9287838',
#  'https://www.domain.com.au/brighton-vic-3186-10694414',
#  'https://www.domain.com.au/6b-centre-road-brighton-east-vic-3187-15971915',
#  'https://www.domain.com.au/29-canberra-grove-brighton-east-vic-3187-15994857',
#  'https://www.domain.com.au/19b-grant-street-brighton-east-vic-3187-16028847',
#  'https://www.domain.com.au/54-o-grady-street-albert-park-vic-3206-16059651',
#  'https://www.domain.com.au/8-7-nelson-street-balaclava-vic-3183-16009120',
#  'https://www.domain.com.au/425b-beach-road-beaumaris-vic-3193-16014933',
#  'https://www.domain.com.au/drummond-street-carlton-vic-3053-15992211',
#  'https://www.domain.com.au/143b-bambra-road-caulfield-vic-3162-16007137',
#  'https://www.domain.com.au/106-leicester-street-fitzroy-vic-3065-15992230',
#  'https://www.domain.com.au/205-250-st-kilda-road-melbourne-vic-3004-15979287',
#  'https://www.domain.com.au/49-o-connell-street-north-melbourne-vic-3051-15685646',
#  'https://www.domain.com.au/34-victoria-street-sandringham-vic-3191-16060121',
#  'https://www.domain.com.au/22-phoenix-street-south-yarra-vic-3141-16054422',
#  'https://www.domain.com.au/10-marne-street-south-yarra-vic-3141-15981508',
#  'https://www.domain.com.au/1701-649-chapel-street-south-yarra-vic-3141-15879263',
#  'https://www.domain.com.au/4-553-toorak-road-toorak-vic-3142-16050069',
#  'https://www.domain.com.au/3-553-toorak-road-toorak-vic-3142-15928839']

# %%
# removing duplicate links while maintaining the order of urls
abc_links = [] 
for i in url_links: 
    if i not in abc_links: 
        abc_links.append(i) 
        
# defining required regural expression for data extraction     
pattern = re.compile(r'>(.+)(.+?).*')
pattern1 = re.compile(r'>(.+)<.')
pattern2 = re.compile(r'destination=(.+)" rel=.')
basic_feature_list = []
# loop to iterate through each url
for property_url in abc_links:
    
    bsobj = BeautifulSoup(requests.get(property_url, headers=headers).text, "html.parser")
    
    # extracting address/name of property
    property_name = bsobj.find("h1", {"class": "css-164r41r"})
    
    # extracting baths, rooms, parking etc
    all_basic_features = bsobj.find("div", {"data-testid": "property-features-wrapper"}).findAll("span", {"data-testid": "property-features-text-container"})
    
    # extracting property price
    property_price = bsobj.find("div", {"data-testid": "listing-details__summary-title"})
    
    # extracting latitudes and longitudes
    lat_long = bsobj.find("a", {"target": "_blank", 'rel': "noopener noreferer"})
    
    # dictionary to store temporary data
    basic_feature_dict = {}
    
    # few properties does not contain all the 4 features such as rooms, baths, parkings, area. So need to check
    # how many features they contain
    if len(all_basic_features) == 4:
        basic_feature_dict[pattern.findall(str(all_basic_features[0]))[0][1]] = pattern.findall(str(all_basic_features[0]))[0][0]
        basic_feature_dict[pattern.findall(str(all_basic_features[1]))[0][1]] = pattern.findall(str(all_basic_features[1]))[0][0]
        basic_feature_dict[pattern.findall(str(all_basic_features[2]))[0][1]] = pattern.findall(str(all_basic_features[2]))[0][0]
        basic_feature_dict[pattern.findall(str(all_basic_features[3]))[0][1]] = pattern.findall(str(all_basic_features[3]))[0][0]
        
    elif len(all_basic_features) == 3:
        basic_feature_dict[pattern.findall(str(all_basic_features[0]))[0][1]] = pattern.findall(str(all_basic_features[0]))[0][0]
        basic_feature_dict[pattern.findall(str(all_basic_features[1]))[0][1]] = pattern.findall(str(all_basic_features[1]))[0][0]
        basic_feature_dict[pattern.findall(str(all_basic_features[2]))[0][1]] = pattern.findall(str(all_basic_features[2]))[0][0]
        
    elif len(all_basic_features) == 2:
        basic_feature_dict[pattern.findall(str(all_basic_features[0]))[0][1]] = pattern.findall(str(all_basic_features[0]))[0][0]
        basic_feature_dict[pattern.findall(str(all_basic_features[1]))[0][1]] = pattern.findall(str(all_basic_features[1]))[0][0]
        
    elif len(all_basic_features) == 1:
        basic_feature_dict[pattern.findall(str(all_basic_features[0]))[0][1]] = pattern.findall(str(all_basic_features[0]))[0][0]
# putting 'none' if price is missing    
    if property_price is None:
        basic_feature_dict['price'] = None
        
    else:
        basic_feature_dict['price'] = pattern1.findall(str(property_price))[0]
        
    # putting 'none' if property name/address is missing       
    if property_name is None:
        basic_feature_dict['name'] = None
        
    else:
        basic_feature_dict['name'] = pattern1.findall(str(property_name))[0]
        
    # putting 'none' if latitude and logitude are missing        
    if lat_long is None:
        basic_feature_dict['lat'] = None
        basic_feature_dict['long'] = None
        
    else:
        basic_feature_dict['lat'] = pattern2.findall(str(lat_long))[0].split(',')[0]
        basic_feature_dict['long'] = pattern2.findall(str(lat_long))[0].split(',')[1]
# appending all the data into a list
    basic_feature_list.append(basic_feature_dict)

# %%
basic_feature_list
# Out:
# [{'price': '$38,000 p.a. Incl. Outgoings + GST',
#   'name': '667 Glenhuntly Road Caulfield VIC 3162',
#   'lat': '-37.8860233',
#   'long': '145.0173065'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$35,000 Annually',
#   'name': 'Upstairs 2C Staley Street Brunswick VIC 3056',
#   'lat': '-37.7655919',
#   'long': '144.9633048'},
#  {'price': '4125000 pw',
#   'name': 'Level 3, 302/13-15 Lake Street Caroline Springs VIC 3023',
#   'lat': '-37.7316459',
#   'long': '144.7446886'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$6,000',
#   'name': '3502/14-16 The Esplanade St Kilda VIC 3182',
#   'lat': '-37.8650177',
#   'long': '144.9746821'},
#  {'>': '700m²<!-- --> </span',
#   'price': '$5,000 per week',
#   'name': '9 Lansdowne Street Blairgowrie VIC 3942',
#   'lat': '-38.372703',
#   'long': '144.7856897'},
#  {'>': '900m²<!-- --> </span',
#   'price': 'From $5500 per week',
#   'name': '52 Black St Brighton VIC 3186',
#   'lat': '-37.9159452',
#   'long': '144.9989003'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$4500 Per Week',
#   'name': '4203/35 Spring Street Melbourne VIC 3000',
#   'lat': '-37.8141725',
#   'long': '144.9740049'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$3,775 wk $545 pn',
#   'name': '335 The Esplanade Indented Head VIC 3223',
#   'lat': '-38.1439923',
#   'long': '144.7147899'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$3750 per week',
#   'name': '50 South Wharf Drive Docklands VIC 3008',
#   'lat': '-37.8223967',
#   'long': '144.938237'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$3750.00 per week',
#   'name': '901 &amp; 902/85 Market Street South Melbourne VIC 3205',
#   'lat': '-37.8301164',
#   'long': '144.9569041'},
#  {'>': '5<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$3,500.00',
#   'name': '9 Keith Court Brighton VIC 3186',
#   'lat': '-37.9171837',
#   'long': '144.9882699'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$3500 Per Week',
#   'name': '7 Haverbrack Avenue Malvern VIC 3144',
#   'lat': '-37.8534875',
#   'long': '145.0311415'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$3,200.00',
#   'name': '27 Moffat Street Brighton VIC 3186',
#   'lat': '-37.9229499',
#   'long': '144.9973078'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Fine Furnished Residences at Westprecinct',
#   'name': 'Brighton VIC 3186',
#   'lat': '-37.9043383',
#   'long': '144.9931825'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$3,100 per week',
#   'name': '7302/462 Elizabeth Street Melbourne VIC 3000',
#   'lat': '-37.807859',
#   'long': '144.960611'},
#  {'>': '509m²<!-- --> </span',
#   'price': '$3000 Per Week',
#   'name': '2B Mulgoa Street Brighton VIC 3186',
#   'lat': '-37.9025755',
#   'long': '144.988376'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2995 Per Week',
#   'name': '5 Wellington Street Brighton VIC 3186',
#   'lat': '-37.915482',
#   'long': '144.9891089'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$3,000 per week',
#   'name': '1 Bronte Court Hampton VIC 3188',
#   'lat': '-37.9399869',
#   'long': '145.0199068'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$3,000 weekly',
#   'name': "3607/80 A'Beckett Street Melbourne VIC 3000",
#   'lat': '-37.8090372',
#   'long': '144.9610905'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$3,000',
#   'name': '2202/14-16 The Esplanade St Kilda VIC 3182',
#   'lat': '-37.8650177',
#   'long': '144.9746821'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Fine Furnished Residences @ Westprecinct',
#   'name': 'Brighton VIC 3186',
#   'lat': '-37.9044002',
#   'long': '144.9997396'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2800 Per Week',
#   'name': '251/350 St Kilda Road Melbourne VIC 3000',
#   'lat': '-37.831142',
#   'long': '144.9708545'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,700',
#   'name': '2601/14-16 The Esplanade St Kilda VIC 3182',
#   'lat': '-37.8650177',
#   'long': '144.9746821'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2600.00 Per Week',
#   'name': '42 Dendy Street Brighton VIC 3186',
#   'lat': '-37.9200549',
#   'long': '144.9957406'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2600 per week',
#   'name': '119-121 Palmerston Street Carlton VIC 3053',
#   'lat': '-37.7965569',
#   'long': '144.9711271'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,600.00',
#   'name': '231/299 Queen Street Melbourne VIC 3000',
#   'lat': '-37.8114187',
#   'long': '144.9587916'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$120,000 plus gst and plus outgoings pa.',
#   'name': '15 Webster Street Malvern East VIC 3145',
#   'lat': '-37.887544',
#   'long': '145.087289'},
#  {'>': '1,056m²<!-- --> </span',
#   'price': '$2,500.00',
#   'name': '46-48 Wells Road Beaumaris VIC 3193',
#   'lat': '-37.9837637',
#   'long': '145.0499964'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,500 per week',
#   'name': 'Blairgowrie VIC 3942',
#   'lat': '-38.3645949',
#   'long': '144.7686693'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,500 per week',
#   'name': '133 North Road Brighton VIC 3186',
#   'lat': '-37.8988631',
#   'long': '145.0019562'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,500 per week',
#   'name': '3 Knight Street Elwood VIC 3184',
#   'lat': '-37.880361',
#   'long': '144.9889154'},
#  {'>': '3,000m²<!-- --> </span',
#   'price': '$2,500 pw',
#   'name': '3 Stonecutters Road Portsea VIC 3944',
#   'lat': '-38.334205',
#   'long': '144.725559'},
#  {'>': '529m²<!-- --> </span',
#   'price': '$2500',
#   'name': 'Richmond VIC 3121',
#   'lat': '-37.8270184',
#   'long': '144.9997611'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,500/MONTH',
#   'name': '62 william street St Albans VIC 3021',
#   'lat': '-37.737358',
#   'long': '144.815952'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,500',
#   'name': '3203/14-16 The Esplanade St Kilda VIC 3182',
#   'lat': '-37.8650177',
#   'long': '144.9746821'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2500 pw High, $1600 pw Low, $380 pn',
#   'name': '46 Leviens Road St Leonards VIC 3223',
#   'lat': '-38.1792023',
#   'long': '144.7079338'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,500.00 Per Week',
#   'name': '21 Mathoura Road Toorak VIC 3142',
#   'lat': '-37.8472801',
#   'long': '145.0067771'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2500 Per Week',
#   'name': '21 Iona Avenue Toorak VIC 3142',
#   'lat': '-37.848656',
#   'long': '145.016179'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,500 per week',
#   'name': '12 Clendon Court Toorak VIC 3142',
#   'lat': '-37.8444355',
#   'long': '145.0176639'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,400.00',
#   'name': '4a Fetherston Street Armadale VIC 3143',
#   'lat': '-37.85662',
#   'long': '145.018182'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,400.00',
#   'name': '27 Grandview Road Brighton VIC 3186',
#   'lat': '-37.9016247',
#   'long': '145.0047756'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,400.00',
#   'name': '1/2 SHANDFORD Avenue Brighton VIC 3186',
#   'lat': '-37.9013936',
#   'long': '144.9849778'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,500 PW -TWO LEVELS',
#   'name': '241/299 Queen Street Melbourne VIC 3000',
#   'lat': '-37.8114751',
#   'long': '144.9586205'},
#  {'>': '362m²<!-- --> </span',
#   'price': '$2,300.00',
#   'name': '142 Nelson Road South Melbourne VIC 3205',
#   'lat': '-37.8375632',
#   'long': '144.9513968'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,250.00',
#   'name': '23 Bay Street Brighton VIC 3186',
#   'lat': '-37.9033023',
#   'long': '144.9869653'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,250',
#   'name': 'UNIT 2707/35 SPRING STREET Melbourne VIC 3000',
#   'lat': '-37.8141725',
#   'long': '144.9740049'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2200 Per Week',
#   'name': '478 New Street Brighton VIC 3186',
#   'lat': '-37.8929745',
#   'long': '144.9956723'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'THE DEAL: $2,200 PER WEEK',
#   'name': '2105/368 St Kilda Road Melbourne VIC 3004',
#   'lat': '-37.8318086',
#   'long': '144.9710272'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,200 pw',
#   'name': '12 The Heights Sorrento VIC 3943',
#   'lat': '-38.32832519999999',
#   'long': '144.7353897'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,150.00',
#   'name': '4 Cowper Street Sandringham VIC 3191',
#   'lat': '-37.95440749999999',
#   'long': '145.0067771'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,150.00',
#   'name': '4 Cowper Street Sandringham VIC 3191',
#   'lat': '-37.95440749999999',
#   'long': '145.0067771'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,100.00',
#   'name': '8 Champion Street Brighton VIC 3186',
#   'lat': '-37.927999',
#   'long': '145.0033766'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,100.00',
#   'name': '2a Omar Street Caulfield South VIC 3162',
#   'lat': '-37.8903662',
#   'long': '145.0205525'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'From $2100 per week',
#   'name': '22 Campbell Street Frankston VIC 3199',
#   'lat': '-38.1444939',
#   'long': '145.1433389'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,100',
#   'name': '802/181 Fitzroy St St Kilda VIC 3182',
#   'lat': '-37.8577879',
#   'long': '144.9811923'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,000 pw',
#   'name': '19 Iona Street Black Rock VIC 3193',
#   'lat': '-37.973172',
#   'long': '145.0166374'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,000.00',
#   'name': '4/19 Birdwood Avenue Brighton VIC 3186',
#   'lat': '-37.8942781',
#   'long': '144.9867852'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,000.00',
#   'name': '2 Winmarleigh Close Brighton VIC 3186',
#   'lat': '-37.9245614',
#   'long': '144.9889585'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,995.00',
#   'name': '8 St Finbars Crescent Brighton East VIC 3187',
#   'lat': '-37.9169',
#   'long': '145.0147997'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1995.00 Per Week',
#   'name': '8 St Finbars Crescent Brighton East VIC 3187',
#   'lat': '-37.9169',
#   'long': '145.0147997'},
#  {'>': '18.12m²<!-- --> </span',
#   'price': '$2,000.00',
#   'name': '25/26 Little Cardigan Street Carlton VIC 3053',
#   'lat': '-37.8040783',
#   'long': '144.9654614'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,000.00',
#   'name': '163 Victoria Parade Fitzroy VIC 3065',
#   'lat': '-37.808286',
#   'long': '144.9804809'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,000',
#   'name': '3803/483 Swanston Street Melbourne VIC 3000',
#   'lat': '-37.8073886',
#   'long': '144.962087'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2,000 Per Week',
#   'name': '12/786 Esplanade Mornington VIC 3931',
#   'lat': '-38.2165108',
#   'long': '145.0357942'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2000 per week',
#   'name': '8 Canadian Bay Road Mount Eliza VIC 3930',
#   'lat': '-38.1737559',
#   'long': '145.0814604'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Contact for Price',
#   'name': 'Rye VIC 3941',
#   'lat': '-38.377',
#   'long': '144.838'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2000.00 per week',
#   'name': '85 Market Street South Melbourne VIC 3205',
#   'lat': '-37.8302556',
#   'long': '144.9579151'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2000 Per Week',
#   'name': '1002/243 Toorak Road South Yarra VIC 3141',
#   'lat': '-37.8392541',
#   'long': '144.995015'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2000 Per Week',
#   'name': '23A Bruce Street Toorak VIC 3142',
#   'lat': '-37.8368651',
#   'long': '145.0082406'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$480',
#   'name': '5 Brently Close Narre Warren North VIC 3804',
#   'lat': '-37.9923682',
#   'long': '145.3012059'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1950.00 per week',
#   'name': '73 Gardenvale Road Gardenvale VIC 3185',
#   'lat': '-37.8983488',
#   'long': '145.0093598'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,950 per week',
#   'name': '52 Sargood Street Hampton VIC 3188',
#   'lat': '-37.9427326',
#   'long': '145.0114045'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,800 per week',
#   'name': '2301/1 Almeida Crescent South Yarra VIC 3141',
#   'lat': '-37.8390089',
#   'long': '144.9954417'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,950 per week',
#   'name': '1203/57 City Road Southbank VIC 3006',
#   'lat': '-37.8220137',
#   'long': '144.9659363'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1950 Per Week',
#   'name': '4/9 Trawalla Avenue Toorak VIC 3142',
#   'lat': '-37.8391787',
#   'long': '145.0134493'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1900',
#   'name': '7 Wagstaff Court Brighton VIC 3186',
#   'lat': '-37.9040743',
#   'long': '144.9974369'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,900.00',
#   'name': '51 Were Street Brighton VIC 3186',
#   'lat': '-37.9245941',
#   'long': '144.993133'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,900.00',
#   'name': '2/10 Asling Street Brighton VIC 3186',
#   'lat': '-37.9042083',
#   'long': '145.0021284'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,900 weekly',
#   'name': '120 Glen Huntly Road Elwood VIC 3184',
#   'lat': '-37.8831984',
#   'long': '144.9894319'},
#  {'>': '37.16m²<!-- --> </span',
#   'price': '$1,900 per month',
#   'name': '21 Belair Avenue Glenroy VIC 3046',
#   'lat': '-37.7042489',
#   'long': '144.9111431'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1900.00 Per Week',
#   'name': '22 Ethel Street Malvern VIC 3144',
#   'lat': '-37.8475835',
#   'long': '145.0382487'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1900 per week',
#   'name': '70 Queens Road Pearcedale VIC 3912',
#   'lat': '-38.2070033',
#   'long': '145.2290927'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,890.00',
#   'name': '9 Exon Street Brighton VIC 3186',
#   'lat': '-37.9218363',
#   'long': '144.9971144'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1995 Per Week',
#   'name': '11 Hansens Lane Balnarring Beach VIC 3926',
#   'lat': '-38.3926971',
#   'long': '145.1241122'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,850.00',
#   'name': '140 Dendy Street Brighton East VIC 3187',
#   'lat': '-37.921372',
#   'long': '145.0083913'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,850',
#   'name': '21 Spring Street Fitzroy VIC 3065',
#   'lat': '-37.7970908',
#   'long': '144.9760426'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,800.00',
#   'name': '5 Alimar Court Brighton VIC 3186',
#   'lat': '-37.8967832',
#   'long': '144.9872371'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,800.00',
#   'name': '19 Moule Avenue Brighton VIC 3186',
#   'lat': '-37.9052991',
#   'long': '144.9865485'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,800.00 Per Week',
#   'name': '1302/1 Powlett Street East Melbourne VIC 3002',
#   'lat': '-37.8161275',
#   'long': '144.984988'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1800 per week',
#   'name': '7/126 Wellington Parade East Melbourne VIC 3002',
#   'lat': '-37.8162107',
#   'long': '144.9859245'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Whole floor penthouse - $1800 Per Week',
#   'name': '1501/601 St Kilda Road Melbourne VIC 3004',
#   'lat': '-37.8504751',
#   'long': '144.981546'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,800 per week',
#   'name': '1901/368 St Kilda Road Melbourne VIC 3004',
#   'lat': '-37.8318086',
#   'long': '144.9710272'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1800 per week',
#   'name': '904/201 Collins Street Melbourne VIC 3000',
#   'lat': '-37.8154091',
#   'long': '144.9674094'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '1800 per week Fully Furnished',
#   'name': '112 Harold St Middle Park VIC 3206',
#   'lat': '-37.851786',
#   'long': '144.9581506'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,800 pw',
#   'name': '24 Dreadnought Street Sandringham VIC 3191',
#   'lat': '-37.9527473',
#   'long': '145.0172376'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1800 per week',
#   'name': '417/250 St Kilda Road Southbank VIC 3006',
#   'lat': '-37.8255907',
#   'long': '144.9705826'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,799',
#   'name': '1/125 High St Prahran VIC 3181',
#   'lat': '-37.851373',
#   'long': '144.990978'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Under Application-$1,750.00 pw',
#   'name': '102 Carpenter Street Brighton VIC 3186',
#   'lat': '-37.9107405',
#   'long': '145.0003207'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1750 per week',
#   'name': '1307/14 Queens Road Melbourne VIC 3004',
#   'lat': '-37.8389211',
#   'long': '144.9749946'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1750 per week',
#   'name': '301/130 Bay Street Port Melbourne VIC 3207',
#   'lat': '-37.8406272',
#   'long': '144.9407724'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'LEASED',
#   'name': '9 Watson Road Sorrento VIC 3943',
#   'lat': '-38.34437800000001',
#   'long': '144.7402295'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,750.00',
#   'name': '12 Gurner Street St Kilda VIC 3182',
#   'lat': '-37.8615448',
#   'long': '144.980653'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,700.00',
#   'name': '14 Mackie Grove Brighton East VIC 3187',
#   'lat': '-37.9082205',
#   'long': '145.0202942'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,700.00',
#   'name': '238B Were Street Brighton East VIC 3187',
#   'lat': '-37.9276055',
#   'long': '145.0145686'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,700 per week',
#   'name': '501/8-10 New Street Richmond VIC 3121',
#   'lat': '-37.81359399999999',
#   'long': '144.992457'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,700.00 Per Week',
#   'name': '76 Millswyn Street South Yarra VIC 3141',
#   'lat': '-37.8356144',
#   'long': '144.980566'},
#  {'>': '711m²<!-- --> </span',
#   'price': '$1,690.00',
#   'name': '4 Newbay Crescent Brighton VIC 3186',
#   'lat': '-37.9048689',
#   'long': '144.991408'},
#  {'>': '250m²<!-- --> </span',
#   'price': '$1,675 per week',
#   'name': '1 Marine Avenue St Kilda VIC 3182',
#   'lat': '-37.873865',
#   'long': '144.977457'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,650.00',
#   'name': '41 Bay Street Brighton VIC 3186',
#   'lat': '-37.9036436',
#   'long': '144.9894542'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1650 Per Week',
#   'name': '7 Tuxen Court Brighton East VIC 3187',
#   'lat': '-37.9288923',
#   'long': '145.0281946'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,650 weekly',
#   'name': '24 Dante Lane Elwood VIC 3184',
#   'lat': '-37.882053',
#   'long': '144.983447'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,650.00',
#   'name': '1906/12 Queens Rd Melbourne VIC 3004',
#   'lat': '-37.8384194',
#   'long': '144.9747126'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,650 pw',
#   'name': '3/164 Ingles Street Port Melbourne VIC 3207',
#   'lat': '-37.8302392',
#   'long': '144.9436427'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,650.00',
#   'name': '25 Holroyd Avenue St Kilda East VIC 3183',
#   'lat': '-37.8644429',
#   'long': '145.0070354'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,615',
#   'name': '5701/260 City Rd Southbank VIC 3006',
#   'lat': '-37.8260239',
#   'long': '144.9595477'},
#  {'>': '6<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$85,000.00',
#   'name': '110 Beevers Street Footscray VIC 3011',
#   'lat': '-37.7958415',
#   'long': '144.9060052'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,600.00',
#   'name': '42 Dixon Street Malvern VIC 3144',
#   'lat': '-37.8607291',
#   'long': '145.0377319'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1600 per week',
#   'name': '1209/14 Queens Road Melbourne VIC 3004',
#   'lat': '-37.8389211',
#   'long': '144.9749946'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,600',
#   'name': '1604/250 St Kilda Road Melbourne VIC 3004',
#   'lat': '-37.8259165',
#   'long': '144.9705248'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,600 Per Week',
#   'name': '75 Rennison Street Parkdale VIC 3195',
#   'lat': '-37.9970369',
#   'long': '145.079791'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,550.00',
#   'name': '14 Evelyn Street Bentleigh VIC 3204',
#   'lat': '-37.9186389',
#   'long': '145.0502279'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1550 per week',
#   'name': '201 Cardigan Carlton VIC 3053',
#   'lat': '-37.8020773',
#   'long': '144.964928'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$2000 Per week',
#   'name': '7 Bonanza Road Beaumaris VIC 3193',
#   'lat': '-37.980529',
#   'long': '145.0519862'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1500 PW',
#   'name': '35 St James Park Drive Brighton VIC 3186',
#   'lat': '-37.9030025',
#   'long': '144.9976091'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500.00',
#   'name': '43 Black Street Brighton VIC 3186',
#   'lat': '-37.9156204',
#   'long': '144.9983193'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 weekly',
#   'name': '17 Durrant St Brighton VIC 3186',
#   'lat': '-37.9085183',
#   'long': '145.0031184'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500',
#   'name': '685 Hampton Street Brighton VIC 3186',
#   'lat': '-37.9249853',
#   'long': '145.0045376'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 per week',
#   'name': '2B Parklands Crescent Brighton East VIC 3187',
#   'lat': '-37.9159403',
#   'long': '145.0226836'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1500 Per Week',
#   'name': '9 Farnsworth Drive Cape Schanck VIC 3939',
#   'lat': '-38.456316',
#   'long': '144.891532'},
#  {'>': '100m²<!-- --> </span',
#   'price': '$1,500 per week',
#   'name': '4/18-22 Islington Street Collingwood VIC 3066',
#   'lat': '-37.8083229',
#   'long': '144.9908124'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500',
#   'name': 'East Melbourne VIC 3002',
#   'lat': '-37.8161444',
#   'long': '144.9804594'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 per week',
#   'name': '30 Gough Street Elsternwick VIC 3185',
#   'lat': '-37.8935491',
#   'long': '145.0074658'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 weekly',
#   'name': '304/2 Pine Avenue Elwood VIC 3184',
#   'lat': '-37.8865296',
#   'long': '144.9889161'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1500 pw',
#   'name': '71B Orlando Street Hampton VIC 3188',
#   'lat': '-37.93645009999999',
#   'long': '144.9982116'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1700 per week',
#   'name': '1/8 Glenview Avenue Malvern VIC 3144',
#   'lat': '-37.8540125',
#   'long': '145.0364677'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 per week',
#   'name': '241/538 Little Lonsdale Street Melbourne VIC 3000',
#   'lat': '-37.8136966',
#   'long': '144.953207'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500.00',
#   'name': '12A/635-643 St Kilda Road Melbourne VIC 3004',
#   'lat': '-37.8543122',
#   'long': '144.9826011'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 per week',
#   'name': '4/15-19 Anthony Street Melbourne VIC 3000',
#   'lat': '-37.809144',
#   'long': '144.958903'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 Per Week',
#   'name': '9 Woodland Avenue Mount Eliza VIC 3930',
#   'lat': '-38.17140330000001',
#   'long': '145.0906267'},
#  {'price': '$1,500 mth',
#   'name': '27 Ian Street Noble Park VIC 3174',
#   'lat': '-37.965879',
#   'long': '145.177001'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,495',
#   'name': '72 Fitzgibbon Street Parkville VIC 3052',
#   'lat': '-37.7946034',
#   'long': '144.9571934'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 pw',
#   'name': '25A Flinders Street Queenscliff VIC 3225',
#   'lat': '-38.2711542',
#   'long': '144.6513737'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1500 per week',
#   'name': '2702/89 Gladstone Street South Melbourne VIC 3205',
#   'lat': '-37.8301549',
#   'long': '144.9500578'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 per week',
#   'name': '2803/63 Haig Street Southbank VIC 3006',
#   'lat': '-37.82776339999999',
#   'long': '144.9567525'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500 per week',
#   'name': '2403/14-16 The Esplanade St Kilda VIC 3182',
#   'lat': '-37.8650177',
#   'long': '144.9746821'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,220 per week',
#   'name': '15C Alfred Street Balaclava VIC 3183',
#   'lat': '-37.8675203',
#   'long': '144.9922635'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,450.00',
#   'name': '3 Bown Court Brighton East VIC 3187',
#   'lat': '-37.9182554',
#   'long': '145.0151067'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,450.00',
#   'name': '119 Victoria Street Fitzroy VIC 3065',
#   'lat': '-37.7990139',
#   'long': '144.97919'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Contact Agent - Call us to book an inspection',
#   'name': '168 Westcott Parade Rockbank VIC 3335',
#   'lat': '-37.728685',
#   'long': '144.654902'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,450.00 per week',
#   'name': '2001/1 ALMEIDA CRESCENT South Yarra VIC 3141',
#   'lat': '-37.8390089',
#   'long': '144.9954417'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1450 per week',
#   'name': '10 Ormsby Grove Toorak VIC 3142',
#   'lat': '-37.8434705',
#   'long': '145.0091016'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,450 per week',
#   'name': '18/18 Curzon Street West Melbourne VIC 3003',
#   'lat': '-37.8043508',
#   'long': '144.9481504'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'LEASED',
#   'name': 'Portsea VIC 3944',
#   'lat': '-38.3207377',
#   'long': '144.718304'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,500.00 per week',
#   'name': '1601/1 ALMEIDA CRESCENT South Yarra VIC 3141',
#   'lat': '-37.8390089',
#   'long': '144.9954417'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,420.00',
#   'name': '14 Durrant Street Brighton VIC 3186',
#   'lat': '-37.9082865',
#   'long': '145.0022237'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1400 per week',
#   'name': '82 Reed Street Albert Park VIC 3206',
#   'lat': '-37.846725',
#   'long': '144.948226'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,400.00',
#   'name': '123 Kooyong Road Armadale VIC 3143',
#   'lat': '-37.8521518',
#   'long': '145.0208754'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,400',
#   'name': '52-54 Tinning Street Brunswick VIC 3056',
#   'lat': '-37.758969',
#   'long': '144.959178'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,400',
#   'name': '190A Weston Street Brunswick East VIC 3057',
#   'lat': '-37.7765669',
#   'long': '144.9756615'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1400pw/$6083pcm',
#   'name': '58 Freeman Street Fitzroy North VIC 3068',
#   'lat': '-37.7901277',
#   'long': '144.9804379'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'UNDER APPLICATION',
#   'name': '72/99 Spring Street Melbourne VIC 3000',
#   'lat': '-37.812531',
#   'long': '144.973326'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1400 per week',
#   'name': '1522/555 St Kilda Road Melbourne VIC 3004',
#   'lat': '-37.8470517',
#   'long': '144.9806745'},
#  {'>': '70m²<!-- --> </span',
#   'price': '$1,400',
#   'name': '3811/639 Lonsdale Street Melbourne VIC 3000',
#   'lat': '-37.8148924',
#   'long': '144.9536021'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,400',
#   'name': '809/576 St Kilda Rd Melbourne VIC 3004',
#   'lat': '-37.8485215',
#   'long': '144.9791462'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1400.00 per week',
#   'name': '803/430 St Kilda Road Melbourne VIC 3004',
#   'lat': '-37.837123',
#   'long': '144.9751256'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1400 per week',
#   'name': '41 Zoe Circuit Northcote VIC 3070',
#   'lat': '-37.7680117',
#   'long': '144.98586'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1750 pw High, $1400 pw Low',
#   'name': '5/90-110 Smythe Street Portarlington VIC 3223',
#   'lat': '-38.1209242',
#   'long': '144.6521696'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1750 pw High, $1400 pw Low',
#   'name': '7/90-110 Smythe Street Portarlington VIC 3223',
#   'lat': '-38.1209242',
#   'long': '144.6521696'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1750 pw High, $1400 pw Low',
#   'name': '6/90-110 Smythe Street Portarlington VIC 3223',
#   'lat': '-38.1209242',
#   'long': '144.6521696'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1750 pw High, $1400 pw Low, $250 pn',
#   'name': '380 Tower Road Portarlington VIC 3223',
#   'lat': '-38.12717290000001',
#   'long': '144.6716102'},
#  {'>': '−<!-- --> <span class="css-12a1b0h" data-testid="property-features-text">Parking</span></span',
#   'price': '$1750 pw High, $1400 pw Low',
#   'name': '8/90-110 Smythe Street Portarlington VIC 3223',
#   'lat': '-38.1209242',
#   'long': '144.6521696'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1400 per week',
#   'name': '2004/22 Dorcas Street Southbank VIC 3006',
#   'lat': '-37.8300237',
#   'long': '144.9695301'},
#  {'>': '23,088m²<!-- --> </span',
#   'price': 'Contact Agent',
#   'name': '208 Sandy Road St Andrews Beach VIC 3941',
#   'lat': '-38.4181171',
#   'long': '144.8526033'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,400',
#   'name': '2G05/14-16 The Esplanade St Kilda VIC 3182',
#   'lat': '-37.8650177',
#   'long': '144.9746821'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1400.00 Per Week',
#   'name': 'G01/508 Toorak Road Toorak VIC 3142',
#   'lat': '-37.8418356',
#   'long': '145.0133202'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,400.00',
#   'name': '188 Williams Road Toorak VIC 3142',
#   'lat': '-37.84698789999999',
#   'long': '145.003764'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1400 Per Week',
#   'name': '2 Rathmines Street Toorak VIC 3142',
#   'lat': '-37.838865',
#   'long': '145.005744'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,400.00',
#   'name': '1 David Lane Windsor VIC 3181',
#   'lat': '-37.8536301',
#   'long': '144.989448'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Fine Furnished Residences @ Westprecinct',
#   'name': 'Brighton VIC 3186',
#   'lat': '-37.9044002',
#   'long': '144.9997396'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Fine Furnished Residences @ Westprecinct',
#   'name': 'Brighton VIC 3186',
#   'lat': '-37.9044002',
#   'long': '144.9997396'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Fine Furnished Residences at Westprecinct',
#   'name': 'Brighton VIC 3186',
#   'lat': '-37.9043383',
#   'long': '144.9931825'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Fine Furnished Residences @ Westprecinct',
#   'name': 'Brighton VIC 3186',
#   'lat': '-37.9044002',
#   'long': '144.9997396'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': 'Fine Furnished Residences @ Westprecinct',
#   'name': 'Brighton VIC 3186',
#   'lat': '-37.9044002',
#   'long': '144.9997396'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,390.00',
#   'name': '6B Centre Road Brighton East VIC 3187',
#   'lat': '-37.9149958',
#   'long': '145.0078102'},
#  {'>': '4<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,390.00',
#   'name': '29 Canberra Grove Brighton East VIC 3187',
#   'lat': '-37.926174',
#   'long': '145.0103499'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,390.00',
#   'name': '19B Grant Street Brighton East VIC 3187',
#   'lat': '-37.9131627',
#   'long': '145.0089079'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350.00',
#   'name': "54 O'Grady Street Albert Park VIC 3206",
#   'lat': '-37.84281300000001',
#   'long': '144.953284'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350.00',
#   'name': '8/7 Nelson Street Balaclava VIC 3183',
#   'lat': '-37.8661624',
#   'long': '144.993616'},
#  {'>': '3<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350.00',
#   'name': '425B Beach Road Beaumaris VIC 3193',
#   'lat': '-37.9937063',
#   'long': '145.0334204'},
#  {'>': '310m²<!-- --> </span',
#   'price': '$1,350',
#   'name': 'Drummond street Carlton VIC 3053',
#   'lat': '-37.7988884',
#   'long': '144.9688269'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350 per week',
#   'name': '143B Bambra Road Caulfield VIC 3162',
#   'lat': '-37.8848382',
#   'long': '145.0289911'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350.00',
#   'name': '106 Leicester Street Fitzroy VIC 3065',
#   'lat': '-37.7956041',
#   'long': '144.9797924'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350',
#   'name': '205/250 St Kilda Road Melbourne VIC 3004',
#   'lat': '-37.8259182',
#   'long': '144.970146'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350',
#   'name': "49 O'Connell Street North Melbourne VIC 3051",
#   'lat': '-37.8046975',
#   'long': '144.9575483'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350.00',
#   'name': '34 Victoria Street Sandringham VIC 3191',
#   'lat': '-37.956845',
#   'long': '145.015297'},
#  {'>': '1<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1350 per week',
#   'name': '22 Phoenix Street South Yarra VIC 3141',
#   'lat': '-37.8429687',
#   'long': '144.9922454'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1350 Per Week',
#   'name': '10 Marne Street South Yarra VIC 3141',
#   'lat': '-37.8372095',
#   'long': '144.9839347'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1350 per week',
#   'name': '1701/649 Chapel Street South Yarra VIC 3141',
#   'lat': '-37.8374374',
#   'long': '144.9955647'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '1350pw',
#   'name': '4/553 Toorak Road Toorak VIC 3142',
#   'lat': '-37.8411174',
#   'long': '145.0126789'},
#  {'>': '2<!-- --> <span class="css-9fxapx" data-testid="property-features-text">Parking</span></span',
#   'price': '$1,350.00',
#   'name': '3/553 Toorak Road Toorak VIC 3142',
#   'lat': '-37.8411094',
#   'long': '145.0126039'}]

# %%
# creating empty lists
beds_list = []
baths_list = []
parking_list = []
area_list = []
name_list = []
lat_list = []
long_list = []
price_list = []
# interating through list created above with data
for row in basic_feature_list:
    
    # checking if the row cointains 'Beds', 'Bed' or nothing
    if 'Beds' in row:
        beds_list.append(row['Beds'])
    elif 'bed' in row:
        beds_list.append(row['Bed'])
    else:
        beds_list.append(None)
        
    # checking if the row cointains 'Baths', 'Bath' or nothing    
    if 'Baths' in row:
        baths_list.append(row['Baths'])
    elif 'Bath ' in row:
        baths_list.append(row['Bath'])
    else:
        baths_list.append(None)
        
    # checking if the row cointains 'Parking', '-' or nothing     
    if 'Parking' in row and row['Parking'] != '−':
        parking_list.append(row['Parking'])
    else:
        parking_list.append(None)
        
    # checking if the row cointains ' ', or nothing. Because empty space (i.e. ' ') reprsents area  
    if ' ' in row:
        area_list.append(row[' '])
    else:
        area_list.append(None)
# checking if the row cointains 'name' that is address of property         
    if 'name' in row:
        name_list.append(row['name'])
    else:
        name_list.append(None)
    
    # checking if the row cointains 'price'         
    if 'price' in row:
        price_list.append(row['price'])
    else:
        price_list.append(None)        
    
    # checking if the row cointains 'lat' that is lattitude of property         
    if 'lat' in row:
        lat_list.append(row['lat'])
    else:
        lat_list.append(None)  
        
    # checking if the row cointains 'long' that is lattitude of property             
    if 'long' in row:
        long_list.append(row['long'])
    else:
        long_list.append(None)

# %%
import random
# creating a new empty price list
actual_price_list = []
# defining some regural expressions, they will be used to extract price of properties
pattern1 = re.compile(r'\$\s?([0-9,\.]+).*\s?.+\s?\$\s?([0-9,\.]+)')
pattern2 = re.compile(r'\$([0-9,\.]+)')
# interating through price_list
for i in range(len(price_list)):
    
    # check that a price is given or range of price is given
    
    if str(price_list[i]).count('$') == 1:
        b_num = pattern2.findall(str(price_list[i]))
        
        # checking length of string, if it is less than or equal to 5 then price is in millions so need to convert the price
        if len(b_num[0].replace(',', '')) > 5:
            actual_price_list.append(float(b_num[0].replace(',', '')))
        else:
            actual_price_list.append(float(b_num[0].replace(',', ''))*1000000)
        
    elif str(price_list[i]).count('$') == 2:
        a_num = pattern1.findall(str(price_list[i]))
        random_error = random.randint(0, 10000)
        
        # checking length of string, if it is less than or equal to 5 then price is in millions so need to convert the price
        if len(a_num[0][0].replace(',', '')) > 5 and len(a_num[0][1].replace(',', '')) > 5:
            
            # to take average price between two price range given
            avg_price = (float(a_num[0][0].replace(',', '')) + float(a_num[0][1].replace(',','')))/2
        else:
            avg_price = (float(a_num[0][0].replace(',', '')) + float(a_num[0][1].replace(',',''))/2)*1000000
            
        # adding or subtracting the amount from the average price by normally distributed generated random number
        avg_price = avg_price + random_error
        actual_price_list.append(avg_price)
    else:
        actual_price_list.append('middle_price')

# %%
# for loop to impute missing values at the start of list, because here we cannot take mean
for i in range(len(actual_price_list)):
    if actual_price_list[i] != 'middle_price':
        for a in range(i, -1, -1):
            actual_price_list[a] = actual_price_list[i]
        break
# here we will be taking mean and then add random number with same standard deviation normal distribution and then impute it
for i in range(len(actual_price_list)):
    if actual_price_list[i] == 'middle_price':
        for j in range(i, len(actual_price_list)):
            if actual_price_list[j] != 'middle_price':
                mid = (actual_price_list[i-1] + actual_price_list[j])/2
                if actual_price_list[j] > 12000000:
                    for k in range(i, j):
                        random_error = random.randint(-1000000, 1000000)
                        mid = mid + random_error
                        actual_price_list[k] = mid
                    i = j
                    break
                elif actual_price_list[j] > 5000000:
                    for k in range(i, j):
                        random_error = random.randint(-100000, 100000)
                        mid = mid + random_error
                        actual_price_list[k] = mid
                    i = j
                    break
                else:
                    for k in range(i, j):
                        random_error = random.randint(-10000, 10000)
                        mid = mid + random_error
                        actual_price_list[k] = mid
                    i = j
                    break
            elif j == len(actual_price_list)-1:
                for n in range(i, len(actual_price_list)):
                    random_error = random.randint(-1000, 1000)
                    a_price = actual_price_list[i-1]
                    a_price = a_price + random_error
                    actual_price_list[n] = a_price
                break

# %%
import pandas as pd
house_dict = {}
house_dict['Beds'] = beds_list
house_dict['Baths'] = baths_list
house_dict['Parking'] = parking_list
house_dict['Area'] = area_list
house_dict['Address'] = name_list
house_dict['Latitude'] = lat_list
house_dict['Longitude'] = long_list
house_dict['Price'] = actual_price_list
house_df = pd.DataFrame(house_dict)
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Beds       0 non-null      object
#  1   Baths      0 non-null      object
#  2   Parking    0 non-null      object
#  3   Area       0 non-null      object
#  4   Address    200 non-null    object
#  5   Latitude   200 non-null    object
#  6   Longitude  200 non-null    object
#  7   Price      200 non-null    float64
# dtypes: float64(1), object(7)
# memory usage: 12.6+ KB

# %%
house_df.to_csv('../data/raw/real_estate_data_csv.csv', index=False)

# %% [markdown]
# #### One ‘area’ column has different null values that cannot be credited so we would be removing the ‘area’ column.

# %%
house_df.drop('Area', axis=1, inplace=True)

# %% [markdown]
# #### In addition, convert baths, beds, and parking string types into numeric types.

# %%
house_df["Beds"] = pd.to_numeric(house_df["Beds"])
house_df["Baths"] = pd.to_numeric(house_df["Baths"])
house_df["Parking"] = pd.to_numeric(house_df["Parking"])

# %% [markdown]
# #### Now, do some descriptive data analytics for finding data problems and solve those problems. For instance, utilize scatter plot for checking outliers within data or utilize histogram to watch data distribution etc.

# %%
# scatter plot
house_df.plot.scatter(x='Beds',y='Baths')
# histogram
house_df["Price"].plot.hist(bins = 50)
# Out:
# <AxesSubplot:xlabel='Beds', ylabel='Frequency'>

# %%
import math
cleaned_house_df = house_df.dropna(how='any')
cleaned_house_df.reset_index(drop = True, inplace = True)
# radius of earth is 6378
r = 6378
dis_to_city = []
for i in range(len(cleaned_house_df)):
    
    lat1_n = math.radians(-37.818078)
    lat2 = math.radians(float(cleaned_house_df['Latitude'][i]))
    
    lon1_n = math.radians(144.96681)
    lon2 = math.radians(float(cleaned_house_df['Longitude'][i]))
    
    lon_diff_n = lon2 - lon1_n
    lat_diff_n = lat2 - lat1_n
    
    a_n = math.sin(lat_diff_n / 2)**2 + math.cos(lat1_n) * math.cos(lat2) * math.sin(lon_diff_n / 2)**2
    c_n = 2 * math.atan2(math.sqrt(a_n), math.sqrt(1 - a_n))
    
    dis_to_city.append(round(r*c_n, 4))
    
cleaned_house_df['distance_to_city'] = dis_to_city

# %% [markdown]
# #### The last step is exporting Dataframe to some other tabular formats file including a CSV or an excel file.

# %%
# exporting to csv file
cleaned_house_df.to_csv('real_estate_data_csv.csv', index=False)
# exporting to excel file
cleaned_house_df.to_excel('real_estate_data_excel.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape_domain.ipynb Cell 20 in <cell line: 4>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape_domain.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> cleaned_house_df.to_csv('real_estate_data_csv.csv', index=False)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape_domain.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # exporting to excel file
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/scrape_domain.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> cleaned_house_df.to_excel('real_estate_data_excel.xlsx', index=False)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353 )
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/formats/excel.py:888, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     884     need_save = False
#     885 else:
#     886     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888     writer = ExcelWriter(  # type: ignore[abstract]
#     889         writer, engine=engine, storage_options=storage_options
#     890     )
#     891     need_save = True
#     893 try:
#
# File ~/.local/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py:49, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      36 def __init__(
#      37     self,
#      38     path,
#    (...)
#      47 ):
#      48     # Use the openpyxl module as the Excel writer.
# ---> 49     from openpyxl.workbook import Workbook
#      51     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      53     super().__init__(
#      54         path,
#      55         mode=mode,
#    (...)
#      58         engine_kwargs=engine_kwargs,
#      59     )
#
# ModuleNotFoundError: No module named 'openpyxl'
