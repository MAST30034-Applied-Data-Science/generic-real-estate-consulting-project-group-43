# %% [markdown]
# # API retrieving for residential instances

# %% [markdown]
# ### Example for install dotenv package

# %%
# !python3.10 -m pip install python-dotenv

# %% [markdown]
# ### Use of .env file for Domain.com API

# %%
from http import client
import os
from dotenv import load_dotenv

load_dotenv()

client_id = []
client_secret = []
for i in range(1, 12):
    client_id.append(os.getenv('CLIENT_ID'+str(i)))
    client_secret.append(os.getenv('CLIENT_SECRET'+str(i)))

CLIENT_ID = client_id
CLIENT_SECRET = client_secret

# %%
import requests
import json
from bs4 import BeautifulSoup
from csv import writer

# register  your own client id and api key at https://developer.domain.com.au/

client = {}
client['client_id'] = CLIENT_ID
client['client_secret'] = CLIENT_SECRET

def retrive_properties(client_id, client_secret, pageNumber, postCode="", state="VIC", pageSize=200, filename="../../data/raw/API_Raw_PropertiesInfo.csv"):
  scopes = ['api_listings_read']
  auth_url = 'https://auth.domain.com.au/v1/connect/token'
  url_endpoint = 'https://api.domain.com.au/v1/listings/residential/_search'

  # mock client post request in exchange of a one-time access token
  response = requests.post(auth_url, data = {
                          'client_id':client_id,
                          'client_secret':client_secret,
                          'grant_type':'client_credentials',
                          'scope':scopes,
                          'Content-Type':'text/json'
                          })
  json_res = response.json()
  # take the access token each time (can call a page of size 200)
  access_token=json_res['access_token']
  print("Access:", access_token)
  # authentication for current access token
  auth = {'Authorization':'Bearer ' + access_token}
  url = url_endpoint

  # with the current access token, specify the post search query 
  post_fields = {
        "listingType":"Rent", # only interested in Rents
        "pageSize": pageSize, 
        "pageNumber": pageNumber, # 200 per page
        "propertyTypes":"",
        "minBedrooms":1,
        "minBathrooms":1,
        # "maxPrice": 400,
        "sort": {
            "sortKey": "Default"
        },

        "locations":[
          {
            "state": state,
            "region":"",
            "area":"",
            "suburb":"",
            "postCode": postCode, # will iterate by postcodes
            "includeSurroundingSuburbs":False
          }
        ]
  }

  # get the response of a post search, could either be 200 (success) or some errors
  respond = requests.post(url,headers=auth,json=post_fields)
  content = json.loads(respond.text)
  print("Loaded data: " + str(len(content)))
  # quota error or no relevant data can be found on this page, e.g.
  # {'errors': {'searchParameters.Page': ['Cannot page beyond 1000 records.']},
  # 'message': 'The request is invalid.'}
  if ("errors" in content or len(content) == 0):                                              
    print("Limit notice")
    print(content)
    return 1
  # errors occur when the query type is not from PropertyListing
  elif ("type" in content and content["type"] != "PropertyListing"):
    print("Error accurs (No data)")
    print(content)
    return 2

  # Get request for each property ID and extract attributes, each 'i' is 
  # a single property schema in json format
  for i in content:
      #get details
      id = i['listing']['id']
      listing_type = i['listing']['listingType']
      r = i['listing']['propertyDetails']
      street_address=r['displayableAddress']
      suburb=r['suburb']
      postcode=r['postcode']
      area=r['area']
      if('buildingArea' in r and 'landArea' in r):
        building_area = r['buildingArea']
        land_area = r['landArea']
      else:
        building_area = 0
        land_area = 0
      # latitude and longitude might not be available in some instances
      if ('latitude' in r and 'longitude' in r):
        latitude = r['latitude']
        longitude = r['longitude']
      else:
        latitude = None
        longitude = None
      
      property_type=r['propertyType']
      bathrooms=r['bathrooms']
      bedrooms=r['bedrooms']

      if(str(i).find('carspaces'))>0:
          carspaces=i['listing']['propertyDetails']['carspaces']
      else:
          carspaces=0

      price=i['listing']['priceDetails']['displayPrice'] #[1:4]

      if(i['listing']['dateListed']):
          time = i['listing']['dateListed']
      else:
          time = 0

      info = [id, time, listing_type, price, property_type, area, building_area, land_area, 
      bedrooms, bathrooms, carspaces, street_address, suburb, postcode, latitude, longitude]

      # write the relevant info of current property one row at a time
      with open(filename, 'a', newline='') as g:
          thewriter = writer(g)
          thewriter.writerow(info)

  return 0

# retrive_properties(client_id, client_secret, 1)

# %% [markdown]
# ### Inialise the csv output file with headers

# %%
# Write column headers
headers = ['property_id', 'listing_type', 'price', 'time_listed', 'property_type', 'area', 'building_area', 'land_area', 
'bedrooms', 'bathrooms', 'carspaces', 'street_address', 'suburb', 'postcode', 'latitude', 'longitude']
output_csv = open('../../data/raw/API_Raw_PropertiesInfo.csv', 'w')
# create the csv writer object
csv_writer = writer(output_csv)
# first write the headers
csv_writer.writerow(headers)

output_csv.close()

# %% [markdown]
# ### Rrtrive rental data

# %%
# Retrive rental data by postcode
# postcode 3000~4000
count = 0
limit = len(client['client_id'])

for i in range(3000, 4000):
    # Check available api list
    if count >= limit:
        print("Exceed the download permit")
        break

    # Retrive data
    print("Retriving data from postcode: " + str(i))

    # read data by page (1~5)
    p = 1
    while p < 6:
        if count >= limit:
            break

        client_id = client['client_id'][count]
        client_secret = client['client_secret'][count]

        num = retrive_properties(client_id, client_secret, p, str(i))
        if num == 1:
            # no data found
            break
        elif num == 2:
            # change the new api
            count += 1
            print("using api" + str(count))
        else:
            # continue to the next page
            p += 1

# postcode 8000~9000
for i in range(8000, 9000):
    if count >= limit:
        print("Exceed the download permit")
        break

    print("Retriving data from postcode: " + str(i))

    p = 1
    while p < 6:
        if count >= limit:
            break
        
        client_id = client['client_id'][count]
        client_secret = client['client_secret'][count]

        num = retrive_properties(client_id, client_secret, p, str(i))
        if num == 1:
            break
        elif num == 2:
            count += 1
            print("using api" + str(count))
        else:
            p += 1
# Out:
# Retriving data from postcode: 3000
# Access: d66e3a731116bc0bde9147c6acb6938c
# Loaded data: 200
# Access: 87e9190ac5029c2559e387377bfb2693
# Loaded data: 200
# Access: 2b4858d108b88ce483e8d81f4fce913b
# Loaded data: 165
# Access: 2f7fc10c3a79a886e3e2c1be47203da3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3001
# Access: b9cbfcb16c2f8d82f93395894b6ec97b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3002
# Access: 6835b59fd53b388b8db9e2428098cb46
# Loaded data: 42
# Access: 21de9c3a9835704509809b0601f71611
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3003
# Access: e65496cd70685b5f6afcc3b18e5d3ec6
# Loaded data: 71
# Access: cc9f68b3afbfbd3e94a3377e088cb9c0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3004
# Access: 0c94b0a405cf24cc802653a969abb992
# Loaded data: 91
# Access: a893bc05742930e706bb5aa6dd27866c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3005
# Access: 3def21dc8f7fc408af906f94573219f8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3006
# Access: af7900da513765988aaa23fa83d8f792
# Loaded data: 200
# Access: 48c78871c2337b6b23de13e486609a85
# Loaded data: 24
# Access: 5ebdce634f4650aaaec5ea444b11486b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3007
# Access: a39ce1aa27768ae65cd99aecc1778b9f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3008
# Access: afa752b4efb818f5a009ce613e1b580d
# Loaded data: 138
# Access: 8797d6f2d76bd67c5990c4593fe41a69
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3009
# Access: 352ad8929de097207d78ee1046e6607d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3010
# Access: f79d9561dc6a9d53ee3ba18a7f151772
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3011
# Access: e765ab83e62da9207bd55f5b18f4e28c
# Loaded data: 200
# Access: d749899ab28d0510d0744d958b2088dd
# Loaded data: 6
# Access: 82a7f0aafee6fe87ace0527bb8469e81
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3012
# Access: def8003d24b6f378e4247adbe7e1ceee
# Loaded data: 127
# Access: ffa86775c6649d42936bc9209f3288f8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3013
# Access: 124761e7053cdf82a747ac99a407b8c3
# Loaded data: 72
# Access: fdc374a87ae8c4eb8ab3dc75a4ede232
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3014
# Access: 051c02559307b8722e0421282beedf2a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3015
# Access: f09cbc37be6e6a23dab15985ece53284
# Loaded data: 84
# Access: fac4102469cc5d9621f87f80281b0ddf
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3016
# Access: 41b3920c0f706201b5238a97edbad033
# Loaded data: 67
# Access: e3d1c9a0274e8afa494179392f54c28b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3017
# Access: 7e60465a5ee83784329433cb6d8ef78a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3018
# Access: 96d4abb7278a2fea4352e2476d41c692
# Loaded data: 58
# Access: 8e152cb70557142d0074ade4034eabec
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3019
# Access: 2775f4a12074259c1e3dffc8fb817f9b
# Loaded data: 29
# Access: 79711beff8375c40c2b931c7b425285a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3020
# Access: 4ce7d025d551ee839479732202e55df0
# Loaded data: 127
# Access: 3e9d290afcec26076efded5eb0171965
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3021
# Access: f821baf7897ea3851bacfef699aec89c
# Loaded data: 138
# Access: 945191e5b1b5cbfa48e6725ef751d98b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3022
# Access: 6a3c1ba6618340b0fc8db4863bdf74a6
# Loaded data: 18
# Access: ae99a7259f3d75d6129004c331035f36
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3023
# Access: 735e03920b293bdd86b2fea8435e4a23
# Loaded data: 100
# Access: b7be7c4f3943a0b392a5528828d142a3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3024
# Access: 02026f43bd97e80c06c529d7714fd771
# Loaded data: 124
# Access: 82d486b2f193ab2c3980b3f04349bfa2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3025
# Access: d849da2c99eaa9a413d43e574edb747f
# Loaded data: 39
# Access: c4e3f5ad00fba9f40836994ba0171e07
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3026
# Access: 2abd860ef4e8a730c26ae26e294730d2
# Loaded data: 9
# Access: a605fe4e0338b5bb92738c964eb54d2b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3027
# Access: 49e44bc68353c66d21274c1b6bd09ed5
# Loaded data: 23
# Access: 3c449cd08bb6eab7065b9389bb0ff931
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3028
# Access: e9b6ca8fbe50d183559c63e7226393a4
# Loaded data: 98
# Access: ba34e8fc8e31a38401eaad96a371738b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3029
# Access: 3d2ef68b578994b50f9c4ca30ca016e4
# Loaded data: 200
# Access: f41d91c61e84fa7fa95e7aa8962335ff
# Loaded data: 63
# Access: ecb48aacae6c0323c412a195edd7e6a7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3030
# Access: 38352bc34701043e13ad665993218bc2
# Loaded data: 200
# Access: a9575ed36425967cfb1d87e30085109b
# Loaded data: 76
# Access: 900017701372f8051841f5729a8dc033
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3031
# Access: fff0303d320b06c8ed4eeb3d380fbd54
# Loaded data: 113
# Access: efed2e1639715c27ad8c93a62d170350
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3032
# Access: 0db0ca3fc6353a2d7abbfbcb5c37d2f8
# Loaded data: 135
# Access: 71b0a95e8cd25e2b0907b081660c25b8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3033
# Access: ff0a18a2043ae7fe15fa4e467ec4ec43
# Loaded data: 22
# Access: ea692fb575e6e4544d9c5d6814f5c94d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3034
# Access: 277ce41658281d1f933f47b588137ff8
# Loaded data: 32
# Access: 6bc60974866272038706463ad6db0b0a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3035
# Access: 2e656378353f8382090f53704d2f896c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3036
# Access: d51d98e58ec51b5001f8e774cbedd6d6
# Loaded data: 4
# Access: c12d57bd0c4d0e58678f3211e5e1404f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3037
# Access: 15d4f1a82b7a29999ce56269d47d51cf
# Loaded data: 42
# Access: b49565872d4a58781fac619cb06aa658
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3038
# Access: 03f0e1584dbae8f1a70902899ff68c22
# Loaded data: 14
# Access: a3aa7997826faa13b809cdf448c403dc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3039
# Access: 7c2b1df34a1cee35115c02f01f881e04
# Loaded data: 76
# Access: 499d817ad104fc942656a363fe1c2cc0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3040
# Access: a4f2dca3ff97177a8dae8963224ed582
# Loaded data: 107
# Access: d70eb44f9a33dc441032f5437fa02119
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3041
# Access: 84fc9651e8c1612f4f42ce1d85a1dba8
# Loaded data: 37
# Access: 42f42d787f6452970ec59117e73f5cf7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3042
# Access: a1618f7892f94f4a4664880306837327
# Loaded data: 43
# Access: 305adef79dc689d8fa766067129e3674
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3043
# Access: 098428a0c21c5a9595bfde1aba850f83
# Loaded data: 45
# Access: dcd3777725cfb737eb41a18ab2516b4d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3044
# Access: 9ab0913ba0aef9534048a1190fd8adae
# Loaded data: 91
# Access: 93916624125947d078867db1c4d41060
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3045
# Access: a5a0df4412f013ca713ed05224a178a0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3046
# Access: 834d14546bc9442f0ede36692e5dd111
# Loaded data: 148
# Access: 35f0f28038bbfbec0da62bcc46d0cd7f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3047
# Access: 15d1c2aae4883b8d0249c467d20ff30d
# Loaded data: 59
# Access: 5236b080daee93be32ba78c74d67b295
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3048
# Access: 0e1c1ddd4d4191d164d60159c2124886
# Loaded data: 22
# Access: a1184bec1d644efb0a113eb22dbbc52f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3049
# Access: e46e48530d61de62c76256e2259a7ffc
# Loaded data: 11
# Access: 728334ed07e330da5f3107bfcd09fffc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3050
# Access: 15ffd863c5b837e078382839f11c485e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3051
# Access: 3ac6b623f3f3cd3ef96221da27d9eab2
# Loaded data: 100
# Access: 9bcfb556616b3ba8bade39b6c2bb80ad
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3052
# Access: 3cd739cf4c38dbe905ee099558bf8898
# Loaded data: 39
# Access: 837adb1f52d09182d8f556cfcf1ddaad
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3053
# Access: 5a8703809ff5052d43c55fd8d415871a
# Loaded data: 150
# Access: be223b13feec78f5d307f4f4a4624592
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3054
# Access: d7ea395087834b1565064745c990e726
# Loaded data: 52
# Access: 2d9061a97aa2f85fd56b12d4258239c8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3055
# Access: 4713e65a96bb8ef2fec34773e62a8522
# Loaded data: 95
# Access: ddc84d238573a3495b5f765c07cca87e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3056
# Access: fda22737c6b30f98438575196ceafbd0
# Loaded data: 143
# Access: ca7112176a4d6622335c17c939137449
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3057
# Access: 8c14332a1a89c4f41c4f32084a339e62
# Loaded data: 92
# Access: b0081d39d1cc5457eac89015f83b7b0f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3058
# Access: c81e7a10b2a0b3fb998ec9118db7ac4c
# Loaded data: 115
# Access: a5097397b2069e1854b07f8b73f61080
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3059
# Access: 3e90bd37ef2f6cde5912428750fe6e68
# Loaded data: 15
# Access: 63d206b78750fcc02cd3006fbacd8f6f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3060
# Access: 4233d131e9ac008cbf79bcde59216633
# Loaded data: 36
# Access: 8d777d477830145c4fbefabc72bbf5ab
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3061
# Access: 2196ae91e9959bf1b494ddf36de0f1e8
# Loaded data: 6
# Access: 822f870075eeec15c672e4238e421f5c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3062
# Access: ad0d67210702edd8fd9d7c6ff5dd96f6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3063
# Access: f90925cf665df947723d4663dd29b440
# Loaded data: 1
# Access: 20b3fcbeac70073edb9621c7007afffb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3064
# Access: 1f1baabc4926168fb8067019d1ccac8e
# Loaded data: 193
# Access: aa9b24a1997e3b602a4cebc82d67b7ee
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3065
# Access: e0e8f5ffcfc97594e23a329ef5330901
# Loaded data: 56
# Access: 30d7063d6b252c3c4a4e40692ae9c358
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3066
# Access: 8aa0f77941a9becc5ec5fb9907be713f
# Loaded data: 46
# Access: 6934f6135b2345c2ea83a9125f40878b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3067
# Access: d73d00082c8ed4f094cf4fd633e0d252
# Loaded data: 48
# Access: 6bee222b985f900455be7f2c33572701
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3068
# Access: e9dcf49096da44cf00b873e6e36a8b09
# Loaded data: 82
# Access: cae133e3c2c805e5c6478284835e2c94
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3069
# Access: 7367768403fc69c4cf26ef9e3110efd5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3070
# Access: 545dea038cd361e2863e41e6e8fb2119
# Loaded data: 106
# Access: 2e240dda9de90eca8717f971500f7097
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3071
# Access: 12088ebff38152060d88640ffedce421
# Loaded data: 60
# Access: 38636ac380bce4b6845adee5159aea2e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3072
# Access: e5986b3f1bd072b1d8acc5e2f6dfcafb
# Loaded data: 132
# Access: dbb03e3d18bfe37e8ad4627ec18e895c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3073
# Access: 7399c7c3d5d198eface869d315b208a2
# Loaded data: 186
# Access: 6a27fbe776fb1bd07be777bd25f0701f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3074
# Access: 272844f8cade1d20e99d40ac6bff9620
# Loaded data: 52
# Access: 11776d17b8a6ee2d1a894444f953e602
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3075
# Access: 36e3d2c5729c9bc587aee93e2986457b
# Loaded data: 38
# Access: 48f063593e35b999abda12c63373ecbe
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3076
# Access: 51f268938d0383d9cc7b400eb9db7fd4
# Loaded data: 59
# Access: 46ed2de8fa969252b9cb9201c21de5d9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3077
# Access: a120879bed4c40dcec666066fd865e45
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3078
# Access: ff1aefdd3e4c6312a9d0cc4071586890
# Loaded data: 56
# Access: 8b3c2fb5487647d568e8c95098bfcd14
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3079
# Access: 529b3e4b8dc2c7ef05d28c3b19c47719
# Loaded data: 60
# Access: a8ffc0697f3e60106de766ba6bc27609
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3080
# Access: 71b149e4a5b2f10e29adb999abd8ed7c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3081
# Access: 6fdb1c3813e407827999c6ab73c36007
# Loaded data: 49
# Access: 7bf37b72a2ce3ae7a733e14eaf080476
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3082
# Access: bf5e594b683962d4cd885b0f878fbaf6
# Loaded data: 36
# Access: e98459eae58097866028fcb802afc330
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3083
# Access: 91867164186216beb1b93a8bbc1d5904
# Loaded data: 110
# Access: b1bf53a1f9231110cf942d58f8abb0af
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3084
# Access: 89d90ae2b4db01ae2eeb64f8a301f77e
# Loaded data: 66
# Access: ae9c53779162d52c2e7a39a8430657bb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3085
# Access: cec2354c5cf8e244ab1136392131f514
# Loaded data: 26
# Access: c1e580a1978a990dba1af5a08e27762a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3086
# Access: 954d0fc28a80b4cc4d957b5d0f8a5d0b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3087
# Access: b56ef947724978033fa80cb8765a7dfb
# Loaded data: 18
# Access: cb36dcbb091957c20a2a1615aa51ac54
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3088
# Access: df9aea1e6a2e625e98bc3ae01fd7983a
# Loaded data: 33
# Access: 9f1162fcb2138cbd5b98e5fef1e3c5f4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3089
# Access: 9014e76a76e31ce17dd6fcb38a1a1356
# Loaded data: 12
# Access: 232f0a66e3ee7da0c6b8b9928dbb268f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3090
# Access: 0d7991c9e6d0050eeafdcf6a011a5ec6
# Loaded data: 1
# Access: a8c62c313c485cb18af133e47aa907e9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3091
# Access: 164b5e93b1dc3b530b4dcff4f3266b37
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3092
# Access: 72c8830e7ef13604466031f06c3e406d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3093
# Access: 501a296342c4aa19e0a37beb49faabdf
# Loaded data: 4
# Access: 5215b64c24478d335d68dc4b86189160
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3094
# Access: 23b5d13d3f7f175149f6b691afb83cf3
# Loaded data: 9
# Access: 39736addf57cc7f695f4938cfe6b2d65
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3095
# Access: 7368149371f45e92d7d7e48e4e0cf6b6
# Loaded data: 14
# Access: a99d10fc13877e9581f40c6a830d0896
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3096
# Access: 61e4f4a59406d29e72b4389b6ac0254f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3097
# Access: 87facbf4ee5ded567216bfe9a85f5e2d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3098
# Access: 4f88fc13ea6d72aa63667cc5b05f52ca
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3099
# Access: 9ac039501b8cf6186c692bd8fe3e3d80
# Loaded data: 2
# Access: 530a59f60979a720a354bdf8282d866d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3100
# Access: 59a6a2eee3730b5ecc2205eb3310f115
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3101
# Access: f292f2b8ead0221f32f4e93008f8f841
# Loaded data: 104
# Access: 92403024556e7a826f2258e896774c5d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3102
# Access: 3b4f7c9c371ca886fbcaa6ea6364414f
# Loaded data: 19
# Access: 245f85bf2c2571d422c7f4f8323f3b62
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3103
# Access: 49244681eacdaa9dafe38a3a664d4ab7
# Loaded data: 40
# Access: 04bbda888dab2afaf5032eaecd49fce5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3104
# Access: 39ca69a3b67f32b2c021fce255a400a4
# Loaded data: 42
# Access: 0fe4120ee039d5c687ccbb51d799125e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3105
# Access: 062e1b08e554ba76cd2c786c5b2f7418
# Loaded data: 24
# Access: e35086bd2f7fb19a7b29cc75b971ef77
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3106
# Access: 82087d23ce97bb533f68df45aed88d48
# Loaded data: 24
# Access: 15de8dc59802eacfd8196ef77ace33b7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3107
# Access: 7c781079dfce398028a6e19052c0d89a
# Loaded data: 19
# Access: 6ce7489ea072923bb8d0d9c43c0ab325
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3108
# Access: 88dc9beed65552b5353c8b50f19f535c
# Loaded data: 76
# Access: 9ae41fbee0391e0673c1c57195ccbf40
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3109
# Access: c12c05b62f8711538374b58c53454d95
# Loaded data: 49
# Access: 5c96eb22871f93c0dd98f0e5a4f9dd1b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3110
# Access: 7b7dc0a466cc3e0433f2071e76eb212c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3111
# Access: d027f1720d5c8c8614269f684ad3c7dd
# Loaded data: 16
# Access: ac11bfcc8ffa5f4608c5378bee9c58b9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3112
# Access: f731b37db0c46e84bbb32df079c6f39d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3113
# Access: 46a4966b2712c2c865f247efa3ebaaa4
# Loaded data: 5
# Access: 0d22ea1912223a3fbc5d7a8f5022e049
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3114
# Access: 71d485e26253162c767f1953f7d81fd2
# Loaded data: 1
# Access: 66915d4eae9d5bd1ded8b9ec6af04ba0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3115
# Access: aa36594f9b47348024a819287880f699
# Loaded data: 1
# Access: cc8c8763ca8f232b6ecc36006dd901dc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3116
# Access: 112ef050a0f6db67a3aba14cbd5206ff
# Loaded data: 11
# Access: 784e57791277c20e07cbf7fb059082dc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3117
# Access: 650d2c527c2e3bcd08ab5bfe7588d1f7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3118
# Access: 81d0f2146140bfed3ab0fdaffda81c55
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3119
# Access: c1f690ff7ee1350b5988b4f2a27288ed
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3120
# Access: f1ced8ab271607c3ceef4092a5f18ff8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3121
# Access: d8f2ad6888f7998333306bca0c49456d
# Loaded data: 200
# Access: 0a2f79010de2d89b353d3712d1a56f28
# Loaded data: 15
# Access: f6347a1b17eb9249e02d1a8d684240b7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3122
# Access: b97e5e787fce88359ba72b3e3ef0c1bf
# Loaded data: 151
# Access: 8fb638649f15a76cfa53978d765aab05
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3123
# Access: 8c789c389f8b6d40789fb4fe6313b511
# Loaded data: 111
# Access: 724cc3652258cba64c105f4550435b36
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3124
# Access: d5050acf5badbe11d93d6588b2d25057
# Loaded data: 83
# Access: 056a8f7bc58236489b1671ee3fa1c420
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3125
# Access: ddee84ea23c443f7a00802700504a7b8
# Loaded data: 78
# Access: cf5826c07658345d6549f7630b27e06c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3126
# Access: e8646777aa407ae078c35cb0a874e0f0
# Loaded data: 22
# Access: 80bb327a060eeaf658ddc10c66933128
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3127
# Access: 515c45e4bac94dd7b1f9d4b3fbebb878
# Loaded data: 62
# Access: cf1e47d903ab04c98ca86cefc84cb334
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3128
# Access: 83dd2cea753f8ef2f00c4602dd11cec4
# Loaded data: 121
# Access: 9b81cf71e63bf49ec04fa0cea1926099
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3129
# Access: 3f251516051284cf4d8d866d15d05ec8
# Loaded data: 44
# Access: af7faba622dc8ec9423b13ab634a47be
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3130
# Access: db49b2892f3d31343a1c31e7ea37aba7
# Loaded data: 57
# Access: ddcf3fb3e6bad10d39dcd1ecd0aa6742
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3131
# Access: b209ecb256149c75b275b7aed419cd07
# Loaded data: 46
# Access: e7d1c6f3f1337b7ac9eb44f7c9d7b4ad
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3132
# Access: f82955a98483cd74c270f115813e25b6
# Loaded data: 29
# Access: 78ff61b9b71d71c90ef3d9926c1b2a97
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3133
# Access: b075b6d9c3f389cfbe14249c093e5842
# Loaded data: 19
# Access: 9d39503740fea6c573fd16a78da2e87a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3134
# Access: 92f003774d1ee126d9b77c42f05ac852
# Loaded data: 59
# Access: 8af211b2adb33c9f02520ed2fccf75d0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3135
# Access: 24ef5110a8764f171bb0b555ad3f328a
# Loaded data: 24
# Access: 6dd09e5ba96e96a502c063f2183b85c3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3136
# Access: 8d97fea962e1dd5d5dfaadadb6b6eb01
# Loaded data: 58
# Access: e036d52b21acdf4ac7a6a6d3fc328b55
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3137
# Access: 5722c7d50a9b9fe9369e9ae9e0f18397
# Loaded data: 10
# Access: a0cb8fbe5fc825d3fdefb1e131cb750b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3138
# Access: 151486f20de5326002aa8d479a725d1d
# Loaded data: 21
# Access: a57bce3c3d0371b8ff251be97864b318
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3139
# Access: 53fe16c836cfcf010bdba8a2e8fbaa8d
# Loaded data: 3
# Access: ee47ffd2b7e2dda0bba136b60280fc80
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3140
# Access: 53ef087755a3ce5de03314d0601730b1
# Loaded data: 12
# Access: 79bd7a67b4c983c3cb009ca286402252
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3141
# Access: c5e7a255550a1663f5f46b3ae94a1bc9
# Loaded data: 200
# Access: 760adbf354728c225c9135c071351f17
# Loaded data: 42
# Access: 3e6bde96c570e3e5d3114ccbff033df2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3142
# Access: f22a28a6f8036a17fbe4a4fe370c44af
# Loaded data: 76
# Access: 99401934f993638c09fd224be0987fb1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3143
# Access: 167d950d8aeb03b53d7f6e23ced12d29
# Loaded data: 38
# Access: 193ec2b4aebd7c857a4917b7b142c0a4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3144
# Access: 9957fba28632eecde5f69995790255c4
# Loaded data: 32
# Access: a205bac7848919168c92193065b1c254
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3145
# Access: 5b1726e0436fb944f3bfd3afa2f36799
# Loaded data: 98
# Access: 19c7c187e04f8dac9f12fa25f6cbb129
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3146
# Access: 8afd12dd53479120c85750f91cc4f98d
# Loaded data: 92
# Access: b6a95bc9ed0972a542df4f92688d347d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3147
# Access: 709a3650034edc1dfee3b4739b310241
# Loaded data: 35
# Access: f098f6923305ce6d3a0c399b38950214
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3148
# Access: a8fac1b65a32c495dda64e272d15a4dc
# Loaded data: 28
# Access: b41c43458c600e8759739dfa26ee27ff
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3149
# Access: 265ac07ca38b92b187aab4c8974426c5
# Loaded data: 58
# Access: d06fb9b37f4ef857b48c50c35c4e59f3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3150
# Access: 02d9880f947aeb7c9db34019b2f1a1c1
# Loaded data: 82
# Access: b70003b4c9ce00d014f1f37bff26b174
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3151
# Access: 13ffa79144a14568c201740fd2baa87c
# Loaded data: 29
# Access: 6691fbb3132cce6f1120f9123f51663d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3152
# Access: 666bdf0a13653cf7c0e464aaddd7211f
# Loaded data: 52
# Access: f1ba7ab83ca3c922085cbcd9f548c224
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3153
# Access: a65daa0021bfb7dfb8cf7a0ae62d32cd
# Loaded data: 20
# Access: 7b925d9be5ae041c40dff6d5ae605636
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3154
# Access: 460d1178bf3e50960d109d2473511d70
# Loaded data: 1
# Access: 8449d4cf513c8abbf19e9d9666f5e5f1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3155
# Access: 19e36552ff557c5e9a77ee375d1a8c77
# Loaded data: 30
# Access: 4ff92cfb33703c754c3cae6b97690a91
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3156
# Access: 04ebe40d4686cca90bdbb6e2d8455faf
# Loaded data: 28
# Access: 5bc16c6dc203f3bb99903c266e610035
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3157
# Access: 731c4b86e605f4ef6a29d01ef4cee0cb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3158
# Access: acb7bd4a83c24f9e6636b1f8cb852068
# Loaded data: 2
# Access: 6d3f9a6609b40c56c02e5e3820b0971e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3159
# Access: 69fe5d09f97e5081024dd7429e7b9fe0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3160
# Access: defa7f58a876c27d25464c915adb41c0
# Loaded data: 1
# Access: 7c3fbc74fb203fe51d6eb5c683d44842
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3161
# Access: eef480fb7c217b08ab5aef6b05560b9f
# Loaded data: 88
# Access: d8050e228d3b2859652e838ff17fcf1d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3162
# Access: b8c09fd39e6d47917be9a50fd036e404
# Loaded data: 59
# Access: 71fa420201bc90b924673fca73b5ccb2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3163
# Access: a1bb6c93db877a81782ea9118819b2d0
# Loaded data: 137
# Access: 9dbaf855513f0ee7d2b75129b5c7235c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3164
# Access: 7f62f2cede347b37fdf7b315fb7e121a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3165
# Access: c843e0e7204b8f6350c4f714d3561d37
# Loaded data: 80
# Access: a1e75139849174a20c51bce120bfd49b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3166
# Access: 3cd0088a36e1ca4ccf920216e359983b
# Loaded data: 79
# Access: 7214c235660dbce55831640d93dae36c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3167
# Access: 6c616018660929b818b22f29a47e55a6
# Loaded data: 18
# Access: 4289e3183d213a9d53555db4771763d0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3168
# Access: 6a0262c259f2b2e1d9f5a3064da0069b
# Loaded data: 118
# Access: 5b3e74b5b43751f6295e22fc453bfd5a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3169
# Access: 2f7731548ba4bcbc2ffe4c4167dbcb1f
# Loaded data: 39
# Access: a0fa7f0bd293b5bed3e768a493885b25
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3170
# Access: 80e89d6096a5bd43e4ce8f14e3112da4
# Loaded data: 25
# Access: 6e86b0cda19d303feb49d68be4261b07
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3171
# Access: 9f65a06db58169cd2f063cdf277cdfd0
# Loaded data: 49
# Access: dd75efe4ba8ba44801f0280391d98c35
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3172
# Access: 74460b47c43912b98b34dd1e0249be88
# Loaded data: 13
# Access: a687f36fd878f275923ccb6a810e5f4b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3173
# Access: eaae4d6d712e727c4bfb0c127e7cd9f1
# Loaded data: 23
# Access: 8b6be3fd75a69b0d6c7136e1b621619c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3174
# Access: bc6285d2d8ea4b5355284103656042e5
# Loaded data: 72
# Access: 63e73210f387cb678bf4b332b42f356f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3175
# Access: c99adfd3478e12d999efc8830a4792d5
# Loaded data: 129
# Access: 7326ce3360bab33f1a3ee83f4e91d14c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3176
# Access: 766d6808d934892aae80d728ef7bffb1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3177
# Access: 8778c07a2208b1621785a002c9b02daa
# Loaded data: 25
# Access: 335ebeb90fb9a53665ef23a1f4765138
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3178
# Access: 3a82eca53b5586f5ef50f029968afe75
# Loaded data: 21
# Access: d4cc4e0ab4fa98eb0869de5ff6cb5865
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3179
# Access: 45f91224ac0d043c57869dec06ed0df7
# Loaded data: 8
# Access: 68741f78620d51f9afd0f1a6448cb1f7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3180
# Access: 2c8f7f9fd1fe244b4b6a5ef255944cfb
# Loaded data: 7
# Access: fb7328a19ec099afc2145928255097ea
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3181
# Access: 80b764de432871ba41c6aba89ddd15a6
# Loaded data: 172
# Access: 83f43d18d4c5f894fd9827880a0ef11e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3182
# Access: dc293990b13d3f0b0b76fc7df68826e7
# Loaded data: 200
# Access: 2ab3515bf9aded4f00773748c3ed9d50
# Loaded data: 6
# Access: 35f2d15913fb6d337bcbb672e6ab4b7e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3183
# Access: 4b35986764da41ccc3ea6da9e959061b
# Loaded data: 121
# Access: 8094f971cbd903e05f579fea867c8007
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3184
# Access: b69967128bba0a2f063164ceeda93568
# Loaded data: 109
# Access: 0d6731a679e75fed21a0a2b8e7bad04c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3185
# Access: cc58160e9927e8fe929d75e6eb4e0c82
# Loaded data: 58
# Access: 087a03a2347c078ceae7ff01ead295a3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3186
# Access: e11b41d73085748ce04da922002f2d67
# Loaded data: 96
# Access: ce6397c5e45bdb68091b41ae358ea118
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3187
# Access: c058ae31f11917a704d34593fc5066d8
# Loaded data: 51
# Access: 5305df8c925273af0baee9bf6c36c34a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3188
# Access: f6df09673e5c5d8899b4ee9c261d2fff
# Loaded data: 38
# Access: 5b977e8b562bf2ef51b6d2b17a4fdf7c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3189
# Access: c3652b2188837f47ab549599c224b17e
# Loaded data: 19
# Access: 3e6a50836c3c84e4e7083c5b9eb84ebf
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3190
# Access: 39db59d11779aa3a264d528381a43f9c
# Loaded data: 27
# Access: 996749e1ceb1e86ef61aec9808de29af
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3191
# Access: 376aef788e56913c269f4e7e366c4b5c
# Loaded data: 21
# Access: 01945942e936ab86b4a5d2c5f44e80d4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3192
# Access: 1d8c3aba4a4605fc74a1806d65fe9c3b
# Loaded data: 64
# Access: c7e69d314ba07942abcd988d5847043b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3193
# Access: 16dccca3dc08af305715b52bbd808756
# Loaded data: 26
# Access: e060675d7cc37fda9294ddb9c3e4a266
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3194
# Access: a18f6d4057eb731cbe59efdc9084a4da
# Loaded data: 39
# Access: 76f067aa77d7a90a826e1ce4428143da
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3195
# Access: 8c1acc42594a7b69a2f3a5cb5036f009
# Loaded data: 54
# Access: 04eba2f96fcaf739dd3bc6b85d232975
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3196
# Access: 37724594da0c35d050dd3c3241abc78b
# Loaded data: 28
# Access: bd93fda66e1b8f13bc1709568472357d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3197
# Access: 5683dc25d3a8d57e6700f47dd88a434d
# Loaded data: 23
# Access: 270a8aa26198ba10d175880c2e249f2e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3198
# Access: 0e149937221dfaaac84c5f81994cdd97
# Loaded data: 34
# Access: 218547ff1d8edd6741d182b04ae56e09
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3199
# Access: 23535e0ad2582ea14ddf20a0f651878c
# Loaded data: 96
# Access: c5ab0b6bc4201b1787f90f48ea6339bc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3200
# Access: 6b95cdec3191c176d2b0a760e2709097
# Loaded data: 16
# Access: 19dca563a24285a1ce8f869a6e999a29
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3201
# Access: 0be299976d9827d0c51db81f99b092e1
# Loaded data: 20
# Access: 0b07816b4e68cacfdb06371c58aa39ba
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3202
# Access: c1300b1fd6b3bbe09a5f63d4dd51f63e
# Loaded data: 4
# Access: 4c75ea4a7f928053ae0a196e6c2a6862
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3203
# Access: 990b428c6f87d3c97284d51502a0f194
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3204
# Access: d64024cbcdb876ac19ad907bc82bb43d
# Loaded data: 119
# Access: a9c8a054c10a160c0a9825951e1c92c5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3205
# Access: c566101abf05a563cc210c274e709e89
# Loaded data: 75
# Access: 53625f5b01ebc8185029c5b90ab80493
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3206
# Access: bf18ed3f3a82245675ac494fe15f846f
# Loaded data: 32
# Access: ff805feea65e5e784704c45da0c28d3d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3207
# Access: 5f2cd75808f6481ffb7c20d81190a00e
# Loaded data: 63
# Access: d75634a348d0b717f98337937b2869c3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3208
# Access: 0e0b3efc557a108994e1cfe5841be900
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3209
# Access: 167f1443448994242d95e664fb0f4400
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3210
# Access: 44d80d65c48ee0a3ed0732173807caee
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3211
# Access: 4523c1617aa786c1c4576096fbfac65c
# Loaded data: 1
# Access: a38dbd81eb768c90e02436ba8285cccb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3212
# Access: 231906968cd9b7583f5c8ed9ddb51311
# Loaded data: 32
# Access: 8a94d6aebeab266c5d3498ac22b9f6c0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3213
# Access: 19d5919e19d2c193626c2e7e31be6d48
# Loaded data: 5
# Access: 51fc268aa6608eb7b6a5f440af318c5d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3214
# Access: b3b21c56a47d67cdd74b72fcbdde9637
# Loaded data: 35
# Access: 5f6acdd2b8c82db4b3f01b7153c386a5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3215
# Access: 285dec80c2dd886cae543167c878c8ba
# Loaded data: 42
# Access: 934871a1e0dcc00ac4e355acb81b3a22
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3216
# Access: a52624f6e9cf91e4cabe900a4e4add93
# Loaded data: 121
# Access: 0c9d423a017f98be6f13644bee8d4403
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3217
# Access: ce82e42cbba976bebc80e329185a3336
# Loaded data: 82
# Access: a66e9205461fc28594b4b9eb01219edd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3218
# Access: 33de21bc2d400b02b2a271337e689f9c
# Loaded data: 54
# Access: 05a008888344f8f89a0541b08d628dab
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3219
# Access: 64b4ab336821cd910ddbea28b8e68689
# Loaded data: 25
# Access: 9cbdd5edca81df848d1c89edd835289a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3220
# Access: 9f44f42bbd04369e8a1b51eec0d4db10
# Loaded data: 80
# Access: 517db2196111d492843a20318e9111ef
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3221
# Access: 1cf9df1e2adcf118b56aa3b51c26e8d5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3222
# Access: 75d0251e7bb745c44377c1a2a43df097
# Loaded data: 27
# Access: faaaf852f36150dc72b8c4daa83d5dbf
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3223
# Access: ea330282ff4d3a5b755c0a7b00f0ccf6
# Loaded data: 43
# Access: e5f661be2f68010983cd6a7fca9855b9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3224
# Access: e0b3bbca4c61c4906488e7d38db447d1
# Loaded data: 13
# Access: 98d7cbefee920f9622bc3a0665e4fb90
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3225
# Access: 1ba7cefbef3f838a40669ff245980ac0
# Loaded data: 10
# Access: 924cd9fc8365573bf910aee7a5aa3392
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3226
# Access: 103089df9eb76728ba4e1b8c4d878cd1
# Loaded data: 33
# Access: 6b3423dbb12ee2f8cf729c7a665f2825
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3227
# Access: de98d4f31f2ee9583f7b297fd2527c24
# Loaded data: 18
# Access: 083cc4d81599894315cb316d02c94c9f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3228
# Access: 36f641f2e65f873c61b8561db2b7cdcd
# Loaded data: 26
# Access: 995a1c6f7f31bde1144211cad4998a0b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3229
# Access: 69520eff4ed3294a0776096d92920846
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3230
# Access: 257ea857590359a451fae7c99864c35a
# Loaded data: 3
# Access: 58ad9142312ddb4d4ece14e266e52f94
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3231
# Access: c238caf895bd83ae791cb52f5aa57c1d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3232
# Access: 2435f250e5730e59e1cc90828cc0a93c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3233
# Access: 9fd9ce4bbc460d1e443c907c955f1307
# Loaded data: 10
# Access: 7733c5825671b93643f966920c2892cd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3234
# Access: 531d5e9de6b6fd44af96159afa1967fd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3235
# Access: 326862cde094358973edaec1f12c7688
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3236
# Access: 06d07142d53e26101d31b278e5188468
# Loaded data: 1
# Access: 94ff6de9f2761fd3f95c485e15ddb063
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3237
# Access: fac7dc25322c7c9fb3db4d6fa9ea8559
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3238
# Access: 33feb2cfa61a8e68abdeac012449dfc8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3239
# Access: 7e15a53f8683240d73617e2bf7faab06
# Loaded data: 1
# Access: d82fe34b5101ccc15fadf568a7a1508e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3240
# Access: a018d8922a58fadd1e01f15dd027dce1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3241
# Access: 276260a51754f44ecfeed41c8b7be29a
# Loaded data: 4
# Access: 1bd3746ce5ef355837dc5ed58e2202a5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3242
# Access: 07e4f75f70dc8ddb525109836fadee80
# Loaded data: 1
# Access: fd2310c561d4e87b2c98ccb17d67c629
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3243
# Access: 72a7656c464ea5bea4aa9a076b2f455d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3244
# Access: 98863b724ebb0c8234a64696c8090dd3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3245
# Access: 854406ab0a130f737fd3b6fb4c782801
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3246
# Access: d6ac35f92052495fe891a3c8d6f463cd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3247
# Access: 44a3146fbe84c978af0edd5b20e04325
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3248
# Access: 503df375b2b16cd897a3bed99b1d35db
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3249
# Access: eddc408a47b7f56fa25258dca816a33b
# Loaded data: 2
# Access: 09e972d0131e3ae7f66b9c995df620e6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3250
# Access: a05b515a4845ae88b19a9d94ffc76528
# Loaded data: 9
# Access: b64adfd6385d1a39f92e575c376507ab
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3251
# Access: 5b53f209c528c3dec4d014c5058e60fc
# Loaded data: 1
# Access: cc251edc3b79dae0e4ae4e52e9826809
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3252
# Access: 8c942e2d721cf7cb4156d6b42c8e6599
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3253
# Access: fde9336fc01b26bfeaf581d69643e678
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3254
# Access: 8b87c33315786b8879d6ce164b70e908
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3255
# Access: 41c0693f6efcc45ed83df01a87da8d8a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3256
# Access: 8abb85a2f2700ad9f6d7cd598a86353b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3257
# Access: 5d5fc20c4628595413dcf0e016042617
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3258
# Access: 30c705043c413b6828a924b52e0bdcfc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3259
# Access: 94fb8d29d35965291c74db9ee94d9f85
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3260
# Access: 18028eab0624d5899f9da334c5005cf5
# Loaded data: 2
# Access: 4da1ab3dd1a04e4dac369a7ee3ef7f9e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3261
# Access: ba8f9950404faf4b8a8858f9d918768c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3262
# Access: efe9795c87b6263198cabdb7be29037b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3263
# Access: da09680d6cd1f828389569cf4bb5d38e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3264
# Access: 9eefffe87d9ca244c5ed2b382260f9ba
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3265
# Access: 1bee9730835ff5bd4c9c37e1bb4d6032
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3266
# Access: ffa910509c4d7042d1274363bbfaacd2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3267
# Access: 9433d9df4fe63a34bccf4dd1e2d5cd99
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3268
# Access: af6af5736289813a6a4a42bbb8e01f3b
# Loaded data: 1
# Access: 8f33b67b7078c4cf514c650034b3d260
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3269
# Access: caead4be91eccc9fb7836e079f9623ef
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3270
# Access: 90e781fa275b943a37ea7233b65ee5f8
# Loaded data: 2
# Access: 70ed197541aece8a4737e65ace1a1a9d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3271
# Access: c0251ff231bee5f65d0fa7a39e87463a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3272
# Access: 5a69a77dd10de8a628e349ab378feaec
# Loaded data: 2
# Access: 70a7ac35f9e32e57c04aa878679c07b9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3273
# Access: 0cfe36a4c25cb88c64060571199f457a
# Loaded data: 1
# Access: c07b8330bef8a80dc96ec688af538964
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3274
# Access: 979179ce2021d3cc2e090eda34f279b8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3275
# Access: 069db4f0c38b4ee4c71d4158b544a672
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3276
# Access: 24c61fdca26a7e4207f457e83f601c68
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3277
# Access: ff5334d67de6864c8f62a7157fe83791
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3278
# Access: 54cc6f2e16374c6512898121d94130b5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3279
# Access: 36ca8e4f5e7605bd6546cab9ac85dc95
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3280
# Access: a5a792111663523decfced46b40d0738
# Loaded data: 41
# Access: 56e8578bb4b6c057a58d7dfe0a3899fa
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3281
# Access: ca6854a036c0adf8c9b8dadf21232bbb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3282
# Access: 3a3dd586e22b6a0dccd31d5f355a0e8e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3283
# Access: 2fc9279436010622f1bd136316854145
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api1
# Access: 8f9c5767290af7a88ace28f345b80acc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3284
# Access: bb1f22f512cf264545f65190b88ba6c3
# Loaded data: 2
# Access: 397a7f7ee40786c12077866398f50afb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3285
# Access: 4ad7ccd25a6c179f3420edd6c40eb450
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3286
# Access: 8a3b2df100a2ab812892b7afc092939b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3287
# Access: 8e6bed0201a87dd0c8e7b2f98cd784a2
# Loaded data: 2
# Access: a8dab02754fbf3271199a5aacc480e07
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3288
# Access: d9fdfb4323897ac4b35af27c2317362c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3289
# Access: 0f20e9526b8ae868c5392f232090f4e9
# Loaded data: 1
# Access: 78788af5d6fb9a461b9ec1f4531c7061
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3290
# Access: 2b22e16fa1b16ea6631c621d00f60fb3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3291
# Access: 2b8a6c94188495e9583eeb3bcb36461e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3292
# Access: 9cec730055ca7adb7ce8d6cbf3c3681c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3293
# Access: 5a969e726ef14d3e2c322cc8257ff281
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3294
# Access: 58cb8b49dc0efa5f4884ca0064c10ed7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3295
# Access: 04117230c103e2adab6e98d6b85004d8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3296
# Access: 874b6a98420ec731e79bc2ac5cbd4343
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3297
# Access: 459f84f55b377c20c8fc28bb06cbe845
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3298
# Access: bfe75c4e5522a854ff763a4a52a549ab
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3299
# Access: 68ec3729197f3a40486712d49c3e546c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3300
# Access: 6ec5a725d1fa504240aa10eaa64b8014
# Loaded data: 12
# Access: 77fef2281de641e550da3d53061bca81
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3301
# Access: e86cbcd751e5db7121dbc0ec2144de25
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3302
# Access: b477d33366e8705c7cabf42560d19e89
# Loaded data: 1
# Access: 208ae1e5a8b2665c953802d4a3fc2bde
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3303
# Access: 23a4a7cf4352792022283def2afc83ca
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3304
# Access: 078540cf1e95b7f33cc42175519e745c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3305
# Access: 1dff7dab0f88f5f2c7e5cabcbe3daa98
# Loaded data: 20
# Access: 17a00be8f239eeb168551bf85c5a5695
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3306
# Access: 6aeb5aabed021f61d340dc9603dc6ab6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3307
# Access: 1db7f29ab3cf783b60ebca0431692c8b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3308
# Access: c013798883e65eeda8bb558dbbe29fcf
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3309
# Access: 1b8a2cb553e429102303c40444340208
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3310
# Access: b974613e3c8d169360cc6c5349a44e54
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3311
# Access: e98041bc314a25bc0fdc167169e42f9c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3312
# Access: 94ad71ed62a20f2634cecd56c1a64058
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3313
# Access: 30d727e5b086a0605db005bb57ffa32a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3314
# Access: 3775b2930978ba98e4a5946cc1d61fa0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3315
# Access: 0da56b7a29742fa3acf9b3d267715c5c
# Loaded data: 4
# Access: 77772a06505fbaaeafcad4d7932a8dd7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3316
# Access: a8f70a666540674e9c163dc6417a768f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3317
# Access: e892a1f14cb1fdb81f05779544fb6133
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3318
# Access: 2f6c08c0f2803fcc5704b94c6dcab345
# Loaded data: 1
# Access: 502d285daabb81c06ad97fe26489249d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3319
# Access: e133544ff2f8206d0d62c01bb2c0bd93
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3320
# Access: 0877a4030dfa53f47016e3a2764a13a2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3321
# Access: 5b3b1e106c5f76ee264a186e27fc8360
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3322
# Access: f4bfcb8ca78c11b937f1d22b2c60f76a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3323
# Access: 9f539f0f662c5d3a42f00f615f3e0151
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3324
# Access: 991f7b3b959f1f0ec9df472941c6d850
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3325
# Access: fab42b7d665e0641bb953d4002e7d604
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3326
# ...
# Access: 70ac73bf93c93f54538659de96918115
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8422
# Access: 4ebe2e53d620db0f2a950c7d94384d1a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8423
# Access: d8f265a6bcaea682cab1c3350a3da4ea
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8424
# Access: 4bc5fd939f83c5cb08e6c5e6784f18c2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8425
# Access: 380d13591cbf12262c19dd399c30c195
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8426
# Access: 597e35c7b1829faedfd85a148c9f1d73
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8427
# Access: 8129d6d51d7bcf194a60033a1b5bd48f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8428
# Access: 128279a16bde7d3500350ac21624bddd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8429
# Access: 51e0cc5d2a1c3c0aff2809cc67b08ac7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8430
# Access: 0621da6e103c9ef21c38a0c470165a95
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8431
# Access: e7a9ba72fa25b6ac06518efcca450c35
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8432
# Access: a27c166f35b4cf0de2ef814b6d2963c6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8433
# Access: 6cacf6e6d136417318f88ab2980e8036
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8434
# Access: 5ad8b6d240dd92082f8544a3167e8ed6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8435
# Access: 3b498c6e06f280a478ad941228e1e5fa
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8436
# Access: 0bdb562e55051e8a0fa130993d4ec821
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8437
# Access: b9486791494163828c61e392faeebfec
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8438
# Access: 3a6c6068535448c5698f3cbf68537332
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8439
# Access: cd74d99bc1b01da1858323e29942df7b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8440
# Access: 1eec3fb5dda5f84e03e311451f4add38
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8441
# Access: 68be11fccfe89c749f6321a84d83a9e9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8442
# Access: fe4f327fc843f7e6f1ccdade49ca9b45
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8443
# Access: 9c61e6794fc8134baef00a7289c8cb44
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8444
# Access: 215293d298b72798927cccf2383d41e0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8445
# Access: 8363549339c9b50ec90cceb0cc354ccb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8446
# Access: dbc6e9369a897165a78553ed02283afc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8447
# Access: 9f3f053c1438f0965c9ef701f0586991
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8448
# Access: d259e3e40f82c79097ab579ef5dd83ac
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8449
# Access: 265d4955f0fae6d72477ecd319186155
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8450
# Access: 05b96ed95000fb8506cb40b2ccb5fe7c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8451
# Access: c1210a9bd2b8b5ca5644e5a31a519d5d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8452
# Access: 7d4cbecf9caf8dccc8da5099ad63b30b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8453
# Access: de6651a0f745f30b7245281f6064c986
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8454
# Access: 583c9b774d6debb78de88230698ea92e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8455
# Access: ec149963d71ad9a252594bd56ddaad6e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8456
# Access: f64d5126971eb74d7aa63ac85ad8c4fa
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8457
# Access: eab5fa0a89cb6cbdebce0c382fd944e3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8458
# Access: 79653d8bdfb03102a0a0fb9800d97ed1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8459
# Access: 0d231fcb6a0033ddf325fbca7c745a3f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8460
# Access: 1d1086b641e261c9467ded8be9ded03a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8461
# Access: e1c744a7f579f424f72c839ecb697cda
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8462
# Access: b99a24c8753e4c61ca97ef8bf8398e65
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8463
# Access: 62b9531530d4b6fd13465e6eb24c7b92
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8464
# Access: 538d85922ac125e8044e1ff42af0ade2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8465
# Access: 21e5624a1b51d7f4543b75df3003b1fa
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8466
# Access: 00cea0f20473426d9e2f96b0a11ff16a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8467
# Access: 992d08272f5674df2e0b51df37dc6224
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8468
# Access: 21f3e1d80e4ba670977dc5aa19a57244
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8469
# Access: 1786c3c54a43c4533aeb19c4b824fe20
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8470
# Access: 9f21ff6f714add40218e681a8a24472b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8471
# Access: b2f4bb832a9e408f3fd7570d0517598c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8472
# Access: 64f763396262b463f30d62b67f5cc9bc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8473
# Access: 331ed7a5f9d365f387000751e2a8d56d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8474
# Access: 2aeb5ef0d28cb9c9391bd22733fca4a3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8475
# Access: 522f8e834ec020a81fb13cb4e6ca1bc0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8476
# Access: ffa7452c96559ac7ac7932661afcf8d4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8477
# Access: 22f1972a64dd5247f72ba9c74540aa4f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8478
# Access: 0d3eff4187ddccc1afa5de45b02fd5e6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8479
# Access: f92e63d76dd91b16b1a83a1f3a9862b5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8480
# Access: 85bf8560a8009ac282eda70ad69bcd06
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8481
# Access: 727e0ea0c58ee81ceb3d89c485278819
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8482
# Access: 9c68af861da3ed1784faff621b8b7446
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8483
# Access: ceaa77c388bf17b32647928513b4040f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8484
# Access: a2421898c3430980a8479612c71945e6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8485
# Access: 59bd91e9b937bc9c631e5ba643a97e9a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8486
# Access: 779c9bd22b1a3a5e6f605415e0e50fde
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8487
# Access: bde43f76de6fd6031c2202904bcee390
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8488
# Access: f935f57bfe8db66947e4ed5ab13664b9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8489
# Access: 0a47afdcee9a08367f6469dc04e9d218
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8490
# Access: 400184434779ce3d602fc4acdce17bb0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8491
# Access: 26ea37084caed40e2914c6c857cfff8e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8492
# Access: c57013a2c10b016376d17d95209e37fc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8493
# Access: c6ec333c7f9cee832f19bc87ea0308c0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8494
# Access: f5e93c8cd5e28094e9032dccd37f7dc9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8495
# Access: a9e9e91269301d1fcefbf153508db2ae
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8496
# Access: 3b6fd39be49240768dc5bfe8e98d9243
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8497
# Access: 9e4b872c538503fd917d27a774a78b25
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8498
# Access: a2a9ab606e504a47e096b8fe7324f00f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8499
# Access: 2fca9a634706d3322d17df2940546745
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8500
# Access: 31a4c3e29d71f9ccc06a3ba8d80fb838
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8501
# Access: 498e15c99c7f27a85c39a47005007bd6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8502
# Access: c8978562a43592d40570db8b36d1ae75
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8503
# Access: afe9d27c1f6537e5ef451f60ae532b6b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8504
# Access: 9d1366f0ecf90d0f98cb12bd04703255
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8505
# Access: 896cbccca1a5e324df59889ff2a6807c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8506
# Access: 6dc470dd0b78c74b2fe4d4c6701099e3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8507
# Access: fec69b0123642321524af94db3e4599e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8508
# Access: 301f1cf76cd8a3fc9ae04a1546ba2adc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8509
# Access: 704e9abc9cfeb9f20a75c338253f5f7a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8510
# Access: 71d543c6f76694997cd83bd7f7d7912f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8511
# Access: 815cdefc2e4de364f5ed92e2f3ba7c76
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8512
# Access: 3440d01d9bf0b96208f83f1f1ac4015f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8513
# Access: 4475c63793c6e53b14a85b896fc755c2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8514
# Access: 4d299e278ffbdd15b6d5eb6701f2174a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8515
# Access: 9d743c20d158c8314c781cd2af9c0432
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8516
# Access: 400bf8706e78409701a1e2f71b73db75
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8517
# Access: f6464e66337d322c1c0cffdc26bff8a0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8518
# Access: 60c8251e278799208fa52a45fde63a31
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8519
# Access: bdc08f15605b6257dbe957f1cb380517
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8520
# Access: fb8e82e4a7bc1c4ed438cb7e5a3db89a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8521
# Access: 1f0b57571e63ce776754930a920d2340
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8522
# Access: 86220e58846fb7996bd9ee4a2b2c6d08
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8523
# Access: 53df32e778300ebd5d483159a4530fd4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8524
# Access: 569f013a24fbf79794f1e6fdac8de778
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8525
# Access: 0200806f2dbf08e428df4b063dc02daf
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8526
# Access: 7836db06a236a8c835d8bd6126ea50d9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8527
# Access: 14c027cc97f3ba76239b484ab3f84865
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8528
# Access: c60c5f7b79f4daa4da803f043950398e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8529
# Access: 8117b1e52ea3893b6170a21105053a8f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8530
# Access: bd6e47ed0fda110323d0a443fe0098cc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8531
# Access: 1d0e04d64c973fa661f98ca9a942d820
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8532
# Access: 202ca5a07a613f4b916deb62e3084b2f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8533
# Access: cde502a88e65c84120973480b6d5d4b4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8534
# Access: a4e1ca55e326358f519a71565e6ad09d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8535
# Access: 0da1487730825e3ead37310660920672
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8536
# Access: 9fdcb0a5e36710aded92415ab4265b3e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8537
# Access: 6091160edf1e01588c823fc7116c8ef0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8538
# Access: 6b2bf1017d46d4c4566a5e87a73fbd51
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8539
# Access: e3e8363881e75753bb07d903ba09fa26
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8540
# Access: d38b04c50eb37b751d82661d2e65111a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8541
# Access: a41caa43e7bf8d0784cc3d88599e787d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8542
# Access: c791263e9babc71d599affda24f12478
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8543
# Access: 61716d9b4819102099a15f8b6e27d997
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8544
# Access: 398c58c61282e6792f99b044e1f10ea4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8545
# Access: 3ba737829a10bd556bba75e6afe1c0e7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8546
# Access: 0e4ee9c3a7b41ecdab3391a296a7e77d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8547
# Access: bc4a2b24a1adc908f8de689c1b5182ed
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8548
# Access: 3ffcc6eb22796963a300e0789e9ed088
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8549
# Access: 6a9ac2b4a23a00a2a1c3c3a3b7cce486
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8550
# Access: 82b8252524c83a739a3bd0f0cb5c4554
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8551
# Access: deb077f36fb44e124346b15ef06153a9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8552
# Access: 9db07487a678cd662a9e4a0a15363fc4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8553
# Access: 5e252d12859cfbf9c610131958c8b2fe
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8554
# Access: 7737f2bd7b63113400c7db826200303f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8555
# Access: b0429d7cd00968ac0b23f4d6fab6470b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8556
# Access: a7414e0696b19236891d83ef48f0fd79
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8557
# Access: 7bfbcc1c7f5291f30694b0014476001e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8558
# Access: c46cb729a4bac7754ed76e71b33bfbbc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8559
# Access: bf899f4709586e7d2743f826da79adab
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8560
# Access: edf1f511aeb896fd892dfbdcf79d0aad
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8561
# Access: 24a1318961d4876b925e69a67922a2ea
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8562
# Access: d49316efec8d7a902ddf76c4ad2a0fdb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8563
# Access: c2051b96ead3ca7fd8eb423212326c6d
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api9
# Access: 3dee75e26eec3a15174e8fda989fc602
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api10
# Access: f8a006876810b0c0fa8c2ede16206554
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api11
# Exceed the download permit

# %% [markdown]
# #### Visualise Property Schema ``(do not run this)``

# %%
"""
[
  {
    "type": "Project",
    "listings": [
      {
        "listingType": "NewHomes",
        "id": 2017835505,
        "projectId": 5437,
        "advertiser": {
          "type": "Agency",
          "id": 32584,
          "name": "Roche Group",
          "logoUrl": "https://images.domain.com.au/img/Agencys/32584/logo_32584.jpeg",
          "preferredColourHex": "#1d2c44",
          "bannerUrl": "https://images.domain.com.au/img/Agencys/32584/banner_32584.jpeg",
          "contacts": [
            {
              "name": "Cameron Grove Sales",
              "photoUrl": "https://images.domain.com.au/img/32584/contact_1637430.png?mod=220821-125111"
            }
          ]
        },
        "priceDetails": {
          "displayPrice": "RESERVED"
        },
        "media": [
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_1_1_220726_010938-w2880-h2160"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_2_1_220725_035031-w2048-h1536"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_3_1_220725_035031-w1536-h2048"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_4_1_220725_035031-w1536-h2048"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_5_1_220725_035031-w2048-h1536"
          }
        ],
        "propertyDetails": {
          "state": "NSW",
          "features": [
            "AirConditioning",
            "Ensuite",
            "Gas",
            "Bath",
            "Dishwasher",
            "Study",
            "RainwaterStorageTank"
          ],
          "propertyType": "House",
          "allPropertyTypes": [
            "House"
          ],
          "bathrooms": 2,
          "bedrooms": 4,
          "carspaces": 2,
          "unitNumber": "",
          "streetNumber": "37",
          "street": "Estelville Circuit",
          "area": "Lake Macquarie West",
          "region": "Hunter Region",
          "suburb": "CAMERON PARK",
          "postcode": "2285",
          "displayableAddress": "37 Estelville Circuit, Cameron Park",
          "latitude": -32.91141,
          "longitude": 151.59761,
          "landArea": 586,
          "buildingArea": 265,
          "isRural": false,
          "isNew": true,
          "tags": [
            "newdevelopment"
          ]
        },
        "headline": "Cameron Park - Home under construction, amazing views!",
        "summaryDescription": "<b></b><br />Don't miss out on this one of a kind opportunity, this home is currently under construction, you will  see the interior of the home this weekend, Landscaping and Fencing are about to commence. Hope to see you here this weekend.\r\n\r\nTucked a...",
        "hasFloorplan": true,
        "hasVideo": false,
        "labels": [
          "Under offer",
          "Updated",
          "New homes"
        ],
        "dateListed": "2022-05-28T20:15:55",
        "inspectionSchedule": {
          "byAppointment": true,
          "recurring": false,
          "times": []
        },
        "listingSlug": "37-estelville-circuit-cameron-park-nsw-2285-2017835505"
      }
    ],
    "project": {
      "state": "NSW",
      "id": 5437,
      "name": "Cameron Grove Estate",
      "bannerUrl": "https://images.domain.com.au/img/Agencys/devproject/banner_5437_220726_011050",
      "preferredColorHex": "#419a45",
      "logoUrl": "https://images.domain.com.au/img/Agencys/devproject/logo_5437_220726_011050",
      "labels": [
        "New"
      ],
      "displayableAddress": "28 28 BREAKWELL ROAD, CAMERON PARK, NSW 2285",
      "suburb": "CAMERON PARK",
      "features": [
        ""
      ],
      "media": [
        {
          "category": "Image",
          "url": "https://bucket-api.domain.com.au/v1/bucket/image/af4a92fb-1686-479d-a6f7-13e7fc1425b8-w1500-h966"
        }
      ],
      "projectSlug": "project/5437/cameron-grove-estate-cameron-park-nsw"
    }
  }
]

"""
# Out:
# '\n[\n  {\n    "type": "Project",\n    "listings": [\n      {\n        "listingType": "NewHomes",\n        "id": 2017835505,\n        "projectId": 5437,\n        "advertiser": {\n          "type": "Agency",\n          "id": 32584,\n          "name": "Roche Group",\n          "logoUrl": "https://images.domain.com.au/img/Agencys/32584/logo_32584.jpeg",\n          "preferredColourHex": "#1d2c44",\n          "bannerUrl": "https://images.domain.com.au/img/Agencys/32584/banner_32584.jpeg",\n          "contacts": [\n            {\n              "name": "Cameron Grove Sales",\n              "photoUrl": "https://images.domain.com.au/img/32584/contact_1637430.png?mod=220821-125111"\n            }\n          ]\n        },\n        "priceDetails": {\n          "displayPrice": "RESERVED"\n        },\n        "media": [\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_1_1_220726_010938-w2880-h2160"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_2_1_220725_035031-w2048-h1536"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_3_1_220725_035031-w1536-h2048"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_4_1_220725_035031-w1536-h2048"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_5_1_220725_035031-w2048-h1536"\n          }\n        ],\n        "propertyDetails": {\n          "state": "NSW",\n          "features": [\n            "AirConditioning",\n            "Ensuite",\n            "Gas",\n            "Bath",\n            "Dishwasher",\n            "Study",\n            "RainwaterStorageTank"\n          ],\n          "propertyType": "House",\n          "allPropertyTypes": [\n            "House"\n          ],\n          "bathrooms": 2,\n          "bedrooms": 4,\n          "carspaces": 2,\n          "unitNumber": "",\n          "streetNumber": "37",\n          "street": "Estelville Circuit",\n          "area": "Lake Macquarie West",\n          "region": "Hunter Region",\n          "suburb": "CAMERON PARK",\n          "postcode": "2285",\n          "displayableAddress": "37 Estelville Circuit, Cameron Park",\n          "latitude": -32.91141,\n          "longitude": 151.59761,\n          "landArea": 586,\n          "buildingArea": 265,\n          "isRural": false,\n          "isNew": true,\n          "tags": [\n            "newdevelopment"\n          ]\n        },\n        "headline": "Cameron Park - Home under construction, amazing views!",\n        "summaryDescription": "<b></b><br />Don\'t miss out on this one of a kind opportunity, this home is currently under construction, you will  see the interior of the home this weekend, Landscaping and Fencing are about to commence. Hope to see you here this weekend.\r\n\r\nTucked a...",\n        "hasFloorplan": true,\n        "hasVideo": false,\n        "labels": [\n          "Under offer",\n          "Updated",\n          "New homes"\n        ],\n        "dateListed": "2022-05-28T20:15:55",\n        "inspectionSchedule": {\n          "byAppointment": true,\n          "recurring": false,\n          "times": []\n        },\n        "listingSlug": "37-estelville-circuit-cameron-park-nsw-2285-2017835505"\n      }\n    ],\n    "project": {\n      "state": "NSW",\n      "id": 5437,\n      "name": "Cameron Grove Estate",\n      "bannerUrl": "https://images.domain.com.au/img/Agencys/devproject/banner_5437_220726_011050",\n      "preferredColorHex": "#419a45",\n      "logoUrl": "https://images.domain.com.au/img/Agencys/devproject/logo_5437_220726_011050",\n      "labels": [\n        "New"\n      ],\n      "displayableAddress": "28 28 BREAKWELL ROAD, CAMERON PARK, ...
