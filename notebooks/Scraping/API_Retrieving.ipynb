# %%
import requests
import json
from bs4 import BeautifulSoup
from csv import writer

# Use client credentials
# Additional
client_id1 = 'client_660b4d0cceb4cf9f989acef154caf4ab'
client_secret1 = 'secret_bd749d4e48d050deb1d8873b061456f2'
# jongho api
client_id2 = 'client_e470bd58b93f29f12bf0a584c8ee6b08'
client_secret2 = 'secret_e721ef5d2089efd16ceef38e10d95d1b'
client_id3 = 'client_aba6e5dec04c5d1a2335705504e56729' 
client_secret3 = 'secret_cabc2a80fd7cd09a918f86b5672962cb'
client_id4 = 'client_b74a3bc9756e77bdcd0a2ffb2e430edb'
client_secret4 = 'secret_666cf9388a8462e398aadf7d4d105879'
# philip api
client_id5 = 'client_4253061ce6d6a7a86cc877d9c9dfa776'
client_secret5 = 'secret_2e3838d9fe9ced976a3fa974689a9d9d'
client_id6 = 'client_a89a8ef1b3cf662607f452a01c8f27b1'
client_secret6 = 'secret_a4f96d2c0790ad05fe041eed2c314dfa'
client_id7 = 'client_80e72e5511155fdde9a18e467f829c15'
client_secret7 = 'secret_4e3af2f4c36e901b8f7c0afbda475f32'
# grace api
client_id8 = 'client_406f326e62a400f902b3f719c8593ab2'
client_secret8 = 'secret_6c7dd26c2428d6074e4a6a6b1bfcced3'
# Nuo api
client_id9 = 'client_19c60ac8e6ddcb881b2ea29962cb34d7'
client_secret9 = 'secret_e4bc232ca320af78499287cf3f5477b8'
client_id10 = 'client_80c69b6fa0e2fb021a23daafa80cde7a'
client_secret10 = 'secret_cb18898e2c6674ff84f78c9918a87429'
client_id11 = 'client_e2048fb1cdea5b654551ebe33b30d471'
client_secret11 = 'secret_ffe3749686b362eee3255848bac52932'

client = {}
client['client_id'] = [client_id1, client_id2, client_id3, client_id4, client_id5, client_id6, client_id7, client_id8, client_id9, client_id10, client_id11]
client['client_secret'] = [client_secret1, client_secret2, client_secret3, client_secret4, client_secret5, client_secret6, client_secret7, client_secret8, client_secret9, client_secret10, client_secret11]

def retrive_properties(client_id, client_secret, pageNumber, postCode="", state="VIC", pageSize=200, filename="../../data/raw/API_Raw_PropertiesInfo.csv"):
  scopes = ['api_listings_read']
  auth_url = 'https://auth.domain.com.au/v1/connect/token'
  url_endpoint = 'https://api.domain.com.au/v1/listings/residential/_search'

  # mock client post request in exchange of a one-time access token
  response = requests.post(auth_url, data = {
                          'client_id':client_id,
                          'client_secret':client_secret,
                          'grant_type':'client_credentials',
                          'scope':scopes,
                          'Content-Type':'text/json'
                          })
  json_res = response.json()
  # take the access token each time (can call a page of size 200)
  access_token=json_res['access_token']
  print("Access:", access_token)
  # authentication for current access token
  auth = {'Authorization':'Bearer ' + access_token}
  url = url_endpoint

  # with the current access token, specify the post search query 
  post_fields = {
        "listingType":"Rent", # only interested in Rents
        "pageSize": pageSize, 
        "pageNumber": pageNumber, # 200 per page
        "propertyTypes":"",
        "minBedrooms":1,
        "minBathrooms":1,
        # "maxPrice": 400,
        "sort": {
            "sortKey": "Default"
        },

        "locations":[
          {
            "state": state,
            "region":"",
            "area":"",
            "suburb":"",
            "postCode": postCode, # will iterate by postcodes
            "includeSurroundingSuburbs":False
          }
        ]
  }

  # get the response of a post search, could either be 200 (success) or some errors
  respond = requests.post(url,headers=auth,json=post_fields)
  content = json.loads(respond.text)
  print("Loaded data: " + str(len(content)))
  # quota error or no relevant data can be found on this page, e.g.
  # {'errors': {'searchParameters.Page': ['Cannot page beyond 1000 records.']},
  # 'message': 'The request is invalid.'}
  if ("errors" in content or len(content) == 0):                                              
    print("Limit notice")
    print(content)
    return 1
  # errors occur when the query type is not from PropertyListing
  elif ("type" in content and content["type"] != "PropertyListing"):
    print("Error accurs (No data)")
    print(content)
    return 2

  # Get request for each property ID and extract attributes, each 'i' is 
  # a single property schema in json format
  for i in content:
      #get details
      id = i['listing']['id']
      listing_type = i['listing']['listingType']
      r = i['listing']['propertyDetails']
      street_address=r['displayableAddress']
      suburb=r['suburb']
      postcode=r['postcode']
      area=r['area']
      if('buildingArea' in r and 'landArea' in r):
        building_area = r['buildingArea']
        land_area = r['landArea']
      else:
        building_area = 0
        land_area = 0
      # latitude and longitude might not be available in some instances
      if ('latitude' in r and 'longitude' in r):
        latitude = r['latitude']
        longitude = r['longitude']
      else:
        latitude = None
        longitude = None
      
      property_type=r['propertyType']
      bathrooms=r['bathrooms']
      bedrooms=r['bedrooms']

      if(str(i).find('carspaces'))>0:
          carspaces=i['listing']['propertyDetails']['carspaces']
      else:
          carspaces=0

      price=i['listing']['priceDetails']['displayPrice'] #[1:4]

      if(i['listing']['dateListed']):
          time = i['listing']['dateListed']
      else:
          time = 0

      info = [id, time, listing_type, price, property_type, area, building_area, land_area, 
      bedrooms, bathrooms, carspaces, street_address, suburb, postcode, latitude, longitude]

      # write the relevant info of current property one row at a time
      with open(filename, 'a', newline='') as g:
          thewriter = writer(g)
          thewriter.writerow(info)

  return 0

# retrive_properties(client_id, client_secret, 1)

# %% [markdown]
# ### Inialise the csv output file with headers

# %%
# Write column headers
headers = ['property_id', 'listing_type', 'price', 'time_listed', 'property_type', 'area', 'building_area', 'land_area', 
'bedrooms', 'bathrooms', 'carspaces', 'street_address', 'suburb', 'postcode', 'latitude', 'longitude']
output_csv = open('../../data/raw/API_Raw_PropertiesInfo.csv', 'w')
# create the csv writer object
csv_writer = writer(output_csv)
# first write the headers
csv_writer.writerow(headers)

output_csv.close()

# %% [markdown]
# ### Rrtrive rental data

# %%
# Retrive rental data by postcode
# postcode 3000~4000
count = 0
limit = len(client['client_id'])

for i in range(3678, 4000): # excuted upto (3278, 3677), start from 3678
    # Check available api list
    if count >= limit:
        print("Exceed the download permit")
        break

    # Retrive data
    print("Retriving data from postcode: " + str(i))

    # read data by page (1~5)
    p = 1
    while p < 6:
        if count >= limit:
            break

        client_id = client['client_id'][count]
        client_secret = client['client_secret'][count]

        num = retrive_properties(client_id, client_secret, p, str(i))
        if num == 1:
            # no data found
            break
        elif num == 2:
            # change the new api
            count += 1
            print("using api" + str(count))
        else:
            # continue to the next page
            p += 1

# postcode 8000~9000
for i in range(8000, 9000):
    if count >= limit:
        print("Exceed the download permit")
        break

    print("Retriving data from postcode: " + str(i))

    p = 1
    while p < 6:
        if count >= limit:
            break
        
        client_id = client['client_id'][count]
        client_secret = client['client_secret'][count]

        num = retrive_properties(client_id, client_secret, p, str(i))
        if num == 1:
            break
        elif num == 2:
            count += 1
            print("using api" + str(count))
        else:
            p += 1
# Out:
# Retriving data from postcode: 3678
# Access: 0f27d4e943929ebdabab07533644c297
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api1
# Access: a241197d4a780c96808b2855409341dd
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api2
# Access: d4d6a92e867d6c6861b77a13c0b5f911
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/access', 'title': 'Not Authorized', 'detail': 'Project [Sandbox] restricted from access to this environment [Primary].'}
# using api3
# Access: 6f30d7e4b57d6b56e3dbde794147945a
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/access', 'title': 'Not Authorized', 'detail': 'Project [Sandbox] restricted from access to this environment [Primary].'}
# using api4
# Access: 28cf2d03081da2a8a5f5aeaad5354fa0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3679
# Access: dc5f2c07f188963337314b83344ddacc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3680
# Access: b6942cf7b82e0485deb0daab6d339ae2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3681
# Access: ac7708d99b549a35eae697d988208334
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3682
# Access: 458f0354387badfadc98ca379bd332d9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3683
# Access: 1810c5b518fad45093c3632d3cbf1116
# Loaded data: 1
# Access: 6ac44a68956243d5aa21c94fbf1c72d8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3684
# Access: 0f0157d3086c85d62b447feb4d0a5a68
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3685
# Access: bfa30a29af48d6a704ae78b16df2a518
# Loaded data: 5
# Access: 99928ad8edd295aa438faa44d2d4627f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3686
# Access: 1d315d276df77f68cbbc688abcc107ae
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3687
# Access: 39a7c871f6ff23566545a93208af5d8f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3688
# Access: 0454c46d496b5606601f2b779b40e074
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3689
# Access: d5c068bb1dec8dbfd3b270f4d1e92427
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3690
# Access: adc7f13fb58168d4e53931c57046cb91
# Loaded data: 37
# Access: 700b6b4756c9d66d5e1cfb622473b521
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3691
# Access: 6d0a0283460458267bc44deb6352da84
# Loaded data: 6
# Access: 485bd36ec8b5417ef5f7f14180930a73
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3692
# Access: 947db9f6138496d19a1947751a53c961
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3693
# Access: 96d6f2f65e80fa10c5539c49f6b36b3a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3694
# Access: 6124081b5304256362b52a121281125e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3695
# Access: ece14dd2fc3a78e05d0c58795913b798
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3696
# Access: 4f3a0ce7365ce0a2ea77c0615a59dff3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3697
# Access: d47332c464a5568970386cdff7de4710
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3698
# Access: 0cd5bc70f6c2b2b124f7770c0c41e990
# Loaded data: 2
# Access: 835137a60fdceaa07a02c4c5b9766bc7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3699
# Access: cb20c821f86d18e53d453d7723bd7b00
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3700
# Access: 2151ac6a7298ea9c7227c9aad892be57
# Loaded data: 1
# Access: 0c805f0f29917d74a7cc81af42eae285
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3701
# Access: 17be6d9f1621f780fa827f312e4f5a5c
# Loaded data: 1
# Access: 569bcb7d8100f0a7d786db76664a3cfe
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3702
# Access: 27b6c1ae76ec7fa8a2eed508e8d92f69
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3703
# Access: 3450cf363ccf8f65d971a797f8484d06
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3704
# Access: 009d8c294f1a42fc8e989beaa8ec956b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3705
# Access: 9d796a3ee27ab0415437de4b1056fde6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3706
# Access: 23422b8ceb2352a6481402763ed74bec
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3707
# Access: 3f88624379dca9d957c21fa809363f56
# Loaded data: 2
# Access: a52f88bcf09945ed29caf79d6fb86ceb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3708
# Access: b419505daa1d23e12bc173af2cdf1a36
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3709
# Access: 67ce64a1bf37af094a91288b86e0fbc4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3710
# Access: 4ecf71c883135d318d420dd0ddfffd0a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3711
# Access: 3ee75c163b371c1bc0b9274aaed7bc35
# Loaded data: 1
# Access: 342bb614e840c6ccf9e94f5c29d01036
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3712
# Access: 0ca328ba172e9fe19b22cc2a14c27810
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3713
# Access: 5d33ed620e3bb6b4fe831e48378eefda
# Loaded data: 2
# Access: bc02520c73a8ac16112a06de5ad59be2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3714
# Access: a18544b2de1fe01d1a217972bf79c3db
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api5
# Access: c498ee0ee6e4ece60413660131525d3a
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api6
# Access: e3443cfb051d8ae5c9f57912913a6327
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api7
# Access: 131c324e75ba4e403d366c847a91b14a
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api8
# Access: c72b64faf9bb8f18b5e6d1e5d29163e4
# Loaded data: 1
# Access: 3c5afb838d94eb95781f61dc9ce0e858
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3715
# Access: 2eb1b3b9de465b4c779ed86997a341aa
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3716
# Access: a89252c8b41c90bdd25c5d0c57a5177c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3717
# Access: 7addf8e1da6e11869f31057fadad51cc
# Loaded data: 1
# Access: 3ecc0dacb3956ce66d1fb1b410e09909
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3718
# Access: 5d44c496bbfa1e0ac3efc565463909e4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3719
# Access: dba9aebabf278934bd284ed4ecfb7377
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3720
# Access: af33340edc2ba084140941025942f7e7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3788
# Access: 41515501ba0b8ea2d5ffd83d3a714f04
# Loaded data: 1
# Access: 41c5ca32d560f15c8a9a220970c7e006
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3789
# Access: 26020ce8a1b7255d66cae4dc18747456
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3790
# Access: 23c1d2792839e57d9d098d6e30836988
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3791
# Access: d526c034d2c21470b308b49277c86d1a
# Loaded data: 1
# Access: 0ce243ba3c7287cc5365ff18bd955cff
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3792
# Access: 99da2d87447f1aa24da5491ce647e054
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3793
# Access: 714e5a97920b01fe92bbbc4477f3c1ec
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3794
# Access: 3fceb9d2be48bec94865d71947149ebb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3795
# Access: 8b3f3a4265ac8493a942623f4bb2a45b
# Loaded data: 1
# Access: 0bf264930b76440bf71e62710298c2f9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3796
# Access: 281e446721d924afbc8248e5572474a6
# Loaded data: 2
# Access: ee8f893e893dbc1dd3f5c8279b2fd327
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3797
# Access: 04b5ed6e8192039fa436a1513211c780
# Loaded data: 1
# Access: b3844cbd271920aa8bb88b6e7fec6b99
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3798
# Access: 173a110d7d96cf0147d74dce2b039637
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3799
# Access: 763dc2a5824b555b483821f6fe19b1ad
# Loaded data: 1
# Access: 3bbb4d60ff068783a66c9f2010228465
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3800
# Access: 12166eea46ef0413cfe3b3a38885a45d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3801
# Access: e26e0393205273cc671c0efb0f045080
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3802
# Access: 1c6515dbb67e4967fca7b6e74729304f
# Loaded data: 20
# Access: a967261fc33ed74de8cc8dafdd20633f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3803
# Access: 38b33f1789faa5d9178908042f37f757
# Loaded data: 14
# Access: 17406d0408ac1c8da6b9a625fd142565
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3804
# Access: a906d92921ec3c0cd0d429537ad50af0
# Loaded data: 1
# Access: eeb3ff07e97ea5cc0ae8c43d758cd69b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3805
# Access: c7f7dda789634bfccbd1454690c5458a
# Loaded data: 57
# Access: bd0103f1822b72e60f2e344022352e77
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3806
# Access: 5e1db1297aee0753764750c0e52cbb7f
# Loaded data: 68
# Access: f1743be9843e8824ef0912a4f283a261
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3807
# Access: 0770ebdb35f50036e1b45df2e8ef2a20
# Loaded data: 10
# Access: 69378ef7b1e1a0dc2feecc99ae8112e6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3808
# Access: a6cefd225375261f2233816d92e8f848
# Loaded data: 1
# Access: c19bd2d282b81d6f9613b5f08a063ce7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3809
# Access: f9143c7d9fb33b4ebc0399c441580629
# Loaded data: 44
# Access: 49ed6a8ea79348243879778b5cdd7fd7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3810
# Access: a38668c8f7056bd6c38d263c8e1df374
# Loaded data: 65
# Access: 5c3e581ac72f6cbc1d47420be32578de
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3811
# Access: 3ac6105fa4168748b88dcece2a83deba
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3812
# Access: d75121e289910a5a696c68164a3044a1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3813
# Access: 64e0ec26bab316a1a58274f6b3a8d933
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3814
# Access: 5e0cfc615efc0b16637dff8538a514d9
# Loaded data: 1
# Access: 3714283f59d82524054bbe362250eb57
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3815
# Access: 4ced747848c402d78aeed804a8c68ef9
# Loaded data: 2
# Access: 1fb77b0ca4b0df5818edae761ff5bcc5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3816
# Access: a3657d991f563a6adcdd29a27d128c67
# Loaded data: 4
# Access: 7e6c381b8fe184687567624e9280d39a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 

# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3924
# Access: cc77156e520ddd386691ec653fac8f33
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3925
# Access: bbef389b28cf6576b3d482828883384c
# Loaded data: 4
# Access: a997620fc37f3a1d1761bb13318a4eaa
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3926
# Access: cdcb418ea91ba7eb313d34316e6772ae
# Loaded data: 8
# Access: 69825ee6976d7f1956e72cdc76e0e182
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3927
# Access: e27a83ad0719e1c281938428eccba3bd
# Loaded data: 1
# Access: 6649ab939bd1af602df343f02ba26158
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3928
# Access: 115c120b15517aabcfee5005f36fd733
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3929
# Access: e6fa21c595c2bddef8615145daf54a95
# Loaded data: 2
# Access: f109bf0bb5ace84fbe90843ea182f473
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3930
# Access: 3ccd41980277342d9c54ac359b380b62
# Loaded data: 19
# Access: b1e23eb36e007b1dab65315b2aeede94
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3931
# Access: dac0cffa0e4e453ed91eaec9d6c95ce6
# Loaded data: 30
# Access: 92a5a8c2099ca6140430226ea78ddc80
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3932
# Access: fdab1a99b6e969ad7ca3ebaa36baf508
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3933
# Access: 1c0e01c3f7b0c9ec6a276d3cfd210a86
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3934
# Access: eb6cf44f16d0dabf65d58998886e1d23
# Loaded data: 13
# Access: 933edac7c5e01b4668ecafafd0218435
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3935
# Access: eb1f89ddc451d07d043c8f294b5adf67
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3936
# Access: ba638ef11a70498c09d3423dbce84ccc
# Loaded data: 25
# Access: 1affeb63b2ca8c4ec3c4b71fdb3c3eb8
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3937
# Access: 5d048919e4e682f2b5a48833be91140f
# Loaded data: 3
# Access: 68defce63f9019409cd2d62082697387
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3938
# Access: b162a24952bba421df4f1fc96d6ee23d
# Loaded data: 7
# Access: c62ee35b426801479a532b6785b80b22
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3939
# Access: 7d1dfe92354e5eed68d2bc75efe8da75
# Loaded data: 29
# Access: f95340540cf37d8c5cc20b33239bce2b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3940
# Access: d3c4f2186cf8e482f0ba75d0fd5be1b9
# Loaded data: 20
# Access: ce1c4da02cd39ff9dea74924fcc1079c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3941
# Access: 2f28628b9e7ccafa6dfa682d743ed3fd
# Loaded data: 34
# Access: 19ea3c59d5c8ce9dc2f079bcd8b313bf
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3942
# Access: 8217787dabcd940eec6258d048c84689
# Loaded data: 11
# Access: a46ac8820a0c0d3b9a37634fdcf65952
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3943
# Access: 9ff11c2a1b98d044d4399aa4de3be280
# Loaded data: 7
# Access: a21fe53b0a040035a8347c802fcf2ea5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3944
# Access: 81cc2c80ea5a2f81c77b7c372d1bdac8
# Loaded data: 6
# Access: 1683419c4fba4c0cab06cb6830063d82
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3945
# Access: ab831d018298533422b1138af1115225
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3946
# Access: 6939dcfdf7e3c1504116c9efdff447c8
# Loaded data: 1
# Access: 2e7e5dba8365558ddba5203917db5fe3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3947
# Access: af2cbc4174bb68e79bcff235c7e2cf3e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3948
# Access: 80f35d1d4ce95d1010e645839bc2081f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3949
# Access: 7a8a18e9f0958b1fdf552e7813a22c12
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3950
# Access: c0997422470a7c68e49e3f574cac9bf3
# Loaded data: 3
# Access: 17cead5a27ca3b2cac01b76cde16bdb4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3951
# Access: 07e1bbc6101a682d10cdecdd331f2c11
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3952
# Access: 6197710b096ea9161da8e003d400c7aa
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3953
# Access: 688fdd257ad5c3854faa2f1fe9b83ac1
# Loaded data: 5
# Access: 8114ae57d5a19ffa2dee094c3c3f3bf3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3954
# Access: 1b40fb4d4d9496b13b5800da26eccdcd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3955
# Access: 1f67607de9b5d265162e3404b94fd499
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3956
# Access: ce1420f347651176b5a282e12b7fa42a
# Loaded data: 9
# Access: b51390550aa9f3f4e77138f1b6649f88
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3957
# Access: 9958811a699eaa20abbe85b9f1835a5d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3958
# Access: 3c33d670612bf900538f3b4a55428bdc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3959
# Access: 8b798293015c7a8db944010a5b3a9f75
# Loaded data: 1
# Access: cfadcf3ae6763912314623a2813c60e9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3960
# Access: fe4ae3bdf581f48874e0376a02738af3
# Loaded data: 5
# Access: 6ae5ab80635a17e1c08272de4bd7e437
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3961
# Access: 8700b0a32f68d5152cb0290695ceaca6
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3962
# Access: 53163cb06ba9fdc9c522e78d874158e9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3963
# Access: 99a4e8c7e5f0e4e5136e097863750406
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3964
# Access: 08d63dbd3206310715de3ef4ccf5f2ff
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3965
# Access: 6b4e7bf18ea697c2da6b449727207ac0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3966
# Access: bbf021bdd30726826124aa144b9f886c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3967
# Access: 458b82f8ed5f182300ab816120e8549f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3968
# Access: 0128c387e976f3665198106c4d6c6f8e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3969
# Access: 6418cf8acedd7a86b22e836a30ef0973
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3970
# Access: 2eb076a099d29978cf7ee8e5fd25c7df
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3971
# Access: cfe1722d05b327ba7f5dd68e167705ee
# Loaded data: 3
# Access: cbef868dcab6b3bf2d9642ce25298d5d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3972
# Access: ead216e32edeae6d46dce213072bd8df
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3973
# Access: f4c6a0ad725b6e6c90fc00aec7055f02
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3974
# Access: f11dc1cbc58ddb0ec181c0ec8adfa323
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3975
# Access: 34fa4b9c94aa2811700da86f33565d16
# Loaded data: 19
# Access: a4395882c77d8ded4c1166c8c24377b9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3976
# Access: 5e1332a8b30ddf73f5805f03d1a8ab38
# Loaded data: 26
# Access: 71c5297d7090fc36d782a17021e446e3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3977
# Access: 7e3379a9d85aca1b98876ed66d520f96
# Loaded data: 125
# Access: 0af9b48e3a3f9f1c9d4b1e2703768f9a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3978
# Access: 2b4604f79ac669a6b7205e4d002490dd
# Loaded data: 72
# Access: ff4b319c2ddc52c1f7861e69d30ea50c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3979
# Access: 9b85903c3ce499178b11f6914ce33c1d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3980
# Access: 9490bd52ca4f634d80c657ca122fdf2c
# Loaded data: 2
# Access: 40fb90830d1020b5255710e80d6a7991
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3981
# Access: 5e6c7d3131f0ae61ecf2071e5965976b
# Loaded data: 2
# Access: 6a2360d7a6af4711074ae2b26b6dd120
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3982
# Access: 1b49a49adbbf6faaf948bc5f46cbe5d0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3983
# Access: 924be76adb880ba5362e2242047a2017
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3984
# Access: 7cbc85dca8ac08527f1043107ab9e293
# Loaded data: 10
# Access: ec48ac146885fa72e5d4a72cd3a28e64
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3985
# Access: 034f43431c7294f4b59f8ea66f6d84c3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8080
# Access: 1ae09f536b743d90207a3af16415e129
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8081
# Access: 947560a24287d14c3f4a508284bb52a5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8082
# Access: 7f5717027883070b0db36da776ffe6de
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8083
# Access: 6909a5033662fe40ff6bc47c605ace60
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8084
# Access: fb66ce5c3442313c6669f816197d5df9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8085
# Access: b2e16c0a168a90f4cc5dbb923e3df5b1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8086
# Access: 7f6d056eacd2a0b5eff9ed0261dc3e47
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8087
# Access: edef6a8868d5c2deceeb77e594d295b7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8088
# Access: d490ea52e4464498295e50c1306ecca2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8089
# Access: b66b62f0739dad480bc1d30bb073ce37
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8090
# Access: 01dd4cb95b2d95538420ed0f9e98762a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8091
# Access: 71e2462acef14cdaf3b63da1af0bcfb1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8092
# Access: e5519fbe40afb16b954fb7acd557f3fd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8093
# Access: 76ee2abdd0ef2cfe9a6462c195b84867
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8094
# Access: 792c96f620fd2614dcb758eda753588d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8095
# Access: 98591443c6c52ee8eb0f73d349a95855
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8096
# Access: d4ec201924846a1aa87b9307b0dd9414
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8097
# Access: cedd7a122144e00461d9e696b056f13f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8098
# Access: e7518ce31afb9bb5696a0b00f7b43bd5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8099
# Access: 14813d55506c39dfcbbb3e0998f4c6fd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8100
# Access: 049cd111620d38b7dbb3a0d03235554f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8101
# Access: c58af019c74b80298dc9e3ef1fb2e79e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8102
# Access: dcf34b90df091230770a68edccc657df
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api9
# Access: 2d679fbd25e684878e8f915146e889d0
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api10
# Access: 1217ff4c11dc0cd218ceaf21971f4878
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api11
# Exceed the download permit

# %% [markdown]
# #### Visualise Property Schema ``(do not run this)``

# %%
"""
[
  {
    "type": "Project",
    "listings": [
      {
        "listingType": "NewHomes",
        "id": 2017835505,
        "projectId": 5437,
        "advertiser": {
          "type": "Agency",
          "id": 32584,
          "name": "Roche Group",
          "logoUrl": "https://images.domain.com.au/img/Agencys/32584/logo_32584.jpeg",
          "preferredColourHex": "#1d2c44",
          "bannerUrl": "https://images.domain.com.au/img/Agencys/32584/banner_32584.jpeg",
          "contacts": [
            {
              "name": "Cameron Grove Sales",
              "photoUrl": "https://images.domain.com.au/img/32584/contact_1637430.png?mod=220821-125111"
            }
          ]
        },
        "priceDetails": {
          "displayPrice": "RESERVED"
        },
        "media": [
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_1_1_220726_010938-w2880-h2160"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_2_1_220725_035031-w2048-h1536"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_3_1_220725_035031-w1536-h2048"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_4_1_220725_035031-w1536-h2048"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_5_1_220725_035031-w2048-h1536"
          }
        ],
        "propertyDetails": {
          "state": "NSW",
          "features": [
            "AirConditioning",
            "Ensuite",
            "Gas",
            "Bath",
            "Dishwasher",
            "Study",
            "RainwaterStorageTank"
          ],
          "propertyType": "House",
          "allPropertyTypes": [
            "House"
          ],
          "bathrooms": 2,
          "bedrooms": 4,
          "carspaces": 2,
          "unitNumber": "",
          "streetNumber": "37",
          "street": "Estelville Circuit",
          "area": "Lake Macquarie West",
          "region": "Hunter Region",
          "suburb": "CAMERON PARK",
          "postcode": "2285",
          "displayableAddress": "37 Estelville Circuit, Cameron Park",
          "latitude": -32.91141,
          "longitude": 151.59761,
          "landArea": 586,
          "buildingArea": 265,
          "isRural": false,
          "isNew": true,
          "tags": [
            "newdevelopment"
          ]
        },
        "headline": "Cameron Park - Home under construction, amazing views!",
        "summaryDescription": "<b></b><br />Don't miss out on this one of a kind opportunity, this home is currently under construction, you will  see the interior of the home this weekend, Landscaping and Fencing are about to commence. Hope to see you here this weekend.\r\n\r\nTucked a...",
        "hasFloorplan": true,
        "hasVideo": false,
        "labels": [
          "Under offer",
          "Updated",
          "New homes"
        ],
        "dateListed": "2022-05-28T20:15:55",
        "inspectionSchedule": {
          "byAppointment": true,
          "recurring": false,
          "times": []
        },
        "listingSlug": "37-estelville-circuit-cameron-park-nsw-2285-2017835505"
      }
    ],
    "project": {
      "state": "NSW",
      "id": 5437,
      "name": "Cameron Grove Estate",
      "bannerUrl": "https://images.domain.com.au/img/Agencys/devproject/banner_5437_220726_011050",
      "preferredColorHex": "#419a45",
      "logoUrl": "https://images.domain.com.au/img/Agencys/devproject/logo_5437_220726_011050",
      "labels": [
        "New"
      ],
      "displayableAddress": "28 28 BREAKWELL ROAD, CAMERON PARK, NSW 2285",
      "suburb": "CAMERON PARK",
      "features": [
        ""
      ],
      "media": [
        {
          "category": "Image",
          "url": "https://bucket-api.domain.com.au/v1/bucket/image/af4a92fb-1686-479d-a6f7-13e7fc1425b8-w1500-h966"
        }
      ],
      "projectSlug": "project/5437/cameron-grove-estate-cameron-park-nsw"
    }
  }
]

"""
# Out:
# '\n[\n  {\n    "type": "Project",\n    "listings": [\n      {\n        "listingType": "NewHomes",\n        "id": 2017835505,\n        "projectId": 5437,\n        "advertiser": {\n          "type": "Agency",\n          "id": 32584,\n          "name": "Roche Group",\n          "logoUrl": "https://images.domain.com.au/img/Agencys/32584/logo_32584.jpeg",\n          "preferredColourHex": "#1d2c44",\n          "bannerUrl": "https://images.domain.com.au/img/Agencys/32584/banner_32584.jpeg",\n          "contacts": [\n            {\n              "name": "Cameron Grove Sales",\n              "photoUrl": "https://images.domain.com.au/img/32584/contact_1637430.png?mod=220821-125111"\n            }\n          ]\n        },\n        "priceDetails": {\n          "displayPrice": "RESERVED"\n        },\n        "media": [\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_1_1_220726_010938-w2880-h2160"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_2_1_220725_035031-w2048-h1536"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_3_1_220725_035031-w1536-h2048"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_4_1_220725_035031-w1536-h2048"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_5_1_220725_035031-w2048-h1536"\n          }\n        ],\n        "propertyDetails": {\n          "state": "NSW",\n          "features": [\n            "AirConditioning",\n            "Ensuite",\n            "Gas",\n            "Bath",\n            "Dishwasher",\n            "Study",\n            "RainwaterStorageTank"\n          ],\n          "propertyType": "House",\n          "allPropertyTypes": [\n            "House"\n          ],\n          "bathrooms": 2,\n          "bedrooms": 4,\n          "carspaces": 2,\n          "unitNumber": "",\n          "streetNumber": "37",\n          "street": "Estelville Circuit",\n          "area": "Lake Macquarie West",\n          "region": "Hunter Region",\n          "suburb": "CAMERON PARK",\n          "postcode": "2285",\n          "displayableAddress": "37 Estelville Circuit, Cameron Park",\n          "latitude": -32.91141,\n          "longitude": 151.59761,\n          "landArea": 586,\n          "buildingArea": 265,\n          "isRural": false,\n          "isNew": true,\n          "tags": [\n            "newdevelopment"\n          ]\n        },\n        "headline": "Cameron Park - Home under construction, amazing views!",\n        "summaryDescription": "<b></b><br />Don\'t miss out on this one of a kind opportunity, this home is currently under construction, you will  see the interior of the home this weekend, Landscaping and Fencing are about to commence. Hope to see you here this weekend.\r\n\r\nTucked a...",\n        "hasFloorplan": true,\n        "hasVideo": false,\n        "labels": [\n          "Under offer",\n          "Updated",\n          "New homes"\n        ],\n        "dateListed": "2022-05-28T20:15:55",\n        "inspectionSchedule": {\n          "byAppointment": true,\n          "recurring": false,\n          "times": []\n        },\n        "listingSlug": "37-estelville-circuit-cameron-park-nsw-2285-2017835505"\n      }\n    ],\n    "project": {\n      "state": "NSW",\n      "id": 5437,\n      "name": "Cameron Grove Estate",\n      "bannerUrl": "https://images.domain.com.au/img/Agencys/devproject/banner_5437_220726_011050",\n      "preferredColorHex": "#419a45",\n      "logoUrl": "https://images.domain.com.au/img/Agencys/devproject/logo_5437_220726_011050",\n      "labels": [\n        "New"\n      ],\n      "displayableAddress": "28 28 BREAKWELL ROAD, CAMERON PARK, ...
