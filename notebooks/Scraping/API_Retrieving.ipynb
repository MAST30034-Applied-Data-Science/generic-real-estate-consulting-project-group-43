# %%
import requests
import json
from bs4 import BeautifulSoup
from csv import writer

# Use client credentials
# Additional
client_id1 = 'client_660b4d0cceb4cf9f989acef154caf4ab'
client_secret1 = 'secret_bd749d4e48d050deb1d8873b061456f2'
# jongho api
client_id2 = 'client_e470bd58b93f29f12bf0a584c8ee6b08'
client_secret2 = 'secret_e721ef5d2089efd16ceef38e10d95d1b'
client_id3 = 'client_aba6e5dec04c5d1a2335705504e56729' 
client_secret3 = 'secret_cabc2a80fd7cd09a918f86b5672962cb'
client_id4 = 'client_b74a3bc9756e77bdcd0a2ffb2e430edb'
client_secret4 = 'secret_666cf9388a8462e398aadf7d4d105879'
# philip api
client_id5 = 'client_4253061ce6d6a7a86cc877d9c9dfa776'
client_secret5 = 'secret_2e3838d9fe9ced976a3fa974689a9d9d'
client_id6 = 'client_a89a8ef1b3cf662607f452a01c8f27b1'
client_secret6 = 'secret_a4f96d2c0790ad05fe041eed2c314dfa'
client_id7 = 'client_80e72e5511155fdde9a18e467f829c15'
client_secret7 = 'secret_4e3af2f4c36e901b8f7c0afbda475f32'
# grace api
client_id8 = 'client_406f326e62a400f902b3f719c8593ab2'
client_secret8 = 'secret_6c7dd26c2428d6074e4a6a6b1bfcced3'
# Nuo api
client_id9 = 'client_19c60ac8e6ddcb881b2ea29962cb34d7'
client_secret9 = 'secret_e4bc232ca320af78499287cf3f5477b8'
client_id10 = 'client_80c69b6fa0e2fb021a23daafa80cde7a'
client_secret10 = 'secret_cb18898e2c6674ff84f78c9918a87429'
client_id11 = 'client_e2048fb1cdea5b654551ebe33b30d471'
client_secret11 = 'secret_ffe3749686b362eee3255848bac52932'

client = {}
client['client_id'] = [client_id1, client_id2, client_id3, client_id4, client_id5, client_id6, client_id7, client_id8, client_id9, client_id10, client_id11]
client['client_secret'] = [client_secret1, client_secret2, client_secret3, client_secret4, client_secret5, client_secret6, client_secret7, client_secret8, client_secret9, client_secret10, client_secret11]

def retrive_properties(client_id, client_secret, pageNumber, postCode="", state="VIC", pageSize=200, filename="../../data/raw/API_Raw_PropertiesInfo.csv"):
  scopes = ['api_listings_read']
  auth_url = 'https://auth.domain.com.au/v1/connect/token'
  url_endpoint = 'https://api.domain.com.au/v1/listings/residential/_search'

  # mock client post request in exchange of a one-time access token
  response = requests.post(auth_url, data = {
                          'client_id':client_id,
                          'client_secret':client_secret,
                          'grant_type':'client_credentials',
                          'scope':scopes,
                          'Content-Type':'text/json'
                          })
  json_res = response.json()
  # take the access token each time (can call a page of size 200)
  access_token=json_res['access_token']
  print("Access:", access_token)
  # authentication for current access token
  auth = {'Authorization':'Bearer ' + access_token}
  url = url_endpoint

  # with the current access token, specify the post search query 
  post_fields = {
        "listingType":"Rent", # only interested in Rents
        "pageSize": pageSize, 
        "pageNumber": pageNumber, # 200 per page
        "propertyTypes":"",
        "minBedrooms":1,
        "minBathrooms":1,
        # "maxPrice": 400,
        "sort": {
            "sortKey": "Default"
        },

        "locations":[
          {
            "state": state,
            "region":"",
            "area":"",
            "suburb":"",
            "postCode": postCode, # will iterate by postcodes
            "includeSurroundingSuburbs":False
          }
        ]
  }

  # get the response of a post search, could either be 200 (success) or some errors
  respond = requests.post(url,headers=auth,json=post_fields)
  content = json.loads(respond.text)
  print("Loaded data: " + str(len(content)))
  # quota error or no relevant data can be found on this page, e.g.
  # {'errors': {'searchParameters.Page': ['Cannot page beyond 1000 records.']},
  # 'message': 'The request is invalid.'}
  if ("errors" in content or len(content) == 0):                                              
    print("Limit notice")
    print(content)
    return 1
  # errors occur when the query type is not from PropertyListing
  elif ("type" in content and content["type"] != "PropertyListing"):
    print("Error accurs (No data)")
    print(content)
    return 2

  # Get request for each property ID and extract attributes, each 'i' is 
  # a single property schema in json format
  for i in content:
      #get details
      id = i['listing']['id']
      listing_type = i['listing']['listingType']
      r = i['listing']['propertyDetails']
      street_address=r['displayableAddress']
      suburb=r['suburb']
      postcode=r['postcode']
      area=r['area']
      if('buildingArea' in r and 'landArea' in r):
        building_area = r['buildingArea']
        land_area = r['landArea']
      else:
        building_area = 0
        land_area = 0
      # latitude and longitude might not be available in some instances
      if ('latitude' in r and 'longitude' in r):
        latitude = r['latitude']
        longitude = r['longitude']
      else:
        latitude = None
        longitude = None
      
      property_type=r['propertyType']
      bathrooms=r['bathrooms']
      bedrooms=r['bedrooms']

      if(str(i).find('carspaces'))>0:
          carspaces=i['listing']['propertyDetails']['carspaces']
      else:
          carspaces=0

      price=i['listing']['priceDetails']['displayPrice'] #[1:4]

      if(i['listing']['dateListed']):
          time = i['listing']['dateListed']
      else:
          time = 0

      info = [id, time, listing_type, price, property_type, area, building_area, land_area, 
      bedrooms, bathrooms, carspaces, street_address, suburb, postcode, latitude, longitude]

      # write the relevant info of current property one row at a time
      with open(filename, 'a', newline='') as g:
          thewriter = writer(g)
          thewriter.writerow(info)

  return 0

# retrive_properties(client_id, client_secret, 1)

# %% [markdown]
# Rrtrive rental data

# %%
# Retrive rental data by postcode
# postcode 3000~4000
count = 0
limit = len(client['client_id'])

for i in range(3678, 4000): # excuted upto (3278, 3677), start from 3678
    # Check available api list
    if count >= limit:
        print("Exceed the download permit")
        break

    # Retrive data
    print("Retriving data from postcode: " + str(i))

    # read data by page (1~5)
    p = 1
    while p < 6:
        if count >= limit:
            break

        client_id = client['client_id'][count]
        client_secret = client['client_secret'][count]

        num = retrive_properties(client_id, client_secret, p, str(i))
        if num == 1:
            # no data found
            break
        elif num == 2:
            # change the new api
            count += 1
            print("using api" + str(count))
        else:
            # continue to the next page
            p += 1

# postcode 8000~9000
for i in range(8000, 9000):
    if count >= limit:
        print("Exceed the download permit")
        break

    print("Retriving data from postcode: " + str(i))

    p = 1
    while p < 6:
        if count >= limit:
            break
        
        client_id = client['client_id'][count]
        client_secret = client['client_secret'][count]

        num = retrive_properties(client_id, client_secret, p, str(i))
        if num == 1:
            break
        elif num == 2:
            count += 1
            print("using api" + str(count))
        else:
            p += 1
# Out:
# Retriving data from postcode: 3678
# Access: 65e09c084262ff92a657276e737a05b5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3923
# Access: bcb45cc34ed034a90dfb324b8e4ac344
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3924
# Access: c868bfd9ecbde6970fe2773ddee66983
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3925
# Access: 1ee3ced64159e903e654301fd154d2a3
# Loaded data: 4
# Access: e7681faf7e33e38d7043054913c70c03
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3926
# Access: ee2cf33bcc61adb4433bb6b3e36d3fa4
# Loaded data: 8
# Access: 3be8a1a7852dc0bb9764547dca6bd60b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3927
# Access: 186a433ba8955ec7388986f826a5ee56
# Loaded data: 1
# Access: 4f6b22f5a85600bcc6e9629161219bee
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3928
# Access: 42ad04be2f8ab16112ac3941b734e8f2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3929
# Access: d00946169fe720fb259717370a51aa9a
# Loaded data: 2
# Access: 3b1e8b4bc865cd6f0507487e46b9076f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3930
# Access: b8f8ca845caabea8b68594e98459fc1d
# Loaded data: 19
# Access: 91dd78f06442e28925a2468f7fab03f2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3931
# Access: 1d8df4bae65d7a75400ed0ee2e82f25e
# Loaded data: 30
# Access: 07ca83e0dfa9fe20f0d4b3ab1eabe851
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3932
# Access: ba22e408d506688ffeca39487deeec9a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3933
# Access: 9f5c50fe2a9ef0b3bf3b9bfb4eceb5dc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3934
# Access: abf57c387216fd64b40ee6467655df51
# Loaded data: 13
# Access: b428ad48b39d78c755c48dfe44fa5642
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3935
# Access: ee95e38c941547f0c1e5bf339bccdc0d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3936
# Access: 4ec870e2e053654f6e7b06ff53473849
# Loaded data: 25
# Access: d5801acd71c0578d8de0a745d2af9f69
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3937
# Access: 112247d59bfca22058229692144e7bbd
# Loaded data: 3
# Access: 0fdc65b7fcc4484f41fbc2ed8e49d60c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3938
# Access: c0a0289944c6db818aa9a7e85687455e
# Loaded data: 7
# Access: 9f6ed843362570c272387a01d658bddc
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3939
# Access: d479ec2c1485f9171c642328e7769289
# Loaded data: 29
# Access: 1022e513185e0582dc34844092b2490c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3940
# Access: f634635d9fdd6e20883e213c087d49e0
# Loaded data: 20
# Access: 8fb85d77d835b986a53f18e462162e08
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3941
# Access: 4b975bdf1673d5cb9bc69492b9a9a631
# Loaded data: 34
# Access: 43645bd501506317bfc09b2887b9dd9c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3942
# Access: 30c10f0b753e2749478e1c4eb5223ea8
# Loaded data: 11
# Access: 815ebb48a461505225b0055132ffbc72
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3943
# Access: 2c2c266d20a5841635903beac237e21b
# Loaded data: 7
# Access: 688c685a3209cfa8626db20c0d35e59a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3944
# Access: 7e02fa9b63177bb8265fa4eafcd205d6
# Loaded data: 6
# Access: fd534769fe566604fe36bf15109a1a90
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3945
# Access: 5397c5a0fd5cd2538aec43728ca1c461
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3946
# Access: 2ec387c920f82f662e381eefe000c1ab
# Loaded data: 1
# Access: 458c3c6231241f1618a4df525bb80e4d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3947
# Access: ddc1e4760c407d2ecf188169a5e19853
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3948
# Access: 151f00bc73a37fd730eff382aea8f2be
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3949
# Access: 5b1e750b321ccbedf05f8b049d9adca3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3950
# Access: f9e082a2aec142ff95fecb157d784973
# Loaded data: 3
# Access: b370adf365e69ad7155aee7954ebd8a2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 3951
# Access: a77747ba6101e37d90c7d95dca15c2e1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8033
# Access: a3144b2c4c46755a7cc525583b55eb13
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8034
# Access: bf9b611a5ec7e1e4ee7e7f22b5c996b7
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8035
# Access: 87108d053bb42d82b33bc874d543893e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8036
# Access: 136ed2d42f835d21bcff57d0dd731dec
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8037
# Access: 0fdd385e738e1d8ee50a41f374ce0f6f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8038
# Access: 63ba9fdf9f381f05c599969669420b94
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8039
# Access: b78ef8101f87d99904814c822c238b11
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8040
# Access: 86494c3e43c8403a7f6ea3ed243f4718
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8041
# Access: 18f5953bbad63d2b912b62e4ccefe016
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8042
# Access: c08d5415de8f5c511cb0b689b0823886
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8043
# Access: 16afbe1d303a5464cd7ea692bc941f0c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8044
# Access: 684408cb681dd20e1cade41ad4b1c875
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8045
# Access: 572427d32958801ba34da158b8e95b76
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8046
# Access: cef4f416bd0d854a79e0ae22ac98c049
# Loaded data: 3
# Error accurs (No data)
# {'type': 'https://developer.domain.com.au/docs/latest/conventions/rate-limiting', 'title': 'Quota Exceeded', 'detail': 'Exceeded rate limit for current period'}
# using api1
# Access: 0a2a9cbeae430b409789c7c2b3742b95
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8047
# Access: e9fa65749750eb876346bb933a7c0c00
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8048
# Access: 0531abdfd90c14af437c16f6662cd0b4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8049
# Access: ef85a72b95336d031c434b169dd78cb4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8050
# Access: b920472f1b8b8ac0a194f7c2be3f10d1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8051
# Access: 8af138c6503dc5b37ca0c1044fa1dff0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8052
# Access: e0260ea4818c2fb6a2ae8ad2e5dce79c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8053
# Access: 4adbe58ec50adf7621f51bfa5f40e03a
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8054
# Access: 237711c79d0f2830a5eef7d7a5133666
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8055
# Access: 60b9496908bd570d6b44316b60097cdd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8056
# Access: 875d3422075de0a175cbfeb8d9802b54
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8057
# Access: 7aab4df109f01acd2a0462e146454981
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8058
# Access: 657b7628f669648a498dd2d33ddb924b
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8059
# Access: f238a2e867b6c3339ea6d7a8ba7fdb9b
# Loaded data: 0
# Limit notice
# ...
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8851
# Access: 1138f2b6fc2bd12fb3a159b05c5df657
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8852
# Access: a364720cea553b3b52ef493c34cf19fe
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8853
# Access: 3f334b78944869c018c11d98fad9d4ac
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8854
# Access: 7886dff1ad2549bb9b7506f89d4fd37c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8855
# Access: d55a5267eafa2e64ce96cba399bee6f5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8856
# Access: e681f8261a2fbd5b38d0b71b3ac750a3
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8857
# Access: 90d7c05db4e00b8e6b18c691437a41f5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8858
# Access: c3c92d87045ccf6474534002e5addaad
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8859
# Access: 19b1ce53089a5c3edee4ecc9fdf54565
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8860
# Access: 463b920574cbed5ee6919ea4048170bb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8861
# Access: 83807cbc25e7b5a4a9f3b34a95f9d734
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8862
# Access: fd3f97ffa67d94c7d3c0f3a1ae0abc05
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8863
# Access: 3d1f5593e668043a859fb607890c58ac
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8864
# Access: e9b0e5c663b44abb479bd6e86ad3c683
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8865
# Access: a5d7289e57e711bdb6849aa8868f3a88
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8866
# Access: d549475d9b90642b705692519d0bd52d
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8867
# Access: 5f9cff5f29d61ea271b0991ce0fc3cd9
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8969
# Access: 8ab029689145066cb0cd7e6541360407
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8970
# Access: b9a35f92c7a79623978da59eb53be1c0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8971
# Access: 25aeba7d9e9e8767db644eecfd4b9e28
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8972
# Access: 32b14706578cb34fb1adf4c53f4b72e4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8973
# Access: b3e8dcfe2cfd65046b58b0632e357062
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8974
# Access: d0bd39abe371c55d375763f47a4d3239
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8975
# Access: d5b704f476f24bc64b10683e77856bf0
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8976
# Access: beaa0386b34d63a15b2ef4fb08d2c8dd
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8977
# Access: 7c0fdc345566b3a7521e97177dbdd605
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8978
# Access: 7f378f5c1e8b3928880e29d346bf8701
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8979
# Access: e70d36ccf42b5e291c55c9024b732559
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8980
# Access: 19d88acff1eb1c2b99e01f3acc1616e4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8981
# Access: 5d99e52ce8693a30f5146567100b5afa
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8982
# Access: ed2920c1d145afeebcaab35455a52db1
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8983
# Access: 6d02a28cb362d1b78e4d829f25da91d4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8984
# Access: 9826f7954778f5e30a6b4b245b9b36eb
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8985
# Access: 4be107e0377d694471b83dd19fd6d5a4
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8986
# Access: 04898aee2b7423487a3bde44b7555c22
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8987
# Access: 614e13720db456107af93f99c8654ac5
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8988
# Access: 61f3ae9fb649b9457b5df1088df1aa17
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8989
# Access: e60684f8315882f04f757d979953ca73
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8990
# Access: 2ec93b25826859267070db38a770d5b2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8991
# Access: 36c9c4f7986ce1e92c2bb4d34fc54932
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8992
# Access: 1558d2a14494c5a17404236ab1f55791
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8993
# Access: 47ae68df1c00d18dcea5dc0212cdad1e
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8994
# Access: 15bdc129e4345cdd928ce82203749680
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8995
# Access: cc6b4237edbdbabd35b6cf61e8a25d6f
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8996
# Access: b9399374364d11bdffa43c319a8e886c
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8997
# Access: eadd92c8e3f6af738bd140442ffc7ce2
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8998
# Access: 0b85b3ff52b447392f5ab54ad1e36449
# Loaded data: 0
# Limit notice
# []
# Retriving data from postcode: 8999
# Access: 57881589c99a602a1ca4ae9dbd1145aa
# Loaded data: 0
# Limit notice
# []

# %%
# adding column names
import pandas as pd
df = pd.read_csv("../../data/raw/API_Raw_PropertiesInfo.csv")
columns = ['id', 'time', 'listing_type', 'price', 'property_type', 'area',
       'building_area', 'land_area', 'bedrooms', 'bathrooms', 'carspaces',
       'street_address', 'suburb', 'postcode', 'latitude', 'longitude']
df.columns = columns
df.to_csv("../../data/raw/API_Raw_PropertiesInfo.csv")

# %% [markdown]
# #### Visualise Property Schema ``(do not run this)``

# %%
"""
[
  {
    "type": "Project",
    "listings": [
      {
        "listingType": "NewHomes",
        "id": 2017835505,
        "projectId": 5437,
        "advertiser": {
          "type": "Agency",
          "id": 32584,
          "name": "Roche Group",
          "logoUrl": "https://images.domain.com.au/img/Agencys/32584/logo_32584.jpeg",
          "preferredColourHex": "#1d2c44",
          "bannerUrl": "https://images.domain.com.au/img/Agencys/32584/banner_32584.jpeg",
          "contacts": [
            {
              "name": "Cameron Grove Sales",
              "photoUrl": "https://images.domain.com.au/img/32584/contact_1637430.png?mod=220821-125111"
            }
          ]
        },
        "priceDetails": {
          "displayPrice": "RESERVED"
        },
        "media": [
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_1_1_220726_010938-w2880-h2160"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_2_1_220725_035031-w2048-h1536"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_3_1_220725_035031-w1536-h2048"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_4_1_220725_035031-w1536-h2048"
          },
          {
            "category": "Image",
            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_5_1_220725_035031-w2048-h1536"
          }
        ],
        "propertyDetails": {
          "state": "NSW",
          "features": [
            "AirConditioning",
            "Ensuite",
            "Gas",
            "Bath",
            "Dishwasher",
            "Study",
            "RainwaterStorageTank"
          ],
          "propertyType": "House",
          "allPropertyTypes": [
            "House"
          ],
          "bathrooms": 2,
          "bedrooms": 4,
          "carspaces": 2,
          "unitNumber": "",
          "streetNumber": "37",
          "street": "Estelville Circuit",
          "area": "Lake Macquarie West",
          "region": "Hunter Region",
          "suburb": "CAMERON PARK",
          "postcode": "2285",
          "displayableAddress": "37 Estelville Circuit, Cameron Park",
          "latitude": -32.91141,
          "longitude": 151.59761,
          "landArea": 586,
          "buildingArea": 265,
          "isRural": false,
          "isNew": true,
          "tags": [
            "newdevelopment"
          ]
        },
        "headline": "Cameron Park - Home under construction, amazing views!",
        "summaryDescription": "<b></b><br />Don't miss out on this one of a kind opportunity, this home is currently under construction, you will  see the interior of the home this weekend, Landscaping and Fencing are about to commence. Hope to see you here this weekend.\r\n\r\nTucked a...",
        "hasFloorplan": true,
        "hasVideo": false,
        "labels": [
          "Under offer",
          "Updated",
          "New homes"
        ],
        "dateListed": "2022-05-28T20:15:55",
        "inspectionSchedule": {
          "byAppointment": true,
          "recurring": false,
          "times": []
        },
        "listingSlug": "37-estelville-circuit-cameron-park-nsw-2285-2017835505"
      }
    ],
    "project": {
      "state": "NSW",
      "id": 5437,
      "name": "Cameron Grove Estate",
      "bannerUrl": "https://images.domain.com.au/img/Agencys/devproject/banner_5437_220726_011050",
      "preferredColorHex": "#419a45",
      "logoUrl": "https://images.domain.com.au/img/Agencys/devproject/logo_5437_220726_011050",
      "labels": [
        "New"
      ],
      "displayableAddress": "28 28 BREAKWELL ROAD, CAMERON PARK, NSW 2285",
      "suburb": "CAMERON PARK",
      "features": [
        ""
      ],
      "media": [
        {
          "category": "Image",
          "url": "https://bucket-api.domain.com.au/v1/bucket/image/af4a92fb-1686-479d-a6f7-13e7fc1425b8-w1500-h966"
        }
      ],
      "projectSlug": "project/5437/cameron-grove-estate-cameron-park-nsw"
    }
  }
]

"""
# Out:
# '\n[\n  {\n    "type": "Project",\n    "listings": [\n      {\n        "listingType": "NewHomes",\n        "id": 2017835505,\n        "projectId": 5437,\n        "advertiser": {\n          "type": "Agency",\n          "id": 32584,\n          "name": "Roche Group",\n          "logoUrl": "https://images.domain.com.au/img/Agencys/32584/logo_32584.jpeg",\n          "preferredColourHex": "#1d2c44",\n          "bannerUrl": "https://images.domain.com.au/img/Agencys/32584/banner_32584.jpeg",\n          "contacts": [\n            {\n              "name": "Cameron Grove Sales",\n              "photoUrl": "https://images.domain.com.au/img/32584/contact_1637430.png?mod=220821-125111"\n            }\n          ]\n        },\n        "priceDetails": {\n          "displayPrice": "RESERVED"\n        },\n        "media": [\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_1_1_220726_010938-w2880-h2160"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_2_1_220725_035031-w2048-h1536"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_3_1_220725_035031-w1536-h2048"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_4_1_220725_035031-w1536-h2048"\n          },\n          {\n            "category": "Image",\n            "url": "https://bucket-api.domain.com.au/v1/bucket/image/2017835505_5_1_220725_035031-w2048-h1536"\n          }\n        ],\n        "propertyDetails": {\n          "state": "NSW",\n          "features": [\n            "AirConditioning",\n            "Ensuite",\n            "Gas",\n            "Bath",\n            "Dishwasher",\n            "Study",\n            "RainwaterStorageTank"\n          ],\n          "propertyType": "House",\n          "allPropertyTypes": [\n            "House"\n          ],\n          "bathrooms": 2,\n          "bedrooms": 4,\n          "carspaces": 2,\n          "unitNumber": "",\n          "streetNumber": "37",\n          "street": "Estelville Circuit",\n          "area": "Lake Macquarie West",\n          "region": "Hunter Region",\n          "suburb": "CAMERON PARK",\n          "postcode": "2285",\n          "displayableAddress": "37 Estelville Circuit, Cameron Park",\n          "latitude": -32.91141,\n          "longitude": 151.59761,\n          "landArea": 586,\n          "buildingArea": 265,\n          "isRural": false,\n          "isNew": true,\n          "tags": [\n            "newdevelopment"\n          ]\n        },\n        "headline": "Cameron Park - Home under construction, amazing views!",\n        "summaryDescription": "<b></b><br />Don\'t miss out on this one of a kind opportunity, this home is currently under construction, you will  see the interior of the home this weekend, Landscaping and Fencing are about to commence. Hope to see you here this weekend.\r\n\r\nTucked a...",\n        "hasFloorplan": true,\n        "hasVideo": false,\n        "labels": [\n          "Under offer",\n          "Updated",\n          "New homes"\n        ],\n        "dateListed": "2022-05-28T20:15:55",\n        "inspectionSchedule": {\n          "byAppointment": true,\n          "recurring": false,\n          "times": []\n        },\n        "listingSlug": "37-estelville-circuit-cameron-park-nsw-2285-2017835505"\n      }\n    ],\n    "project": {\n      "state": "NSW",\n      "id": 5437,\n      "name": "Cameron Grove Estate",\n      "bannerUrl": "https://images.domain.com.au/img/Agencys/devproject/banner_5437_220726_011050",\n      "preferredColorHex": "#419a45",\n      "logoUrl": "https://images.domain.com.au/img/Agencys/devproject/logo_5437_220726_011050",\n      "labels": [\n        "New"\n      ],\n      "displayableAddress": "28 28 BREAKWELL ROAD, CAMERON PARK, ...
