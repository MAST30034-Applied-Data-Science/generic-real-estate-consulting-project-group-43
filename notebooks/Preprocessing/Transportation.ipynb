# %%
import pandas as pd
df_train = pd.read_csv("../../data/raw/train_raw.csv")
df_tram = pd.read_csv("../../data/raw/tram_raw.csv")

# %%
df_tram.head()
# Out:
#    Unnamed: 0  STOP_ID                                STOP_NAME   LATITUDE  \
# 0           0    18730  134-Merribell Ave/Nicholson St (Coburg) -37.744359
# 1           1    18732  44-Deepdene Park/Whitehorse Rd (Balwyn) -37.811375
# 2           2    18733   45-Hardwicke St/Whitehorse Rd (Balwyn) -37.811750
# 3           3    18734  46-Balwyn Cinema/Whitehorse Rd (Balwyn) -37.812242
# 4           4    18735      47-Balwyn Rd/Whitehorse Rd (Balwyn) -37.812919
#
#     LONGITUDE TICKETZONE ROUTEUSSP  \
# 0  144.977728          1         1
# 1  145.068671          1       109
# 2  145.071785          1       109
# 3  145.075930          1       109
# 4  145.081524        1,2       109
#
#                                         geometry  postcode    suburb
# 0  POINT (144.97773390165608 -37.74434586797992)      3058    COBURG
# 1   POINT (145.0686770785946 -37.81136185463405)      3103  DEEPDENE
# 2  POINT (145.07179107801323 -37.81173688485068)      3103  DEEPDENE
# ...

# %%
df_train.head()
# Out:
#    Unnamed: 0    STATION  STATUS  STOPID_MTR  STID_VLINE PREMIUM METRO VLINE  \
# 0           0  Dandenong  Active     19888.0     22250.0     Yes   Yes   Yes
# 1           1    Darebin  Active     19932.0         NaN      No   Yes    No
# 2           2    Darling  Active     19837.0         NaN     Yes   Yes    No
# 3           3  Deer Park  Active         NaN     19982.0      No    No   Yes
# 4           4     Dennis  Active     19929.0         NaN      No   Yes    No
#
#   INTERSTATE STOP_ZONE           COMMENTS  \
# 0         No    Reg, 2  Metro Interchange
# 1         No         1                NaN
# 2         No      1, 2                NaN
# 3         No    Reg, 2                NaN
# 4         No         1                NaN
#
#                                          geometry  postcode        suburb
# 0   POINT (145.20964487441773 -37.98992085547722)      3175     DANDENONG
# 1  POINT (145.03862792779512 -37.774802842342275)      3079       IVANHOE
# ...
