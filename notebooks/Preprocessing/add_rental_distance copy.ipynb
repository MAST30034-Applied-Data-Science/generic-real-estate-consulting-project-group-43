# 1002                       $620_weekly  ApartmentUnitFlat
# 1003                     $700_per_week  ApartmentUnitFlat
# 1004                   $650PW_$2824PCM  ApartmentUnitFlat
# 1005                     $400_per_week  ApartmentUnitFlat
# 1006                              $550              House
# 1007                     $550_per_week  ApartmentUnitFlat
# 1008                     $400_Per_Week  ApartmentUnitFlat
# 1009                           $550.00  ApartmentUnitFlat
# 1010                       $520_weekly  ApartmentUnitFlat
# 1011                           $800_pw  ApartmentUnitFlat
# 1012                              $620  ApartmentUnitFlat
# 1013                     $800_per_week  ApartmentUnitFlat
# 1014                       $460_weekly  ApartmentUnitFlat
# 1015                   $620PW_$2694PCM  ApartmentUnitFlat
# 1016                              $450  ApartmentUnitFlat
# 1017                     $720_per_week  ApartmentUnitFlat
# 1018                           $580.00  ApartmentUnitFlat
# 1019                       $420_weekly  ApartmentUnitFlat
# 1020                       $595_weekly  ApartmentUnitFlat
# 1021                           $580.00  ApartmentUnitFlat
# 1022                     $495_per_week  ApartmentUnitFlat
# 1023                              $650  ApartmentUnitFlat
# 1024                              $620  ApartmentUnitFlat
# 1025                              $570  ApartmentUnitFlat
# 1026                       $580_weekly  ApartmentUnitFlat
# 1027                     $480_per_week  ApartmentUnitFlat
# 1028                     $650_Per_Week  ApartmentUnitFlat
# 1029   $620_per_week_*Fully_Furnished*  ApartmentUnitFlat
# 1030                     $580_per_week  ApartmentUnitFlat
# 1031                     $500_per_week  ApartmentUnitFlat
# 1032                   $450_per_weekly  ApartmentUnitFlat
# 1033                              $580  ApartmentUnitFlat
# 1034                     $430_per_week  ApartmentUnitFlat
# 1035                $450/w_Unfurnished  ApartmentUnitFlat
# 1036                     $650_per_week  ApartmentUnitFlat
# 1037                              $800  ApartmentUnitFlat
# 1038                     $440_per_week  ApartmentUnitFlat
# 1039                              $600  ApartmentUnitFlat
# 1040                     $620_Per_Week  ApartmentUnitFlat
# 1041                             $1100  ApartmentUnitFlat
# 1042                     $380_PER_WEEK  ApartmentUnitFlat
# 1043                              $650  ApartmentUnitFlat
# 1044                           $480_pw  ApartmentUnitFlat
# 1045                     $800_per_week  ApartmentUnitFlat
# 1046                              $520  ApartmentUnitFlat
# 1047  $660_pw_*Multiple_Apts_Available  ApartmentUnitFlat
# 1048                     $900_per_week  ApartmentUnitFlat
# 1049                     $600_per_week  ApartmentUnitFlat
#
#                                        area  building_area  land_area  \
# 1000  Melbourne City Council - Greater Area            0.0        0.0
# 1001  Melbourne City Council - Greater Area            0.0        0.0
# 1002  Melbourne City Council - Greater Area            0.0        0.0
# 1003  Melbourne City Council - Greater Area            0.0        0.0
# 1004  Melbourne City Council - Greater Area            0.0        0.0
# 1005  Melbourne City Council - Greater Area            0.0        0.0
# 1006  Melbourne City Council - Greater Area            0.0        0.0
# 1007  Melbourne City Council - Greater Area            0.0        0.0
# 1008  Melbourne City Council - Greater Area            0.0        0.0
# 1009  Melbourne City Council - Greater Area            0.0        0.0
# 1010  Melbourne City Council - Greater Area            0.0        0.0
# 1011  Melbourne City Council - Greater Area            0.0        0.0
#        [-37.8145638, 144.95228600000002,
#         '1211/260 Spencer Street, Melbourne'],
#        [-37.81068, 144.959274, '504/350 La Trobe Street, Melbourne'],
#        ...,
#        [-38.628715500000006, 145.73580900000002,
#         '14 Inverloch Parade, Inverloch'],
#        [-38.6341248, 145.730682, '10 Hopetoun Street, Inverloch'],
#        [-38.63146210000001, 145.72937, 'Inverloch']], dtype=object)

# %%
import geopy
from geopy.geocoders import GoogleV3
import googlemaps
import re

# %%
def rowwise_driving_distance(origin_latitude, origin_longitude, gmaps, pattern, destination_latitude, destination_longitude):
    driving_distance_matrix = gmaps.distance_matrix([str(origin_latitude) + " " + str(origin_longitude)], [str(destination_latitude) + " " + str(destination_longitude)], mode='driving')
    return pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['distance']['text'])[0])

def rowwise_driving_time(origin_latitude, origin_longitude, gmaps, destination_latitude, destination_longitude):
    driving_distance_matrix = gmaps.distance_matrix([str(origin_latitude) + " " + str(origin_longitude)], [str(destination_latitude) + " " + str(destination_longitude)], mode='driving')
    return pd.to_numeric(driving_distance_matrix['rows'][0]['elements'][0]['duration']['value'])

def rowwise_walking_distance(origin_latitude, origin_longitude, gmaps, pattern, destination_latitude, destination_longitude):
    walking_distance_matrix = gmaps.distance_matrix([str(origin_latitude) + " " + str(origin_longitude)], [str(destination_latitude) + " " + str(destination_longitude)], mode='walking')
    return pd.to_numeric(pattern.findall(walking_distance_matrix['rows'][0]['elements'][0]['distance']['text'])[0])  

def rowwise_walking_time(origin_latitude, origin_longitude, gmaps, destination_latitude, destination_longitude):
    walking_distance_matrix = gmaps.distance_matrix([str(origin_latitude) + " " + str(origin_longitude)], [str(destination_latitude) + " " + str(destination_longitude)], mode='walking')
    return pd.to_numeric(walking_distance_matrix['rows'][0]['elements'][0]['duration']['value'])

# %%
import swifter
"""This function takes in a property csv (pandas dataframe) file, and compute distance, time for each property location to Melbourne CBD, using 
the latitude and longitude of each property, and return the imputed csv file"""
def add_distance(property_csv):
    # convert to dict for faster computation
    #property_dict = property_csv[['latitude', 'longitude', 'street_address']].to_dict('records')
    #property_list = property[['latitude', 'longitude', 'street_address']].to_numpy()
    pattern = re.compile(r'\d+.?\d?') # get only numeric distance or time value
    destination_latitude, destination_longitude = -37.810454, 144.962379 # melbourne central latitude and longitude
    gmaps = googlemaps.Client(key='AIzaSyCSmyP2Pxq7lMHE7w27m2he1l-RtreJdAQ') # Philip's api, please don't overuse

    property_csv['dri_dist_km'] = property_csv.swifter.apply(lambda x: rowwise_driving_distance(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
    property_csv['dri_time_sec'] = property_csv.swifter.apply(lambda x: rowwise_driving_time(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
    property_csv['dri_time_min'] = property_csv['dri_time_sec'] / 60
    property_csv['walk_dist_km'] = property_csv.swifter.apply(lambda x: rowwise_walking_distance(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
    property_csv['walk_time_sec'] = property_csv.swifter.apply(lambda x: rowwise_walking_time(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
    property_csv['walk_time_min'] = property_csv['walk_time_sec'] / 60
    
    return property_csv

# %%
import swifter
df['new'] = df.swifter.apply(lambda x : func(x['a'],x['b'],x['c'],x['d'],x['e']),axis=1)

"""This function takes in a property csv (pandas dataframe) file, and compute distance, time for each property location to Melbourne CBD, using 
the latitude and longitude of each property, and return the imputed csv file"""
def add_distance(property_csv):
    # convert to dict for faster computation
    property_dict = property_csv[['latitude', 'longitude', 'street_address']].to_dict('records')
    #property_list = property[['latitude', 'longitude', 'street_address']].to_numpy()
    pattern = re.compile(r'\d+.?\d?') # get only numeric distance or time value
    destination_latitude, destination_longitude = -37.810454, 144.962379 # melbourne central latitude and longitude
    gmaps = googlemaps.Client(key='AIzaSyCSmyP2Pxq7lMHE7w27m2he1l-RtreJdAQ') # Philip's api, please don't overuse
    driving_distance_list_km = []
    driving_time_list_mins = []
    walking_distance_list_km = []
    walking_time_list_mins = []        
    i=0
    for row in property_dict:
        print(f"Row {i}, location {row['street_address']}")
        origin_latitude, origin_longitude = row['latitude'], row['longitude']
        #print(f"Row {i}, location {row[2]}")
        #origin_latitude, origin_longitude = row[0], row[1]

        driving_distance_matrix = gmaps.distance_matrix([str(origin_latitude) + " " + str(origin_longitude)], [str(destination_latitude) + " " + str(destination_longitude)], mode='driving')
        walking_distance_matrix = gmaps.distance_matrix([str(origin_latitude) + " " + str(origin_longitude)], [str(destination_latitude) + " " + str(destination_longitude)], mode='walking')
        
        # individual values
        driving_distance_km = pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['distance']['text'])[0])
        driving_time_mins = pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['duration']['text'])[0])
        walking_distance_km = pd.to_numeric(pattern.findall(walking_distance_matrix['rows'][0]['elements'][0]['distance']['text'])[0])
        walking_time_mins = pd.to_numeric(pattern.findall(walking_distance_matrix['rows'][0]['elements'][0]['duration']['text'])[0])

        # store values to corresponding list
        driving_distance_list_km.append(driving_distance_km)
        driving_time_list_mins.append(driving_time_mins)
        walking_distance_list_km.append(walking_distance_km)
        walking_time_list_mins.append(walking_time_mins)

        i += 1
    property_csv['dri_dist_km'] = driving_distance_list_km
    property_csv['dri_time_min'] = driving_time_list_mins
    property_csv['dri_time_sec'] = property_csv['dri_time_min'] / 60
    property_csv['walk_dist_km'] = walking_distance_list_km
    property_csv['walk_time_min'] = walking_time_list_mins
    property_csv['walk_time_sec'] = property_csv['walk_time_min'] / 60
    
    return property_csv

# %%
def add_distance(row, gmaps, pattern):
    driving_distance_matrix = gmaps.distance_matrix([str(row['latitude']) + " " + str(row['longitude'])], [str(-37.810454) + " " + str(144.962379)], mode='driving')
    walking_distance_matrix = gmaps.distance_matrix([str(row['latitude']) + " " + str(row['longitude'])], [str(-37.810454) + " " + str(144.962379)], mode='walking')
    print(driving_distance_matrix)    
    # individual values
    #row['dri_dist_km'] = pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['distance']['text'])[0])
    #row['dri_time_sec'] = pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['duration']['value']))
    #row['dri_time_min'] = row['dri_time_sec'] / 60

    #row['walk_dist_km'] = pd.to_numeric(pattern.findall(walking_distance_matrix['rows'][0]['elements'][0]['distance']['text'])[0])
    #row['walk_time_sec'] = pd.to_numeric(pattern.findall(walking_distance_matrix['rows'][0]['elements'][0]['duration']['value']))
    #row['walk_time_min'] = row['walk_time_sec'] / 60
    
    return pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['distance']['text'])[0])

# %%
# %%time
gmaps = googlemaps.Client(key='AIzaSyCSmyP2Pxq7lMHE7w27m2he1l-RtreJdAQ') # Philip's api, please don't overuse
pattern = re.compile(r'\d+.?\d?') # get only numeric distance or time value
property['dri_dist_km'] = property.swifter.apply(add_distance, args=[gmaps, pattern] axis=1)
property.iloc[1000:1030, :]
# Out:
# Pandas Apply:   0%|          | 0/14694 [00:00<?, ?it/s]
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['238-242 Flinders St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.6 km', 'value': 1609}, 'duration': {'text': '7 mins', 'value': 449}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['260 Spencer St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.3 km', 'value': 1280}, 'duration': {'text': '6 mins', 'value': 356}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['303/350 La Trobe St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.4 km', 'value': 382}, 'duration': {'text': '2 mins', 'value': 115}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['1108/555 Flinders St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '2.4 km', 'value': 2419}, 'duration': {'text': '12 mins', 'value': 709}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['3603/200 Spencer St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.5 km', 'value': 1455}, 'duration': {'text': '7 mins', 'value': 421}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['464 Collins St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.3 km', 'value': 1270}, 'duration': {'text': '6 mins', 'value': 349}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['37 Queen St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.6 km', 'value': 1578}, 'duration': {'text': '7 mins', 'value': 441}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['118 Franklin St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.5 km', 'value': 501}, 'duration': {'text': '3 mins', 'value': 194}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['118 Russell St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.0 km', 'value': 988}, 'duration': {'text': '5 mins', 'value': 281}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ["Unit 3005/120 A'Beckett St, Melbourne VIC 3000, Australia"], 'rows': [{'elements': [{'distance': {'text': '0.3 km', 'value': 300}, 'duration': {'text': '2 mins', 'value': 141}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['296 Flinders St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.1 km', 'value': 1063}, 'duration': {'text': '7 mins', 'value': 412}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['268 State Route 30, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.2 km', 'value': 1152}, 'duration': {'text': '7 mins', 'value': 434}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ["81 A'Beckett St, Melbourne VIC 3000, Australia"], 'rows': [{'elements': [{'distance': {'text': '0.2 km', 'value': 232}, 'duration': {'text': '2 mins', 'value': 109}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['464 Collins St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.3 km', 'value': 1266}, 'duration': {'text': '6 mins', 'value': 348}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['87 Franklin St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.4 km', 'value': 442}, 'duration': {'text': '3 mins', 'value': 177}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['225 Elizabeth St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.9 km', 'value': 869}, 'duration': {'text': '5 mins', 'value': 270}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['325 Collins St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.2 km', 'value': 1193}, 'duration': {'text': '5 mins', 'value': 320}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['500 Elizabeth St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.4 km', 'value': 424}, 'duration': {'text': '3 mins', 'value': 155}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['Unit 615/339 Swanston St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.9 km', 'value': 853}, 'duration': {'text': '5 mins', 'value': 301}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': 
Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.5 km', 'value': 1524}, 'duration': {'text': '7 mins', 'value': 429}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['3603/200 Spencer St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.5 km', 'value': 1455}, 'duration': {'text': '7 mins', 'value': 421}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['25 Therry St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.5 km', 'value': 543}, 'duration': {'text': '3 mins', 'value': 208}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['639 Little Lonsdale St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.1 km', 'value': 1101}, 'duration': {'text': '6 mins', 'value': 339}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['5/10 Bligh Pl, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.3 km', 'value': 1314}, 'duration': {'text': '6 mins', 'value': 367}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['340 Russell St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.5 km', 'value': 473}, 'duration': {'text': '2 mins', 'value': 125}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['268 State Route 30, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.2 km', 'value': 1152}, 'duration': {'text': '7 mins', 'value': 434}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['565 Flinders St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '2.3 km', 'value': 2258}, 'duration': {'text': '10 mins', 'value': 597}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['457 Elizabeth St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.7 km', 'value': 747}, 'duration': {'text': '3 mins', 'value': 193}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['19 Rose Ln, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.5 km', 'value': 1528}, 'duration': {'text': '7 mins', 'value': 431}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['380 Little Lonsdale St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.8 km', 'value': 790}, 'duration': {'text': '4 mins', 'value': 259}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['462 Elizabeth St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.1 km', 'value': 1090}, 'duration': {'text': '6 mins', 'value': 356}, 'status': 'OK'}]}], 'status': 'OK'}
# ...
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['2605/155 Franklin St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.7 km', 'value': 680}, 'duration': {'text': '3 mins', 'value': 174}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['2605/155 Franklin St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.7 km', 'value': 680}, 'duration': {'text': '3 mins', 'value': 174}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['560 Lonsdale St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '0.9 km', 'value': 920}, 'duration': {'text': '4 mins', 'value': 253}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['3003/38 Rose Ln, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.6 km', 'value': 1620}, 'duration': {'text': '8 mins', 'value': 464}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ["135 A'Beckett St, Melbourne VIC 3000, Australia"], 'rows': [{'elements': [{'distance': {'text': '0.3 km', 'value': 324}, 'duration': {'text': '2 mins', 'value': 149}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['108 Flinders St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '1.6 km', 'value': 1625}, 'duration': {'text': '7 mins', 'value': 439}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['565 Flinders St, Melbourne VIC 3000, Australia'], 'rows': [{'elements': [{'distance': {'text': '2.3 km', 'value': 2258}, 'duration': {'text': '10 mins', 'value': 597}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ['Ground Floor, 360 St Kilda Rd, Melbourne VIC 3004, Australia'], 'rows': [{'elements': [{'distance': {'text': '3.2 km', 'value': 3163}, 'duration': {'text': '12 mins', 'value': 718}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['LG29, Melbourne Central, Swanston St, Melbourne VIC 3000, Australia'], 'origin_addresses': ["181 A'Beckett St, Melbourne VIC 3000, Australia"], 'rows': [{'elements': [{'distance': {'text': '0.5 km', 'value': 465}, 'duration': {'text': '2 mins', 'value': 144}, 'status': 'OK'}]}], 'status': 'OK'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1, in <module>
#
# File ~/.local/lib/python3.8/site-packages/swifter/swifter.py:451, in DataFrameAccessor.apply(self, func, axis, raw, result_type, args, **kwds)
#     448 else:
#     449     apply_func = self._obj.apply
# --> 451 return apply_func(func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds)
#
# File ~/.local/lib/python3.8/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# -> 8845 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/apply.py:857, in FrameApply.apply_standard(self)
#     856 def apply_standard(self):
# --> 857     results, res_index = self.apply_series_generator()
#     859     # wrap results
#     860     return self.wrap_results(results, res_index)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/apply.py:873, in FrameApply.apply_series_generator(self)
#     870 with option_context("mode.chained_assignment", None):
#     871     for i, v in enumerate(series_gen):
#     872         # ignore SettingWithCopy here in case the user mutates
# --> 873         results[i] = self.f(v)
#     874         if isinstance(results[i], ABCSeries):
#     875             # If we have a view on v, we need to make a copy because
#     876             #  series_generator will swap out the underlying data
#     877             results[i] = results[i].copy(deep=False)
#
# File ~/.local/lib/python3.8/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# File <timed exec>:1, in <lambda>(x)
#
# /home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance copy.ipynb Cell 10 in add_distance(latitude, longitude)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> pattern = re.compile(r'\d+.?\d?') # get only numeric distance or time value
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> driving_distance_matrix = gmaps.distance_matrix([str(latitude) + " " + str(longitude)], [str(-37.810454) + " " + str(144.962379)], mode='driving')
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> walking_distance_matrix = gmaps.distance_matrix([str(latitude) + " " + str(longitude)], [str(-37.810454) + " " + str(144.962379)], mode='walking')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> print(driving_distance_matrix)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> # individual values
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> #row['dri_dist_km'] = pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['distance']['text'])[0])
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> #row['dri_time_sec'] = pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['duration']['value']))
#    (...)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> #row['walk_time_sec'] = pd.to_numeric(pattern.findall(walking_distance_matrix['rows'][0]['elements'][0]['duration']['value']))
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> #row['walk_time_min'] = row['walk_time_sec'] / 60
#
# File ~/.local/lib/python3.8/site-packages/googlemaps/client.py:420, in make_api_method.<locals>.wrapper(*args, **kwargs)
#     417 @functools.wraps(func)
#     418 def wrapper(*args, **kwargs):
#     419     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 420     result = func(*args, **kwargs)
#     421     try:
#     422         del args[0]._extra_params
#
# File ~/.local/lib/python3.8/site-packages/googlemaps/distance_matrix.py:139, in distance_matrix(client, origins, destinations, mode, language, avoid, units, departure_time, arrival_time, transit_mode, transit_routing_preference, traffic_model, region)
#     136 if region:
#     137     params["region"] = region
# --> 139 return client._request("/maps/api/distancematrix/json", params)
#
# File ~/.local/lib/python3.8/site-packages/googlemaps/client.py:290, in Client._request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     287     final_requests_kwargs["json"] = post_json
#     289 try:
# --> 290     response = requests_method(base_url + authed_url,
#     291                                **final_requests_kwargs)
#     292 except requests.exceptions.Timeout:
#     293     raise googlemaps.exceptions.Timeout()
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:555, in Session.get(self, url, **kwargs)
#     547 r"""Sends a GET request. Returns :class:`Response` object.
#     548
#     549 :param url: URL for the new :class:`Request` object.
#     550 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     551 :rtype: requests.Response
#     552 """
#     554 kwargs.setdefault('allow_redirects', True)
# --> 555 return self.request('GET', url, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     537 send_kwargs = {
#     538     'timeout': timeout,
#     539     'allow_redirects': allow_redirects,
#     540 }
#     541 send_kwargs.update(settings)
# --> 542 resp = self.send(prep, **send_kwargs)
#     544 return resp
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:655, in Session.send(self, request, **kwargs)
#     652 start = preferred_clock()
#     654 # Send the request
# --> 655 r = adapter.send(request, **kwargs)
#     657 # Total elapsed time of the request (approximately)
#     658 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.8/site-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File /usr/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /usr/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# %%time
gmaps = googlemaps.Client(key='AIzaSyCSmyP2Pxq7lMHE7w27m2he1l-RtreJdAQ') # Philip's api, please don't overuse
driving_distance_matrix = gmaps.distance_matrix([str(property[['latitude']]) + " " + str(property[['longitude']])], [str(-37.810454) + " " + str(144.962379)], mode='driving')
driving_distance_matrix
# Out:
# CPU times: user 28.1 ms, sys: 614 µs, total: 28.7 ms
# Wall time: 299 ms
# {'destination_addresses': ['-37.810454,144.962379'],
#  'origin_addresses': ['Rochester, NY 14692, USA'],
#  'rows': [{'elements': [{'status': 'ZERO_RESULTS'}]}],
#  'status': 'OK'}

# %%
# %%time
new_property = add_distance(property)
new_property.iloc[1000:1050, :]
# Out:
# Pandas Apply:   0%|          | 0/14694 [00:00<?, ?it/s]
# Pandas Apply:   0%|          | 0/14694 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1, in <module>
#
# /home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance copy.ipynb Cell 9 in add_distance(property_csv)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> gmaps = googlemaps.Client(key='AIzaSyCSmyP2Pxq7lMHE7w27m2he1l-RtreJdAQ') # Philip's api, please don't overuse
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> property_csv['dri_dist_km'] = property_csv.swifter.apply(lambda x: rowwise_driving_distance(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> property_csv['dri_time_mins'] = property_csv.swifter.apply(lambda x: rowwise_driving_time(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> property_csv['walk_dist_km'] = property_csv.swifter.apply(lambda x: rowwise_walking_distance(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> property_csv['walk_time_mins'] = property_csv.swifter.apply(lambda x: rowwise_walking_time(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
#
# File ~/.local/lib/python3.8/site-packages/swifter/swifter.py:451, in DataFrameAccessor.apply(self, func, axis, raw, result_type, args, **kwds)
#     448 else:
#     449     apply_func = self._obj.apply
# --> 451 return apply_func(func, axis=axis, raw=raw, result_type=result_type, args=args, **kwds)
#
# File ~/.local/lib/python3.8/site-packages/tqdm/std.py:814, in tqdm.pandas.<locals>.inner_generator.<locals>.inner(df, func, *args, **kwargs)
#     811 # Apply the provided function (in **kwargs)
#     812 # on the df using our wrapper (which provides bar updating)
#     813 try:
# --> 814     return getattr(df, df_function)(wrapper, **kwargs)
#     815 finally:
#     816     t.close()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# -> 8845 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/apply.py:857, in FrameApply.apply_standard(self)
#     856 def apply_standard(self):
# --> 857     results, res_index = self.apply_series_generator()
#     859     # wrap results
#     860     return self.wrap_results(results, res_index)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/apply.py:873, in FrameApply.apply_series_generator(self)
#     870 with option_context("mode.chained_assignment", None):
#     871     for i, v in enumerate(series_gen):
#     872         # ignore SettingWithCopy here in case the user mutates
# --> 873         results[i] = self.f(v)
#     874         if isinstance(results[i], ABCSeries):
#     875             # If we have a view on v, we need to make a copy because
#     876             #  series_generator will swap out the underlying data
#     877             results[i] = results[i].copy(deep=False)
#
# File ~/.local/lib/python3.8/site-packages/tqdm/std.py:809, in tqdm.pandas.<locals>.inner_generator.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     803 def wrapper(*args, **kwargs):
#     804     # update tbar correctly
#     805     # it seems `pandas apply` calls `func` twice
#     806     # on the first column/row to decide whether it can
#     807     # take a fast or slow code path; so stop when t.total==t.n
#     808     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 809     return func(*args, **kwargs)
#
# /home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance copy.ipynb Cell 9 in add_distance.<locals>.<lambda>(x)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> gmaps = googlemaps.Client(key='AIzaSyCSmyP2Pxq7lMHE7w27m2he1l-RtreJdAQ') # Philip's api, please don't overuse
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> property_csv['dri_dist_km'] = property_csv.swifter.apply(lambda x: rowwise_driving_distance(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> property_csv['dri_time_mins'] = property_csv.swifter.apply(lambda x: rowwise_driving_time(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> property_csv['walk_dist_km'] = property_csv.swifter.apply(lambda x: rowwise_walking_distance(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> property_csv['walk_time_mins'] = property_csv.swifter.apply(lambda x: rowwise_walking_time(x['latitude'], x['longitude'], gmaps, pattern, destination_latitude, destination_longitude), axis=1)
#
# /home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance copy.ipynb Cell 9 in rowwise_driving_time(origin_latitude, origin_longitude, gmaps, pattern, destination_latitude, destination_longitude)
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> def rowwise_driving_time(origin_latitude, origin_longitude, gmaps, pattern, destination_latitude, destination_longitude):
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>     driving_distance_matrix = gmaps.distance_matrix([str(origin_latitude) + " " + str(origin_longitude)], [str(destination_latitude) + " " + str(destination_longitude)], mode='driving')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/phikhocaz/Applied_DS/generic-real-estate-consulting-project-group-43/notebooks/Preprocessing/add_rental_distance%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     return pd.to_numeric(pattern.findall(driving_distance_matrix['rows'][0]['elements'][0]['duration']['text'])[0])
#
# File ~/.local/lib/python3.8/site-packages/googlemaps/client.py:420, in make_api_method.<locals>.wrapper(*args, **kwargs)
#     417 @functools.wraps(func)
#     418 def wrapper(*args, **kwargs):
#     419     args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 420     result = func(*args, **kwargs)
#     421     try:
#     422         del args[0]._extra_params
#
# File ~/.local/lib/python3.8/site-packages/googlemaps/distance_matrix.py:139, in distance_matrix(client, origins, destinations, mode, language, avoid, units, departure_time, arrival_time, transit_mode, transit_routing_preference, traffic_model, region)
#     136 if region:
#     137     params["region"] = region
# --> 139 return client._request("/maps/api/distancematrix/json", params)
#
# File ~/.local/lib/python3.8/site-packages/googlemaps/client.py:290, in Client._request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     287     final_requests_kwargs["json"] = post_json
#     289 try:
# --> 290     response = requests_method(base_url + authed_url,
#     291                                **final_requests_kwargs)
#     292 except requests.exceptions.Timeout:
#     293     raise googlemaps.exceptions.Timeout()
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:555, in Session.get(self, url, **kwargs)
#     547 r"""Sends a GET request. Returns :class:`Response` object.
#     548
#     549 :param url: URL for the new :class:`Request` object.
#     550 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     551 :rtype: requests.Response
#     552 """
#     554 kwargs.setdefault('allow_redirects', True)
# --> 555 return self.request('GET', url, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     537 send_kwargs = {
#     538     'timeout': timeout,
#     539     'allow_redirects': allow_redirects,
#     540 }
#     541 send_kwargs.update(settings)
# --> 542 resp = self.send(prep, **send_kwargs)
#     544 return resp
#
# File ~/.local/lib/python3.8/site-packages/requests/sessions.py:655, in Session.send(self, request, **kwargs)
#     652 start = preferred_clock()
#     654 # Send the request
# --> 655 r = adapter.send(request, **kwargs)
#     657 # Total elapsed time of the request (approximately)
#     658 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.8/site-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /usr/lib/python3.8/http/client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File /usr/lib/python3.8/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /usr/lib/python3.8/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /usr/lib/python3.8/socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# File /usr/lib/python3.8/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.8/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#gmaps.distance_matrix(property.iloc[1:]['street_address'], 'Melbourne Central')
origin_latitude, origin_longitude = property.iloc[8]['latitude'], property.iloc[8]['longitude']
destination_latitude, destination_longitude = -37.810454, 144.962379 # melbourne central
distance = gmaps.distance_matrix([str(origin_latitude) + " " + str(origin_longitude)], [str(destination_latitude) + " " + str(destination_longitude)], mode='driving')
#gmaps.distance_matrix('1216/628 Flinders Street','Melbourne Central', mode='driving')
#distance['rows'][0]['elements'][0]['distance']
distance
pattern = re.compile(r'\d+.?\d?')
pd.to_numeric(pattern.findall(distance['rows'][0]['elements'][0]['distance']['text'])[0])
pd.to_numeric(pattern.findall(distance['rows'][0]['elements'][0]['duration']['text'])[0])
# Out:
# 5
