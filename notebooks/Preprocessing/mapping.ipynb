# %%
import pandas as pd

# %% [markdown]
# Read csv files

# %%
path = '../../data/curated/min_distance/'
filename = '_min_distance.csv'
COL = ['address', 'postcode', 'SA2_CODE', 'residence_type', 
        'nbed', 'nbath', 'ncar', 'weekly_rent', 'dist_to_cbd_KM', 
        'min_distance_to_park', 'min_distance_to_prim', 'min_distance_to_second', 
        'min_distance_to_train', 'min_distance_to_hosp', 'min_distance_to_poli', 'min_distance_to_shop']
# 'year', 'month', 'latitude_ori', 'longitude_ori',

rent = {}
for y in range(2013, 2023):
    rent[str(y)] = pd.read_csv('../../data/curated/min_distance/'+str(y)+filename)
    #rent[str(y)] = rent[str(y)][COL]

# %%
rent['2018']
# Out:
#                                                 address  nbed  nbath  ncar  \
# 0                         - GOUGHS BAY ROAD, GOUGHS BAY   3.0    2.0     2
# 1                . 'WILLOW COTTAGE' TARCOMBE RD, AVENEL   3.0    1.0     1
# 2              . 'WILLOW COTTAGE' TARCOMBE ROAD, AVENEL   3.0    1.0     1
# 3                 . SHERBROOK LODGE ROAD, PORT CAMPBELL   3.0    1.0     0
# 4      . U0027WILLOW COTTAGEU0027 TARCOMBE ROAD, AVENEL   3.0    1.0     1
# ...                                                 ...   ...    ...   ...
# 14203         UNITS 1-11/279 WYNDHAM STREET, SHEPPARTON   1.0    1.0     0
# 14204                            VICTORY AVENUE, FOSTER   1.0    1.0     1
# 14205               VILLA 6/1-5 CANAL ROAD, PAYNESVILLE   3.0    1.0     1
# 14206                             WELSHPOOL ROAD, TOORA   4.0    1.0     1
# 14207                          WOORARRA ROAD, WELSHPOOL   3.0    1.0     4
#
#        postcode   SA2_CODE residence_type  dist_to_cbd_KM  \
# ...
