# %% [markdown]
# ### ``Important:`` Only reproduce (Run All) this when the API's have been restored with at least 5000 total calls
# ### Use ``Open Route Service API`` to retrieve distance matrix (Iterative version)
# #### Quota 500 per client per day, approx 1 year of merged rental-place dataset per client.

# %%
import pandas as pd
import sys
import os
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '../../scripts/')
import openrouteservice as ors
from add_distance import add_distance_time

# %% [markdown]
# ### The whole Place dataset from 2013 to 2021

# %%
if not os.path.exists('../../data/featured'):
    os.makedirs('../../data/featured')
PLACE_COLS = ['Place_Names', 'latitude', 'longitude', 'year', 'place_type', 'SA2_CODE']
place_df = pd.read_csv('../../data/curated/features_of_interst/place_all_with_sa2.csv')[PLACE_COLS]
print(place_df.shape)
place_df.head(10)
# Out:
# (70444, 6)
#                          Place_Names  latitude  longitude  year place_type  \
# 0  TAHARA BRIDGE RESERVE PICNIC AREA -37.66568  141.66459  2013       park
# 1          CULGOA RECREATION RESERVE -35.71682  143.10101  2013       park
# 2                         CUMBERLAND -38.57263  143.94681  2013       park
# 3                       WAREENA PARK -36.35911  146.30977  2013       park
# 4                    ENTERPRIZE PARK -37.82000  144.95973  2013       park
# 5                      RYANS RESERVE -37.66807  145.15741  2013       park
# 6       FERNTREE GULLY PICNIC GROUND -37.89088  145.31692  2013       park
# 7            LORRAINE KOVACS RESERVE -37.97763  145.25403  2013       park
# 8                 RAY BASTIN RESERVE -38.03359  145.30791  2013       park
# 9           NEVILLE HAMILTON RESERVE -38.02612  145.34533  2013       park
#
#     SA2_CODE
# 0  217011420
# 1  215031400
# 2  203031049
# 3  204021066
# 4  206041505
# 5  209031215
# 6  211051282
# 7  212021454
# 8  212021456
# 9  212021293

# %%
# columns of interest in property dataset
PROPERTY_COLS = ['address', 'latitude', 'longitude', 'nbed', 'nbath', 'ncar', 'weekly_rent', 'type', 'postcode', 'year', 'month', 'residence_type', 'SA2_CODE']

# %%
# Test the quota status of this API key
#locations = [(144.204874, -37.088043), (144.962379, -37.810454)]
#sources = [0]
#destinations = [1]

# add back 2013, 2014 for reproduction
YEARS = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021] # 2022 do separately
client_index = 0 # check this back to 0
for year in YEARS:
    # update client settings
    client1 = ors.Client('5b3ce3597851110001cf6248b55ae99fc05b4e5d80e222bbbe04657d') # Philly's api key 500
    client2 = ors.Client('5b3ce3597851110001cf6248e33707f5c3914f39b4671bac87646ac7') # Phikho's api key 500
    client3 = ors.Client('5b3ce3597851110001cf6248e33390389e0b4e0292fb3dcd2dec286b') # Phikhocaz's api key 500
    client4 = ors.Client('5b3ce3597851110001cf62488fd6bd483e964233809653e71984440a') # jonghop api key 500
    client5 = ors.Client('5b3ce3597851110001cf62482d289033372149f7b6419d839d18a3dc') # gracelovesyah api key 500 
    client6 = ors.Client('5b3ce3597851110001cf62488fb71274f7ac4b2ca2c679bedd963683') # gracelovesyah1 api key 500
    client7 = ors.Client('5b3ce3597851110001cf6248768e34108776435cabbcffaf2fb63a60') # kakakkaa api key 500
    client8 = ors.Client('5b3ce3597851110001cf624851a53f74cc8e4c6c9e751bb8aee27e05') # hyunjinp api key 500
    client9 = ors.Client('5b3ce3597851110001cf6248ce6c95ac96814219a4c3a7741f323b73') # Phikho-caz's api key 2500, back up for at least 4 full year
    client_list = [client1, client2, client3, client4, client5, client6, client7, client8, client9]
    
    place_sample = place_df[place_df['year'] == year] # place df of selected year
    place_sample = place_sample.drop_duplicates(subset=['Place_Names', 'latitude']).reset_index(drop=True)   
    property_df = pd.read_csv(f"../../data/curated/property_all_with_SA2/{year}_property_with_SA2.csv")[PROPERTY_COLS] # property df of selected year
    print(f"Year {year} place sample = {place_sample.shape}")
    print(f"Client {client_index} property df = {property_df.shape}")
    # merge the place df and property df
    merged_df = property_df.merge(place_sample, how='inner', on='SA2_CODE')
    merged_df = merged_df.rename(columns={'latitude_x': 'latitude_ori', 'longitude_x': 'longitude_ori', 'latitude_y': 'latitude_des', 'longitude_y': 'longitude_des', 'year_x': 'year'})
    merged_df.drop('year_y', axis=1, inplace=True)
    print(f"merged df has shape {merged_df.shape}")
    
    client = client_list[client_index]
    added_distance_merged_df = add_distance_time(merged_df, year, client, 'saving')
    print(f"Year {year} completed, distance added dataset has shape {added_distance_merged_df.shape}")
    client_index += 1 # each client is approximately responsible for a year
# Out:
# Year 2013 place sample = (5928, 6)
# Client 0 property df = (11466, 13)
# merged df has shape (153849, 17)
# Executing SA2 Code 202021027
# Subset size = 210, Places count = 10, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 210
# Executing SA2 Code 204031070
# Subset size = 56, Places count = 8, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 266
# Executing SA2 Code 211051275
# Subset size = 14, Places count = 2, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 280
# Executing SA2 Code 209031212
# Subset size = 575, Places count = 25, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 855
# Executing SA2 Code 211051276
# Subset size = 440, Places count = 20, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 1295
# Executing SA2 Code 205041094
# Subset size = 986, Places count = 34, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 2281
# Executing SA2 Code 201021012
# Subset size = 286, Places count = 22, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 2567
# Executing SA2 Code 212041309
# Subset size = 14, Places count = 2, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 2581
# Executing SA2 Code 212051567
# Subset size = 145, Places count = 5, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 2726
# Executing SA2 Code 212041310
# Subset size = 64, Places count = 8, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 2790
# Executing SA2 Code 212051568
# Subset size = 198, Places count = 6, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 2988
# Executing SA2 Code 212011289
# Subset size = 608, Places count = 16, Property count = 38
# To Place Distance Grand List, Normal Branch, length = 3596
# Executing SA2 Code 205021082
# Subset size = 2640, Places count = 44, Property count = 60
# To Place Distance Grand List, Normal Branch, length = 6236
# Executing SA2 Code 206071145
# Subset size = 598, Places count = 13, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 6834
# Executing SA2 Code 203031048
# Subset size = 6, Places count = 3, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 6840
# Executing SA2 Code 209041224
# Subset size = 180, Places count = 10, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 7020
# Executing SA2 Code 201021010
# Subset size = 1188, Places count = 33, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 8208
# Executing SA2 Code 212031303
# Subset size = 280, Places count = 5, Property count = 56
# To Place Distance Grand List, Normal Branch, length = 8488
# Executing SA2 Code 201021011
# Subset size = 1674, Places count = 27, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 10162
# Executing SA2 Code 217031475
# Subset size = 840, Places count = 28, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 11002
# Executing SA2 Code 216021411
# Subset size = 8, Places count = 8, Property count = 1
# To Place Distance Grand List, Normal Branch, length = 11010
# Executing SA2 Code 210031236
# Subset size = 98, Places count = 14, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 11108
# Executing SA2 Code 206011497
# Subset size = 777, Places count = 21, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 11885
# Executing SA2 Code 206011498
# Subset size = 286, Places count = 13, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 12171
# Executing SA2 Code 213051368
# Subset size = 507, Places count = 13, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 12678
# Executing SA2 Code 213051468
# Subset size = 130, Places count = 13, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 12808
# Executing SA2 Code 215031401
# Subset size = 98, Places count = 49, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 12906
# Executing SA2 Code 213041353
# Subset size = 300, Places count = 15, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 13206
# Executing SA2 Code 217031472
# Subset size = 112, Places count = 14, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 13318
# Executing SA2 Code 217031473
# Subset size = 320, Places count = 20, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 13638
# Executing SA2 Code 216011410
# Subset size = 567, Places count = 21, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 14205
# Executing SA2 Code 211051278
# Subset size = 338, Places count = 13, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 14543
# Executing SA2 Code 217011423
# Subset size = 280, Places count = 40, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 14823
# Executing SA2 Code 206071141
# Subset size = 54, Places count = 2, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 14877
# Executing SA2 Code 206071142
# Subset size = 230, Places count = 5, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 15107
# Executing SA2 Code 216031418
# Subset size = 456, Places count = 24, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 15563
# Executing SA2 Code 203021044
# Subset size = 22, Places count = 2, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 15585
# Executing SA2 Code 203031489
# Subset size = 140, Places count = 5, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 15725
# Executing SA2 Code 203031053
# Subset size = 357, Places count = 7, Property count = 51
# To Place Distance Grand List, Normal Branch, length = 16082
# Executing SA2 Code 210051243
# Subset size = 221, Places count = 13, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 16303
# Executing SA2 Code 216031419
# Subset size = 714, Places count = 34, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 17017
# Executing SA2 Code 205051101
# Subset size = 999, Places count = 27, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 18016
# Executing SA2 Code 212011547
# Subset size = 360, Places count = 15, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 18376
# Executing SA2 Code 205031093
# Subset size = 3468, Places count = 34, Property count = 102
# To Place Distance Grand List, Slice Branch, length = 20110
# To Place Distance Grand List, Slice Branch, length = 21844
# Executing SA2 Code 203021486
# Subset size = 225, Places count = 15, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 22069
# Executing SA2 Code 205031091
# Subset size = 504, Places count = 9, Property count = 56
# To Place Distance Grand List, Normal Branch, length = 22573
# Executing SA2 Code 205051102
# Subset size = 196, Places count = 14, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 22769
# Executing SA2 Code 201031017
# Subset size = 484, Places count = 22, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 23253
# Executing SA2 Code 210051443
# Subset size = 21, Places count = 3, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 23274
# Executing SA2 Code 210051543
# Subset size = 8, Places count = 1, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 23282
# Executing SA2 Code 210051441
# Subset size = 4, Places count = 1, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 23286
# Executing SA2 Code 210051442
# Subset size = 18, Places count = 3, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 23304
# Executing SA2 Code 212031557
# Subset size = 12, Places count = 2, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 23316
# Executing SA2 Code 212031559
# Subset size = 7, Places count = 1, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 23323
# Executing SA2 Code 212031560
# Subset size = 28, Places count = 4, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 23351
# Executing SA2 Code 212031300
# Subset size = 261, Places count = 9, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 23612
# Executing SA2 Code 213041462
# Subset size = 79, Places count = 1, Property count = 79
# To Place Distance Grand List, Normal Branch, length = 23691
# Executing SA2 Code 207031166
# Subset size = 180, Places count = 12, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 23871
# Executing SA2 Code 207031165
# Subset size = 198, Places count = 9, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 24069
# Executing SA2 Code 212051319
# Subset size = 430, Places count = 10, Property count = 43
# To Place Distance Grand List, Normal Branch, length = 24499
# Executing SA2 Code 217041479
# Subset size = 270, Places count = 15, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 24769
# Executing SA2 Code 204011054
# Subset size = 1064, Places count = 38, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 25833
# Executing SA2 Code 215021396
# Subset size = 270, Places count = 15, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 26103
# Executing SA2 Code 213011329
# Subset size = 45, Places count = 9, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 26148
# Executing SA2 Code 202011019
# Subset size = 216, Places count = 12, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 26364
# Executing SA2 Code 207011149
# Subset size = 520, Places count = 13, Property count = 40
# To Place Distance Grand List, Normal Branch, length = 26884
# Executing SA2 Code 207011150
# Subset size = 242, Places count = 11, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 27126
# Executing SA2 Code 206041505
# Subset size = 162, Places count = 6, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 27288
# Executing SA2 Code 206041504
# Subset size = 39, Places count = 3, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 27327
# Executing SA2 Code 206041503
# Subset size = 44, Places count = 4, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 27371
# Executing SA2 Code 206041118
# Subset size = 374, Places count = 11, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 27745
# Executing SA2 Code 213041578
# Subset size = 48, Places count = 6, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 27793
# Executing SA2 Code 213041358
# Subset size = 21, Places count = 3, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 27814
# Executing SA2 Code 213041577
# Subset size = 64, Places count = 2, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 27878
# Executing SA2 Code 208031190
# Subset size = 259, Places count = 7, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 28137
# Executing SA2 Code 211051274
# Subset size = 576, Places count = 18, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 28713
# Executing SA2 Code 217041477
# Subset size = 1248, Places count = 39, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 29961
# Executing SA2 Code 203011035
# Subset size = 306, Places count = 17, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 30267
# Executing SA2 Code 209041531
# Subset size = 4, Places count = 1, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 30271
# Executing SA2 Code 204031071
# Subset size = 196, Places count = 14, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 30467
# Executing SA2 Code 214021379
# Subset size = 1540, Places count = 28, Property count = 55
# To Place Distance Grand List, Normal Branch, length = 32007
# Executing SA2 Code 214021378
# Subset size = 516, Places count = 12, Property count = 43
# To Place Distance Grand List, Normal Branch, length = 32523
# Executing SA2 Code 205021084
# Subset size = 378, Places count = 14, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 32901
# Executing SA2 Code 202021029
# Subset size = 48, Places count = 6, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 32949
# Executing SA2 Code 206051128
# Subset size = 1391, Places count = 13, Property count = 107
# To Place Distance Grand List, Normal Branch, length = 34340
# Executing SA2 Code 206051514
# Subset size = 399, Places count = 7, Property count = 57
# To Place Distance Grand List, Normal Branch, length = 34739
# Executing SA2 Code 204021067
# Subset size = 1216, Places count = 38, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 35955
# Executing SA2 Code 215021469
# Subset size = 352, Places count = 11, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 36307
# Executing SA2 Code 215021470
# Subset size = 156, Places count = 6, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 36463
# Executing SA2 Code 209041220
# Subset size = 17, Places count = 1, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 36480
# Executing SA2 Code 209041221
# Subset size = 20, Places count = 1, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 36500
# Executing SA2 Code 211051286
# Subset size = 2368, Places count = 32, Property count = 74
# To Place Distance Grand List, Normal Branch, length = 38868
# Executing SA2 Code 217011420
# Subset size = 2622, Places count = 57, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 41490
# Executing SA2 Code 203021042
# Subset size = 192, Places count = 12, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 41682
# Executing SA2 Code 204031069
# Subset size = 868, Places count = 31, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 42550
# Executing SA2 Code 211051285
# Subset size = 75, Places count = 5, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 42625
# Executing SA2 Code 201011005
# Subset size = 115, Places count = 5, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 42740
# Executing SA2 Code 204021066
# Subset size = 558, Places count = 18, Property count = 31
# To Place Distance Grand List, Normal Branch, length = 43298
# Executing SA2 Code 211011260
# Subset size = 99, Places count = 9, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 43397
# Executing SA2 Code 211011259
# Subset size = 168, Places count = 8, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 43565
# Executing SA2 Code 205031087
# Subset size = 1911, Places count = 39, Property count = 49
# To Place Distance Grand List, Normal Branch, length = 45476
# Executing SA2 Code 212031308
# Subset size = 100, Places count = 5, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 45576
# Executing SA2 Code 215011394
# Subset size = 1550, Places count = 62, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 47126
# Executing SA2 Code 205011079
# Subset size = 810, Places count = 27, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 47936
# Executing SA2 Code 211021262
# Subset size = 72, Places count = 12, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 48008
# Executing SA2 Code 211031265
# Subset size = 210, Places count = 14, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 48218
# Executing SA2 Code 204021064
# Subset size = 736, Places count = 23, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 48954
# Executing SA2 Code 201011481
# Subset size = 532, Places count = 14, Property count = 38
# To Place Distance Grand List, Normal Branch, length = 49486
# Executing SA2 Code 217041480
# Subset size = 165, Places count = 15, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 49651
# Executing SA2 Code 215031400
# Subset size = 952, Places count = 56, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 50603
# Executing SA2 Code 208031183
# Subset size = 32, Places count = 2, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 50635
# Executing SA2 Code 209011204
# Subset size = 56, Places count = 7, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 50691
# Executing SA2 Code 210021232
# Subset size = 91, Places count = 7, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 50782
# Executing SA2 Code 210051245
# Subset size = 322, Places count = 14, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 51104
# Executing SA2 Code 208021182
# Subset size = 408, Places count = 6, Property count = 68
# To Place Distance Grand List, Normal Branch, length = 51512
# Executing SA2 Code 208021176
# Subset size = 268, Places count = 4, Property count = 67
# To Place Distance Grand List, Normal Branch, length = 51780
# Executing SA2 Code 208041194
# Subset size = 1650, Places count = 22, Property count = 75
# To Place Distance Grand List, Normal Branch, length = 53430
# Executing SA2 Code 212051322
# Subset size = 288, Places count = 9, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 53718
# Executing SA2 Code 212051321
# Subset size = 486, Places count = 18, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 54204
# Executing SA2 Code 204011060
# Subset size = 35, Places count = 7, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 54239
# Executing SA2 Code 204011062
# Subset size = 210, Places count = 21, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 54449
# Executing SA2 Code 202011018
# Subset size = 1508, Places count = 13, Property count = 116
# To Place Distance Grand List, Normal Branch, length = 55957
# Executing SA2 Code 205021086
# Subset size = 60, Places count = 3, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 56017
# Executing SA2 Code 208021426
# Subset size = 84, Places count = 6, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 56101
# Executing SA2 Code 208021427
# Subset size = 180, Places count = 12, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 56281
# Executing SA2 Code 208021174
# Subset size = 224, Places count = 4, Property count = 56
# To Place Distance Grand List, Normal Branch, length = 56505
# Executing SA2 Code 205031090
# Subset size = 152, Places count = 19, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 56657
# Executing SA2 Code 212021554
# Subset size = 14, Places count = 1, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 56671
# Executing SA2 Code 212021293
# Subset size = 740, Places count = 20, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 57411
# Executing SA2 Code 212021553
# Subset size = 64, Places count = 4, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 57475
# Executing SA2 Code 204031072
# Subset size = 481, Places count = 37, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 57956
# Executing SA2 Code 215031405
# Subset size = 1500, Places count = 50, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 59456
# Executing SA2 Code 202011022
# Subset size = 495, Places count = 11, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 59951
# Executing SA2 Code 203031049
# Subset size = 414, Places count = 9, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 60365
# Executing SA2 Code 201011482
# Subset size = 663, Places count = 17, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 61028
# Executing SA2 Code 208011173
# Subset size = 656, Places count = 16, Property count = 41
# To Place Distance Grand List, Normal Branch, length = 61684
# Executing SA2 Code 207031161
# Subset size = 567, Places count = 21, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 62251
# Executing SA2 Code 207031162
# Subset size = 72, Places count = 8, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 62323
# Executing SA2 Code 201021009
# Subset size = 88, Places count = 11, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 62411
# Executing SA2 Code 206071139
# Subset size = 78, Places count = 6, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 62489
# Executing SA2 Code 206031501
# Subset size = 328, Places count = 8, Property count = 41
# To Place Distance Grand List, Normal Branch, length = 62817
# Executing SA2 Code 210011226
# Subset size = 95, Places count = 5, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 62912
# Executing SA2 Code 213011333
# Subset size = 110, Places count = 11, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 63022
# Executing SA2 Code 213011328
# Subset size = 130, Places count = 13, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 63152
# Executing SA2 Code 201011001
# Subset size = 30, Places count = 2, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 63182
# Executing SA2 Code 205011078
# Subset size = 432, Places count = 18, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 63614
# Executing SA2 Code 206021110
# Subset size = 128, Places count = 4, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 63742
# Executing SA2 Code 213021343
# Subset size = 814, Places count = 22, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 64556
# Executing SA2 Code 213021342
# Subset size = 455, Places count = 13, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 65011
# Executing SA2 Code 213021341
# Subset size = 805, Places count = 23, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 65816
# Executing SA2 Code 202021026
# Subset size = 405, Places count = 15, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 66221
# Executing SA2 Code 203021040
# Subset size = 660, Places count = 10, Property count = 66
# To Place Distance Grand List, Normal Branch, length = 66881
# Executing SA2 Code 204011057
# Subset size = 240, Places count = 24, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 67121
# Executing SA2 Code 217031476
# Subset size = 720, Places count = 16, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 67841
# Executing SA2 Code 213031349
# Subset size = 594, Places count = 11, Property count = 54
# To Place Distance Grand List, Normal Branch, length = 68435
# Executing SA2 Code 205021085
# Subset size = 832, Places count = 52, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 69267
# Executing SA2 Code 203021485
# Subset size = 6, Places count = 1, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 69273
# Executing SA2 Code 201031016
# Subset size = 50, Places count = 25, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 69323
# Executing SA2 Code 214021384
# Subset size = 420, Places count = 10, Property count = 42
# To Place Distance Grand List, Normal Branch, length = 69743
# Executing SA2 Code 205051104
# Subset size = 770, Places count = 35, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 70513
# Executing SA2 Code 210051247
# Subset size = 24, Places count = 3, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 70537
# Executing SA2 Code 209031215
# Subset size = 240, Places count = 12, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 70777
# Executing SA2 Code 201031013
# Subset size = 230, Places count = 23, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 71007
# Executing SA2 Code 203021487
# Subset size = 85, Places count = 5, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 71092
# Executing SA2 Code 202031033
# Subset size = 594, Places count = 66, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 71686
# Executing SA2 Code 202021028
# Subset size = 1020, Places count = 30, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 72706
# Executing SA2 Code 201011008
# Subset size = 390, Places count = 13, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 73096
# Executing SA2 Code 213051467
# Subset size = 207, Places count = 9, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 73303
# Executing SA2 Code 213031351
# Subset size = 297, Places count = 9, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 73600
# Executing SA2 Code 206041510
# Subset size = 36, Places count = 3, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 73636
# Executing SA2 Code 203031490
# Subset size = 112, Places count = 8, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 73748
# Executing SA2 Code 216011406
# Subset size = 578, Places count = 17, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 74326
# Executing SA2 Code 212051327
# Subset size = 228, Places count = 12, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 74554
# Executing SA2 Code 202011025
# Subset size = 390, Places count = 13, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 74944
# Executing SA2 Code 203021045
# Subset size = 90, Places count = 6, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 75034
# Executing SA2 Code 210021235
# Subset size = 40, Places count = 8, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 75074
# Executing SA2 Code 213011569
# Subset size = 288, Places count = 16, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 75362
# Executing SA2 Code 201011006
# Subset size = 9, Places count = 3, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 75371
# Executing SA2 Code 213011331
# Subset size = 64, Places count = 4, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 75435
# Executing SA2 Code 215011387
# Subset size = 282, Places count = 47, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 75717
# Executing SA2 Code 213011570
# Subset size = 28, Places count = 7, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 75745
# Executing SA2 Code 217031474
# Subset size = 420, Places count = 28, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 76165
# Executing SA2 Code 210041540
# Subset size = 117, Places count = 9, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 76282
# Executing SA2 Code 215011390
# Subset size = 1242, Places count = 46, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 77524
# Executing SA2 Code 205031089
# Subset size = 1305, Places count = 29, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 78829
# Executing SA2 Code 210031537
# Subset size = 45, Places count = 9, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 78874
# Executing SA2 Code 210031538
# Subset size = 300, Places count = 15, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 79174
# Executing SA2 Code 212051326
# Subset size = 649, Places count = 11, Property count = 59
# To Place Distance Grand List, Normal Branch, length = 79823
# Executing SA2 Code 212011546
# Subset size = 56, Places count = 7, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 79879
# Executing SA2 Code 211051282
# Subset size = 1144, Places count = 26, Property count = 44
# To Place Distance Grand List, Normal Branch, length = 81023
# Executing SA2 Code 216031594
# Subset size = 552, Places count = 12, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 81575
# Executing SA2 Code 215021398
# Subset size = 480, Places count = 48, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 82055
# Executing SA2 Code 212011552
# Subset size = 120, Places count = 6, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 82175
# Executing SA2 Code 212011548
# Subset size = 112, Places count = 16, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 82287
# Executing SA2 Code 212011551
# Subset size = 6, Places count = 1, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 82293
# Executing SA2 Code 205051100
# Subset size = 198, Places count = 9, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 82491
# Executing SA2 Code 215011391
# Subset size = 372, Places count = 31, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 82863
# Executing SA2 Code 211021261
# Subset size = 36, Places count = 9, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 82899
# Executing SA2 Code 208031193
# Subset size = 578, Places count = 17, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 83477
# Executing SA2 Code 206041124
# Subset size = 76, Places count = 4, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 83553
# Executing SA2 Code 212041460
# Subset size = 252, Places count = 7, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 83805
# Executing SA2 Code 212041459
# Subset size = 380, Places count = 10, Property count = 38
# To Place Distance Grand List, Normal Branch, length = 84185
# Executing SA2 Code 205011077
# Subset size = 759, Places count = 33, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 84944
# Executing SA2 Code 203021488
# Subset size = 84, Places count = 7, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 85028
# Executing SA2 Code 203021047
# Subset size = 1104, Places count = 16, Property count = 69
# To Place Distance Grand List, Normal Branch, length = 86132
# Executing SA2 Code 206041506
# Subset size = 244, Places count = 4, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 86376
# Executing SA2 Code 209031214
# Subset size = 52, Places count = 4, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 86428
# Executing SA2 Code 206021499
# Subset size = 297, Places count = 9, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 86725
# Executing SA2 Code 206021500
# Subset size = 312, Places count = 12, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 87037
# Executing SA2 Code 201011484
# Subset size = 155, Places count = 5, Property count = 31
# To Place Distance Grand List, Normal Branch, length = 87192
# Executing SA2 Code 204011056
# Subset size = 112, Places count = 7, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 87304
# Executing SA2 Code 204011061
# Subset size = 6, Places count = 2, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 87310
# Executing SA2 Code 209021523
# Subset size = 156, Places count = 6, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 87466
# Executing SA2 Code 209021526
# Subset size = 408, Places count = 12, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 87874
# Executing SA2 Code 209021525
# Subset size = 145, Places count = 5, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 88019
# Executing SA2 Code 209021524
# Subset size = 40, Places count = 10, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 88059
# Executing SA2 Code 206071518
# Subset size = 348, Places count = 12, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 88407
# Executing SA2 Code 206071517
# Subset size = 585, Places count = 13, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 88992
# Executing SA2 Code 211031267
# Subset size = 540, Places count = 20, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 89532
# Executing SA2 Code 211031268
# Subset size = 196, Places count = 14, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 89728
# Executing SA2 Code 211031266
# Subset size = 705, Places count = 15, Property count = 47
# To Place Distance Grand List, Normal Branch, length = 90433
# Executing SA2 Code 205011076
# Subset size = 221, Places count = 17, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 90654
# Executing SA2 Code 206051134
# Subset size = 75, Places count = 5, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 90729
# Executing SA2 Code 209041432
# Subset size = 98, Places count = 7, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 90827
# Executing SA2 Code 209041431
# Subset size = 40, Places count = 5, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 90867
# Executing SA2 Code 210011230
# Subset size = 96, Places count = 6, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 90963
# Executing SA2 Code 206031502
# Subset size = 390, Places count = 10, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 91353
# Executing SA2 Code 212021295
# Subset size = 24, Places count = 24, Property count = 1
# To Place Distance Grand List, Normal Branch, length = 91377
# Executing SA2 Code 204011055
# Subset size = 84, Places count = 21, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 91461
# Executing SA2 Code 213041573
# Subset size = 2, Places count = 1, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 91463
# Executing SA2 Code 210031237
# Subset size = 168, Places count = 12, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 91631
# Executing SA2 Code 211011447
# Subset size = 180, Places count = 15, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 91811
# Executing SA2 Code 211011448
# Subset size = 140, Places count = 14, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 91951
# Executing SA2 Code 206071143
# Subset size = 399, Places count = 7, Property count = 57
# To Place Distance Grand List, Normal Branch, length = 92350
# Executing SA2 Code 201011007
# Subset size = 55, Places count = 5, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 92405
# Executing SA2 Code 217031471
# Subset size = 21, Places count = 7, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 92426
# Executing SA2 Code 201011483
# Subset size = 1110, Places count = 15, Property count = 74
# To Place Distance Grand List, Normal Branch, length = 93536
# Executing SA2 Code 207011155
# Subset size = 350, Places count = 10, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 93886
# Executing SA2 Code 201031015
# Subset size = 500, Places count = 20, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 94386
# Executing SA2 Code 215021399
# Subset size = 55, Places count = 11, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 94441
# Executing SA2 Code 206071140
# Subset size = 324, Places count = 6, Property count = 54
# To Place Distance Grand List, Normal Branch, length = 94765
# Executing SA2 Code 206041117
# Subset size = 320, Places count = 8, Property count = 40
# To Place Distance Grand List, Normal Branch, length = 95085
# Executing SA2 Code 213041463
# Subset size = 76, Places count = 4, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 95161
# Executing SA2 Code 213041360
# Subset size = 18, Places count = 2, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 95179
# Executing SA2 Code 216021413
# Subset size = 1961, Places count = 37, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 97140
# Executing SA2 Code 214021385
# Subset size = 357, Places count = 21, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 97497
# Executing SA2 Code 211031263
# Subset size = 18, Places count = 3, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 97515
# Executing SA2 Code 211011251
# Subset size = 200, Places count = 10, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 97715
# Executing SA2 Code 201031014
# Subset size = 248, Places count = 31, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 97963
# Executing SA2 Code 208011168
# Subset size = 147, Places count = 7, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 98110
# Executing SA2 Code 204031068
# Subset size = 70, Places count = 7, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 98180
# Executing SA2 Code 209011199
# Subset size = 232, Places count = 8, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 98412
# Executing SA2 Code 203021037
# Subset size = 300, Places count = 15, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 98712
# Executing SA2 Code 204021063
# Subset size = 48, Places count = 3, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 98760
# Executing SA2 Code 202011020
# Subset size = 132, Places count = 2, Property count = 66
# To Place Distance Grand List, Normal Branch, length = 98892
# Executing SA2 Code 202011021
# Subset size = 318, Places count = 6, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 99210
# Executing SA2 Code 213031347
# Subset size = 700, Places count = 25, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 99910
# Executing SA2 Code 203021039
# Subset size = 760, Places count = 19, Property count = 40
# To Place Distance Grand List, Normal Branch, length = 100670
# Executing SA2 Code 209011202
# Subset size = 490, Places count = 14, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 101160
# Executing SA2 Code 208011170
# Subset size = 297, Places count = 9, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 101457
# Executing SA2 Code 208011169
# Subset size = 715, Places count = 13, Property count = 55
# To Place Distance Grand List, Normal Branch, length = 102172
# Executing SA2 Code 210051242
# Subset size = 198, Places count = 18, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 102370
# Executing SA2 Code 206011106
# Subset size = 294, Places count = 14, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 102664
# Executing SA2 Code 206011496
# Subset size = 968, Places count = 22, Property count = 44
# To Place Distance Grand List, Normal Branch, length = 103632
# Executing SA2 Code 206011107
# Subset size = 688, Places count = 16, Property count = 43
# To Place Distance Grand List, Normal Branch, length = 104320
# Executing SA2 Code 206011495
# Subset size = 160, Places count = 8, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 104480
# Executing SA2 Code 203021043
# Subset size = 180, Places count = 12, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 104660
# Executing SA2 Code 204011058
# Subset size = 168, Places count = 14, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 104828
# Executing SA2 Code 210011533
# Subset size = 50, Places count = 5, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 104878
# Executing SA2 Code 202031032
# Subset size = 285, Places count = 19, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 105163
# Executing SA2 Code 205021081
# Subset size = 160, Places count = 10, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 105323
# Executing SA2 Code 201011002
# Subset size = 784, Places count = 14, Property count = 56
# To Place Distance Grand List, Normal Branch, length = 106107
# Executing SA2 Code 216011408
# Subset size = 147, Places count = 21, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 106254
# Executing SA2 Code 207011148
# Subset size = 495, Places count = 11, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 106749
# Executing SA2 Code 207011147
# Subset size = 243, Places count = 9, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 106992
# Executing SA2 Code 204031491
# Subset size = 216, Places count = 18, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 107208
# Executing SA2 Code 212041566
# Subset size = 18, Places count = 3, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 107226
# Executing SA2 Code 203011034
# Subset size = 10, Places count = 2, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 107236
# Executing SA2 Code 209041225
# Subset size = 77, Places count = 7, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 107313
# Executing SA2 Code 210041240
# Subset size = 20, Places count = 4, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 107333
# Executing SA2 Code 210051246
# Subset size = 12, Places count = 4, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 107345
# Executing SA2 Code 213051363
# Subset size = 280, Places count = 10, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 107625
# Executing SA2 Code 213021346
# Subset size = 1197, Places count = 19, Property count = 63
# To Place Distance Grand List, Normal Branch, length = 108822
# Executing SA2 Code 213021344
# Subset size = 1278, Places count = 18, Property count = 71
# To Place Distance Grand List, Normal Branch, length = 110100
# Executing SA2 Code 203011036
# Subset size = 168, Places count = 12, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 110268
# Executing SA2 Code 206061136
# Subset size = 909, Places count = 9, Property count = 101
# To Place Distance Grand List, Normal Branch, length = 111177
# Executing SA2 Code 208031191
# Subset size = 210, Places count = 14, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 111387
# Executing SA2 Code 204031073
# Subset size = 1159, Places count = 61, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 112546
# Executing SA2 Code 204031492
# Subset size = 2100, Places count = 70, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 114646
# Executing SA2 Code 209041437
# Subset size = 1, Places count = 1, Property count = 1
# To Place Distance Grand List, Normal Branch, length = 114647
# Executing SA2 Code 207021424
# Subset size = 108, Places count = 6, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 114755
# Executing SA2 Code 207021425
# Subset size = 126, Places count = 7, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 114881
# Executing SA2 Code 207021157
# Subset size = 280, Places count = 10, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 115161
# Executing SA2 Code 206011109
# Subset size = 18, Places count = 9, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 115179
# Executing SA2 Code 208031185
# Subset size = 120, Places count = 6, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 115299
# Executing SA2 Code 205051103
# Subset size = 765, Places count = 15, Property count = 51
# To Place Distance Grand List, Normal Branch, length = 116064
# Executing SA2 Code 209031211
# Subset size = 216, Places count = 8, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 116280
# Executing SA2 Code 202021030
# Subset size = 510, Places count = 17, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 116790
# Executing SA2 Code 209031213
# Subset size = 196, Places count = 7, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 116986
# Executing SA2 Code 213051580
# Subset size = 22, Places count = 2, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 117008
# Executing SA2 Code 213051466
# Subset size = 34, Places count = 2, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 117042
# Executing SA2 Code 213051464
# Subset size = 14, Places count = 2, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 117056
# Executing SA2 Code 203031052
# Subset size = 35, Places count = 7, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 117091
# Executing SA2 Code 206051130
# Subset size = 693, Places count = 9, Property count = 77
# To Place Distance Grand List, Normal Branch, length = 117784
# Executing SA2 Code 208031189
# Subset size = 230, Places count = 10, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 118014
# Executing SA2 Code 208021179
# Subset size = 59, Places count = 1, Property count = 59
# To Place Distance Grand List, Normal Branch, length = 118073
# Executing SA2 Code 209011197
# Subset size = 494, Places count = 19, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 118567
# Executing SA2 Code 209031209
# Subset size = 425, Places count = 17, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 118992
# Executing SA2 Code 206051129
# Subset size = 432, Places count = 4, Property count = 108
# To Place Distance Grand List, Normal Branch, length = 119424
# Executing SA2 Code 206051513
# Subset size = 342, Places count = 6, Property count = 57
# To Place Distance Grand List, Normal Branch, length = 119766
# Executing SA2 Code 212021454
# Subset size = 165, Places count = 11, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 119931
# Executing SA2 Code 212021453
# Subset size = 90, Places count = 9, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 120021
# Executing SA2 Code 212041317
# Subset size = 48, Places count = 12, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 120069
# Executing SA2 Code 213011335
# Subset size = 322, Places count = 23, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 120391
# Executing SA2 Code 213011334
# Subset size = 400, Places count = 16, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 120791
# Executing SA2 Code 204031075
# Subset size = 200, Places count = 10, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 120991
# Executing SA2 Code 202011024
# Subset size = 8, Places count = 1, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 120999
# Executing SA2 Code 210011231
# Subset size = 78, Places count = 6, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 121077
# Executing SA2 Code 216011409
# Subset size = 143, Places count = 11, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 121220
# Executing SA2 Code 212021455
# Subset size = 64, Places count = 4, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 121284
# Executing SA2 Code 212021456
# Subset size = 442, Places count = 17, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 121726
# Executing SA2 Code 215011389
# Subset size = 215, Places count = 43, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 121941
# Executing SA2 Code 205041095
# Subset size = 330, Places count = 30, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 122271
# Executing SA2 Code 203021046
# Subset size = 646, Places count = 17, Property count = 38
# To Place Distance Grand List, Normal Branch, length = 122917
# Executing SA2 Code 215021395
# Subset size = 120, Places count = 8, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 123037
# Executing SA2 Code 202021031
# Subset size = 12, Places count = 6, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 123049
# Executing SA2 Code 213051590
# Subset size = 21, Places count = 3, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 123070
# ...
# To Place Distance Grand List, Normal Branch, length = 420962
# Executing SA2 Code 208031188
# Subset size = 1144, Places count = 13, Property count = 88
# To Place Distance Grand List, Normal Branch, length = 422106
# Executing SA2 Code 208011171
# Subset size = 310, Places count = 10, Property count = 31
# To Place Distance Grand List, Normal Branch, length = 422416
# Executing SA2 Code 208031191
# Subset size = 784, Places count = 16, Property count = 49
# To Place Distance Grand List, Normal Branch, length = 423200
# Executing SA2 Code 211051281
# Subset size = 580, Places count = 20, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 423780
# Executing SA2 Code 216031415
# Subset size = 336, Places count = 12, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 424116
# Executing SA2 Code 214021591
# Subset size = 1296, Places count = 36, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 425412
# Executing SA2 Code 214021592
# Subset size = 1215, Places count = 27, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 426627
# Executing SA2 Code 205041096
# Subset size = 2405, Places count = 37, Property count = 65
# To Place Distance Grand List, Normal Branch, length = 429032
# Executing SA2 Code 213051582
# Subset size = 5, Places count = 1, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 429037
# Executing SA2 Code 214021381
# Subset size = 2624, Places count = 41, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 431661
# Executing SA2 Code 213041575
# Subset size = 528, Places count = 24, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 432189
# Executing SA2 Code 213011339
# Subset size = 868, Places count = 14, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 433057
# Executing SA2 Code 213051362
# Subset size = 651, Places count = 7, Property count = 93
# To Place Distance Grand List, Normal Branch, length = 433708
# Executing SA2 Code 213051361
# Subset size = 315, Places count = 5, Property count = 63
# To Place Distance Grand List, Normal Branch, length = 434023
# Executing SA2 Code 208021180
# Subset size = 195, Places count = 5, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 434218
# Executing SA2 Code 209031210
# Subset size = 290, Places count = 10, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 434508
# Executing SA2 Code 209011201
# Subset size = 88, Places count = 8, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 434596
# Executing SA2 Code 209011200
# Subset size = 804, Places count = 12, Property count = 67
# To Place Distance Grand List, Normal Branch, length = 435400
# Executing SA2 Code 211041270
# Subset size = 798, Places count = 14, Property count = 57
# To Place Distance Grand List, Normal Branch, length = 436198
# Executing SA2 Code 212011547
# Subset size = 1134, Places count = 18, Property count = 63
# To Place Distance Grand List, Normal Branch, length = 437332
# Executing SA2 Code 207031167
# Subset size = 350, Places count = 7, Property count = 50
# To Place Distance Grand List, Normal Branch, length = 437682
# Executing SA2 Code 211051280
# Subset size = 42, Places count = 6, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 437724
# Executing SA2 Code 206031116
# Subset size = 909, Places count = 9, Property count = 101
# To Place Distance Grand List, Normal Branch, length = 438633
# Executing SA2 Code 207011152
# Subset size = 1936, Places count = 16, Property count = 121
# To Place Distance Grand List, Normal Branch, length = 440569
# Executing SA2 Code 207011520
# Subset size = 1312, Places count = 16, Property count = 82
# To Place Distance Grand List, Normal Branch, length = 441881
# Executing SA2 Code 207011519
# Subset size = 546, Places count = 14, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 442427
# Executing SA2 Code 211051283
# Subset size = 189, Places count = 9, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 442616
# Executing SA2 Code 214021382
# Subset size = 1296, Places count = 36, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 443912
# Executing SA2 Code 212051323
# Subset size = 675, Places count = 15, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 444587
# Executing SA2 Code 212051325
# Subset size = 640, Places count = 10, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 445227
# Executing SA2 Code 208021181
# Subset size = 432, Places count = 9, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 445659
# Executing SA2 Code 210041540
# Subset size = 444, Places count = 12, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 446103
# Executing SA2 Code 210041541
# Subset size = 184, Places count = 8, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 446287
# Executing SA2 Code 213011337
# Subset size = 658, Places count = 14, Property count = 47
# To Place Distance Grand List, Normal Branch, length = 446945
# Executing SA2 Code 213011336
# Subset size = 2178, Places count = 22, Property count = 99
# To Place Distance Grand List, Normal Branch, length = 449123
# Executing SA2 Code 215031404
# Subset size = 700, Places count = 20, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 449823
# Executing SA2 Code 204011060
# Subset size = 28, Places count = 7, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 449851
# Executing SA2 Code 209041217
# Subset size = 192, Places count = 4, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 450043
# Executing SA2 Code 210031440
# Subset size = 95, Places count = 5, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 450138
# Executing SA2 Code 217011421
# Subset size = 256, Places count = 32, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 450394
# Executing SA2 Code 212031561
# Subset size = 123, Places count = 3, Property count = 41
# To Place Distance Grand List, Normal Branch, length = 450517
# Executing SA2 Code 212031562
# Subset size = 250, Places count = 5, Property count = 50
# To Place Distance Grand List, Normal Branch, length = 450767
# Executing SA2 Code 212021299
# Subset size = 28, Places count = 14, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 450795
# Executing SA2 Code 216011408
# Subset size = 63, Places count = 21, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 450858
# Executing SA2 Code 205041493
# Subset size = 450, Places count = 15, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 451308
# Executing SA2 Code 205041494
# Subset size = 540, Places count = 15, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 451848
# Executing SA2 Code 206031115
# Subset size = 820, Places count = 10, Property count = 82
# To Place Distance Grand List, Normal Branch, length = 452668
# Executing SA2 Code 213051588
# Subset size = 52, Places count = 2, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 452720
# Executing SA2 Code 213051586
# Subset size = 9, Places count = 1, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 452729
# Executing SA2 Code 210051250
# Subset size = 144, Places count = 3, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 452873
# Executing SA2 Code 216021412
# Subset size = 300, Places count = 20, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 453173
# Executing SA2 Code 205041098
# Subset size = 784, Places count = 16, Property count = 49
# To Place Distance Grand List, Normal Branch, length = 453957
# Executing SA2 Code 207021156
# Subset size = 234, Places count = 9, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 454191
# Executing SA2 Code 209011196
# Subset size = 370, Places count = 10, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 454561
# Executing SA2 Code 209041216
# Subset size = 122, Places count = 2, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 454683
# Executing SA2 Code 203021044
# Subset size = 144, Places count = 18, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 454827
# Executing SA2 Code 212041318
# Subset size = 14, Places count = 14, Property count = 1
# To Place Distance Grand List, Normal Branch, length = 454841
# Executing SA2 Code 213021345
# Subset size = 72, Places count = 3, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 454913
# Executing SA2 Code 214011375
# Subset size = 1680, Places count = 28, Property count = 60
# To Place Distance Grand List, Normal Branch, length = 456593
# Executing SA2 Code 214011372
# Subset size = 3471, Places count = 39, Property count = 89
# To Place Distance Grand List, Slice Branch, length = 458309
# To Place Distance Grand List, Slice Branch, length = 460064
# Executing SA2 Code 213031350
# Subset size = 183, Places count = 3, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 460247
# Executing SA2 Code 213031352
# Subset size = 3014, Places count = 22, Property count = 137
# To Place Distance Grand List, Normal Branch, length = 463261
# Executing SA2 Code 216031416
# Subset size = 2352, Places count = 28, Property count = 84
# To Place Distance Grand List, Normal Branch, length = 465613
# Executing SA2 Code 213011332
# Subset size = 1254, Places count = 19, Property count = 66
# To Place Distance Grand List, Normal Branch, length = 466867
# Executing SA2 Code 210011534
# Subset size = 363, Places count = 11, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 467230
# Executing SA2 Code 214011376
# Subset size = 64, Places count = 1, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 467294
# Executing SA2 Code 201011007
# Subset size = 24, Places count = 6, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 467318
# Executing SA2 Code 206041509
# Subset size = 20, Places count = 5, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 467338
# Executing SA2 Code 206051511
# Subset size = 126, Places count = 7, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 467464
# Executing SA2 Code 209041436
# Subset size = 9, Places count = 3, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 467473
# Executing SA2 Code 209041435
# Subset size = 21, Places count = 3, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 467494
# Executing SA2 Code 206051130
# Subset size = 783, Places count = 9, Property count = 87
# To Place Distance Grand List, Normal Branch, length = 468277
# Executing SA2 Code 217011422
# Subset size = 1020, Places count = 20, Property count = 51
# To Place Distance Grand List, Normal Branch, length = 469297
# Executing SA2 Code 209021429
# Subset size = 488, Places count = 8, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 469785
# Executing SA2 Code 209021428
# Subset size = 2000, Places count = 20, Property count = 100
# To Place Distance Grand List, Normal Branch, length = 471785
# Executing SA2 Code 215031403
# Subset size = 15, Places count = 5, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 471800
# Executing SA2 Code 211011256
# Subset size = 612, Places count = 9, Property count = 68
# To Place Distance Grand List, Normal Branch, length = 472412
# Executing SA2 Code 211011258
# Subset size = 222, Places count = 6, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 472634
# Executing SA2 Code 211011257
# Subset size = 51, Places count = 3, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 472685
# Executing SA2 Code 210051544
# Subset size = 217, Places count = 7, Property count = 31
# To Place Distance Grand List, Normal Branch, length = 472902
# Executing SA2 Code 210051545
# Subset size = 24, Places count = 2, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 472926
# Executing SA2 Code 214021377
# Subset size = 440, Places count = 20, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 473366
# Executing SA2 Code 216011407
# Subset size = 740, Places count = 20, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 474106
# Executing SA2 Code 209041530
# Subset size = 294, Places count = 7, Property count = 42
# To Place Distance Grand List, Normal Branch, length = 474400
# Executing SA2 Code 209041529
# Subset size = 156, Places count = 6, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 474556
# Executing SA2 Code 206041121
# Subset size = 1498, Places count = 14, Property count = 107
# To Place Distance Grand List, Normal Branch, length = 476054
# Executing SA2 Code 215031402
# Subset size = 144, Places count = 6, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 476198
# Executing SA2 Code 207011154
# Subset size = 63, Places count = 7, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 476261
# Executing SA2 Code 207011522
# Subset size = 624, Places count = 13, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 476885
# Executing SA2 Code 212041565
# Subset size = 357, Places count = 17, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 477242
# Executing SA2 Code 212041566
# Subset size = 132, Places count = 12, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 477374
# Executing SA2 Code 216031593
# Subset size = 75, Places count = 5, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 477449
# Executing SA2 Code 211051277
# Subset size = 228, Places count = 12, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 477677
# Executing SA2 Code 211031450
# Subset size = 966, Places count = 21, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 478643
# Executing SA2 Code 211041269
# Subset size = 135, Places count = 5, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 478778
# Executing SA2 Code 214011373
# Subset size = 629, Places count = 17, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 479407
# Executing SA2 Code 214011371
# Subset size = 2862, Places count = 27, Property count = 106
# To Place Distance Grand List, Normal Branch, length = 482269
# Executing SA2 Code 213051584
# Subset size = 4, Places count = 2, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 482273
# Executing SA2 Code 213051585
# Subset size = 6, Places count = 3, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 482279
# Executing SA2 Code 207021159
# Subset size = 350, Places count = 10, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 482629
# Executing SA2 Code 211011449
# Subset size = 160, Places count = 5, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 482789
# Executing SA2 Code 209041223
# Subset size = 869, Places count = 11, Property count = 79
# To Place Distance Grand List, Normal Branch, length = 483658
# Executing SA2 Code 211031452
# Subset size = 52, Places count = 4, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 483710
# Executing SA2 Code 211031451
# Subset size = 425, Places count = 25, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 484135
# Executing SA2 Code 210031535
# Subset size = 1258, Places count = 17, Property count = 74
# To Place Distance Grand List, Normal Branch, length = 485393
# Executing SA2 Code 207011146
# Subset size = 645, Places count = 15, Property count = 43
# To Place Distance Grand List, Normal Branch, length = 486038
# Executing SA2 Code 216021414
# Subset size = 121, Places count = 11, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 486159
# Year 2021 completed, distance added dataset has shape (486159, 25)
