# %% [markdown]
# ### ``Important:`` Only reproduce (Run All) this when the API's have been restored with at least 5000 total calls
# ### Use ``Open Route Service API`` to retrieve distance matrix (Iterative version)
# #### Quota 500 per client per day, approx 1 year of merged rental-place dataset per client.

# %%
import pandas as pd
import sys
import os
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '../../scripts/')
import openrouteservice as ors
from add_distance import add_distance_time

# %% [markdown]
# ### The whole Place dataset from 2013 to 2021

# %%
if not os.path.exists('../../data/featured'):
    os.makedirs('../../data/featured')
PLACE_COLS = ['Place_Names', 'latitude', 'longitude', 'year', 'place_type', 'SA2_CODE']
place_df = pd.read_csv('../../data/curated/features_of_interst/place_all_with_sa2.csv')[PLACE_COLS]
print(place_df.shape)
place_df.head(10)
# Out:
# (70444, 6)
#                          Place_Names  latitude  longitude  year place_type  \
# 0  TAHARA BRIDGE RESERVE PICNIC AREA -37.66568  141.66459  2013       park
# 1          CULGOA RECREATION RESERVE -35.71682  143.10101  2013       park
# 2                         CUMBERLAND -38.57263  143.94681  2013       park
# 3                       WAREENA PARK -36.35911  146.30977  2013       park
# 4                    ENTERPRIZE PARK -37.82000  144.95973  2013       park
# 5                      RYANS RESERVE -37.66807  145.15741  2013       park
# 6       FERNTREE GULLY PICNIC GROUND -37.89088  145.31692  2013       park
# 7            LORRAINE KOVACS RESERVE -37.97763  145.25403  2013       park
# 8                 RAY BASTIN RESERVE -38.03359  145.30791  2013       park
# 9           NEVILLE HAMILTON RESERVE -38.02612  145.34533  2013       park
#
#     SA2_CODE
# 0  217011420
# 1  215031400
# 2  203031049
# 3  204021066
# 4  206041505
# 5  209031215
# 6  211051282
# 7  212021454
# 8  212021456
# 9  212021293

# %%
# columns of interest in property dataset
PROPERTY_COLS = ['address', 'latitude', 'longitude', 'nbed', 'nbath', 'ncar', 'weekly_rent', 'type', 'postcode', 'year', 'month', 'residence_type', 'SA2_CODE']

# %%
# Test the quota status of this API key
#locations = [(144.204874, -37.088043), (144.962379, -37.810454)]
#sources = [0]
#destinations = [1]

# add back 2013, 2014 for reproduction
YEARS = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021] # 2022 do separately
client_index = 0 # check this back to 0
for year in YEARS:
    # update client settings
    client1 = ors.Client('5b3ce3597851110001cf6248301e2c7b55374eeea49e28cd5ae0ce4c') # Philly's api key 500
    client2 = ors.Client('5b3ce3597851110001cf6248e33707f5c3914f39b4671bac87646ac7') # Phikho's api key 500
    client3 = ors.Client('5b3ce3597851110001cf6248e33390389e0b4e0292fb3dcd2dec286b') # Phikhocaz's api key 500
    client4 = ors.Client('5b3ce3597851110001cf62488fd6bd483e964233809653e71984440a') # jonghop api key 500
    client5 = ors.Client('5b3ce3597851110001cf62482d289033372149f7b6419d839d18a3dc') # gracelovesyah api key 500 
    client6 = ors.Client('5b3ce3597851110001cf62488fb71274f7ac4b2ca2c679bedd963683') # gracelovesyah1 api key 500
    client7 = ors.Client('5b3ce3597851110001cf6248768e34108776435cabbcffaf2fb63a60') # kakakkaa api key 500
    client8 = ors.Client('5b3ce3597851110001cf624851a53f74cc8e4c6c9e751bb8aee27e05') # hyunjinp api key 500
    client9 = ors.Client('5b3ce3597851110001cf6248ce6c95ac96814219a4c3a7741f323b73') # Phikho-caz's api key 2500, back up for at least 4 full year
    client_list = [client1, client2, client3, client4, client5, client6, client7, client8, client9]
    
    place_sample = place_df[place_df['year'] == year] # place df of selected year
    place_sample = place_sample.drop_duplicates(subset=['Place_Names', 'latitude']).reset_index(drop=True)   
    property_df = pd.read_csv(f"../../data/curated/property_all_with_SA2/{year}_property_with_SA2.csv")[PROPERTY_COLS] # property df of selected year
    print(f"Year {year} place sample = {place_sample.shape}")
    print(f"Client {client_index} property df = {property_df.shape}")
    # merge the place df and property df
    merged_df = property_df.merge(place_sample, how='inner', on='SA2_CODE')
    merged_df = merged_df.rename(columns={'latitude_x': 'latitude_ori', 'longitude_x': 'longitude_ori', 'latitude_y': 'latitude_des', 'longitude_y': 'longitude_des', 'year_x': 'year'})
    merged_df.drop('year_y', axis=1, inplace=True)
    print(f"merged df has shape {merged_df.shape}")
    
    client = client_list[client_index]
    added_distance_merged_df = add_distance_time(merged_df, year, client, 'saving')
    print(f"Year {year} completed, distance added dataset has shape {added_distance_merged_df.shape}")
    client_index += 1 # each client is approximately responsible for a year
# Out:
# Year 2018 place sample = (8317, 6)
# Client 4 property df = (19604, 13)
# merged df has shape (373152, 17)
# Executing SA2 Code 202021027
# Subset size = 882, Places count = 14, Property count = 63
# To Place Distance Grand List, Normal Branch, length = 882
# Executing SA2 Code 205011078
# Subset size = 630, Places count = 21, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 1512
# Executing SA2 Code 204031070
# Subset size = 216, Places count = 9, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 1728
# Executing SA2 Code 211051275
# Subset size = 33, Places count = 3, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 1761
# Executing SA2 Code 209031212
# Subset size = 442, Places count = 26, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 2203
# Executing SA2 Code 211051276
# Subset size = 638, Places count = 22, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 2841
# Executing SA2 Code 205041094
# Subset size = 1599, Places count = 39, Property count = 41
# To Place Distance Grand List, Normal Branch, length = 4440
# Executing SA2 Code 201021012
# Subset size = 390, Places count = 26, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 4830
# Executing SA2 Code 212041309
# Subset size = 84, Places count = 3, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 4914
# Executing SA2 Code 210041240
# Subset size = 135, Places count = 9, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 5049
# Executing SA2 Code 212041310
# Subset size = 306, Places count = 9, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 5355
# Executing SA2 Code 212051568
# Subset size = 648, Places count = 9, Property count = 72
# To Place Distance Grand List, Normal Branch, length = 6003
# Executing SA2 Code 212051567
# Subset size = 165, Places count = 5, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 6168
# Executing SA2 Code 205021082
# Subset size = 5063, Places count = 61, Property count = 83
# To Place Distance Grand List, Slice Branch, length = 8669
# To Place Distance Grand List, Slice Branch, length = 11231
# Executing SA2 Code 206071145
# Subset size = 795, Places count = 15, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 12026
# Executing SA2 Code 203031048
# Subset size = 247, Places count = 19, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 12273
# Executing SA2 Code 205011079
# Subset size = 2691, Places count = 39, Property count = 69
# To Place Distance Grand List, Normal Branch, length = 14964
# Executing SA2 Code 201021010
# Subset size = 1666, Places count = 34, Property count = 49
# To Place Distance Grand List, Normal Branch, length = 16630
# Executing SA2 Code 212031556
# Subset size = 7, Places count = 1, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 16637
# Executing SA2 Code 212031555
# Subset size = 9, Places count = 1, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 16646
# Executing SA2 Code 212031557
# Subset size = 36, Places count = 4, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 16682
# Executing SA2 Code 212021293
# Subset size = 3668, Places count = 28, Property count = 131
# To Place Distance Grand List, Slice Branch, length = 18502
# To Place Distance Grand List, Slice Branch, length = 20350
# Executing SA2 Code 212031303
# Subset size = 444, Places count = 6, Property count = 74
# To Place Distance Grand List, Normal Branch, length = 20794
# Executing SA2 Code 205051100
# Subset size = 352, Places count = 16, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 21146
# Executing SA2 Code 217031475
# Subset size = 2070, Places count = 45, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 23216
# Executing SA2 Code 216021411
# Subset size = 140, Places count = 10, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 23356
# Executing SA2 Code 210031236
# Subset size = 304, Places count = 16, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 23660
# Executing SA2 Code 206011498
# Subset size = 672, Places count = 14, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 24332
# Executing SA2 Code 206011497
# Subset size = 1363, Places count = 29, Property count = 47
# To Place Distance Grand List, Normal Branch, length = 25695
# Executing SA2 Code 212011289
# Subset size = 1113, Places count = 21, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 26808
# Executing SA2 Code 215031401
# Subset size = 500, Places count = 50, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 27308
# Executing SA2 Code 217031472
# Subset size = 432, Places count = 18, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 27740
# Executing SA2 Code 211051278
# Subset size = 646, Places count = 17, Property count = 38
# To Place Distance Grand List, Normal Branch, length = 28386
# Executing SA2 Code 217011423
# Subset size = 2542, Places count = 62, Property count = 41
# To Place Distance Grand List, Normal Branch, length = 30928
# Executing SA2 Code 206071141
# Subset size = 320, Places count = 5, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 31248
# Executing SA2 Code 203031489
# Subset size = 504, Places count = 12, Property count = 42
# To Place Distance Grand List, Normal Branch, length = 31752
# Executing SA2 Code 210051243
# Subset size = 480, Places count = 20, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 32232
# Executing SA2 Code 216031419
# Subset size = 1748, Places count = 38, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 33980
# Executing SA2 Code 201021011
# Subset size = 2204, Places count = 29, Property count = 76
# To Place Distance Grand List, Normal Branch, length = 36184
# Executing SA2 Code 205051101
# Subset size = 3220, Places count = 46, Property count = 70
# To Place Distance Grand List, Normal Branch, length = 39404
# Executing SA2 Code 205031093
# Subset size = 4674, Places count = 38, Property count = 123
# To Place Distance Grand List, Slice Branch, length = 41722
# To Place Distance Grand List, Slice Branch, length = 44078
# Executing SA2 Code 203021486
# Subset size = 1560, Places count = 39, Property count = 40
# To Place Distance Grand List, Normal Branch, length = 45638
# Executing SA2 Code 217031473
# Subset size = 693, Places count = 21, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 46331
# Executing SA2 Code 204031072
# Subset size = 1230, Places count = 41, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 47561
# Executing SA2 Code 216031418
# Subset size = 450, Places count = 25, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 48011
# Executing SA2 Code 205031091
# Subset size = 1188, Places count = 12, Property count = 99
# To Place Distance Grand List, Normal Branch, length = 49199
# Executing SA2 Code 205051102
# Subset size = 805, Places count = 23, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 50004
# Executing SA2 Code 210051443
# Subset size = 96, Places count = 6, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 50100
# Executing SA2 Code 210051442
# Subset size = 75, Places count = 5, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 50175
# Executing SA2 Code 210051542
# Subset size = 4, Places count = 1, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 50179
# Executing SA2 Code 210051543
# Subset size = 30, Places count = 2, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 50209
# Executing SA2 Code 210051441
# Subset size = 14, Places count = 2, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 50223
# Executing SA2 Code 212031560
# Subset size = 228, Places count = 6, Property count = 38
# To Place Distance Grand List, Normal Branch, length = 50451
# Executing SA2 Code 212031559
# Subset size = 48, Places count = 2, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 50499
# Executing SA2 Code 212031304
# Subset size = 42, Places count = 3, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 50541
# Executing SA2 Code 212031300
# Subset size = 1023, Places count = 11, Property count = 93
# To Place Distance Grand List, Normal Branch, length = 51564
# Executing SA2 Code 213041462
# Subset size = 111, Places count = 1, Property count = 111
# To Place Distance Grand List, Normal Branch, length = 51675
# Executing SA2 Code 207031166
# Subset size = 420, Places count = 14, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 52095
# Executing SA2 Code 207031165
# Subset size = 826, Places count = 14, Property count = 59
# To Place Distance Grand List, Normal Branch, length = 52921
# Executing SA2 Code 212051319
# Subset size = 1260, Places count = 12, Property count = 105
# To Place Distance Grand List, Normal Branch, length = 54181
# Executing SA2 Code 217041479
# Subset size = 1860, Places count = 30, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 56041
# Executing SA2 Code 204011054
# Subset size = 2120, Places count = 40, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 58161
# Executing SA2 Code 204011056
# Subset size = 286, Places count = 11, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 58447
# Executing SA2 Code 213011329
# Subset size = 27, Places count = 9, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 58474
# Executing SA2 Code 212011548
# Subset size = 266, Places count = 19, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 58740
# Executing SA2 Code 202011019
# Subset size = 510, Places count = 17, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 59250
# Executing SA2 Code 207011149
# Subset size = 2162, Places count = 23, Property count = 94
# To Place Distance Grand List, Normal Branch, length = 61412
# Executing SA2 Code 207011150
# Subset size = 1323, Places count = 21, Property count = 63
# To Place Distance Grand List, Normal Branch, length = 62735
# Executing SA2 Code 206061136
# Subset size = 1896, Places count = 12, Property count = 158
# To Place Distance Grand List, Normal Branch, length = 64631
# Executing SA2 Code 206041505
# Subset size = 99, Places count = 9, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 64730
# Executing SA2 Code 206041504
# Subset size = 198, Places count = 6, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 64928
# Executing SA2 Code 206041503
# Subset size = 297, Places count = 9, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 65225
# Executing SA2 Code 213041578
# Subset size = 119, Places count = 7, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 65344
# Executing SA2 Code 213041463
# Subset size = 396, Places count = 9, Property count = 44
# To Place Distance Grand List, Normal Branch, length = 65740
# Executing SA2 Code 213041358
# Subset size = 63, Places count = 7, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 65803
# Executing SA2 Code 213041577
# Subset size = 153, Places count = 3, Property count = 51
# To Place Distance Grand List, Normal Branch, length = 65956
# Executing SA2 Code 208031190
# Subset size = 583, Places count = 11, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 66539
# Executing SA2 Code 211051274
# Subset size = 714, Places count = 21, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 67253
# Executing SA2 Code 215021396
# Subset size = 375, Places count = 25, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 67628
# Executing SA2 Code 203011035
# Subset size = 493, Places count = 17, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 68121
# Executing SA2 Code 209041531
# Subset size = 18, Places count = 2, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 68139
# Executing SA2 Code 209041532
# Subset size = 8, Places count = 2, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 68147
# Executing SA2 Code 204031071
# Subset size = 286, Places count = 22, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 68433
# Executing SA2 Code 214021379
# Subset size = 3570, Places count = 70, Property count = 51
# To Place Distance Grand List, Slice Branch, length = 70183
# To Place Distance Grand List, Slice Branch, length = 72003
# Executing SA2 Code 204011057
# Subset size = 1073, Places count = 29, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 73076
# Executing SA2 Code 205021084
# Subset size = 1350, Places count = 25, Property count = 54
# To Place Distance Grand List, Normal Branch, length = 74426
# Executing SA2 Code 210051445
# Subset size = 10, Places count = 2, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 74436
# Executing SA2 Code 206051128
# Subset size = 1988, Places count = 14, Property count = 142
# To Place Distance Grand List, Normal Branch, length = 76424
# Executing SA2 Code 204011055
# Subset size = 390, Places count = 26, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 76814
# Executing SA2 Code 204021067
# Subset size = 2280, Places count = 40, Property count = 57
# To Place Distance Grand List, Normal Branch, length = 79094
# Executing SA2 Code 215021470
# Subset size = 1140, Places count = 19, Property count = 60
# To Place Distance Grand List, Normal Branch, length = 80234
# Executing SA2 Code 215021469
# Subset size = 2432, Places count = 38, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 82666
# Executing SA2 Code 215021395
# Subset size = 361, Places count = 19, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 83027
# Executing SA2 Code 209041220
# Subset size = 168, Places count = 4, Property count = 42
# To Place Distance Grand List, Normal Branch, length = 83195
# Executing SA2 Code 209041221
# Subset size = 48, Places count = 2, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 83243
# Executing SA2 Code 209011203
# Subset size = 525, Places count = 15, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 83768
# Executing SA2 Code 211051286
# Subset size = 2890, Places count = 34, Property count = 85
# To Place Distance Grand List, Normal Branch, length = 86658
# Executing SA2 Code 203021042
# Subset size = 1365, Places count = 35, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 88023
# Executing SA2 Code 204031069
# Subset size = 2142, Places count = 42, Property count = 51
# To Place Distance Grand List, Normal Branch, length = 90165
# Executing SA2 Code 211051285
# Subset size = 85, Places count = 5, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 90250
# Executing SA2 Code 209041224
# Subset size = 429, Places count = 11, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 90679
# Executing SA2 Code 204021066
# Subset size = 2296, Places count = 28, Property count = 82
# To Place Distance Grand List, Normal Branch, length = 92975
# Executing SA2 Code 217041477
# Subset size = 1710, Places count = 45, Property count = 38
# To Place Distance Grand List, Normal Branch, length = 94685
# Executing SA2 Code 211011260
# Subset size = 480, Places count = 15, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 95165
# Executing SA2 Code 211011254
# Subset size = 600, Places count = 15, Property count = 40
# To Place Distance Grand List, Normal Branch, length = 95765
# Executing SA2 Code 211011259
# Subset size = 288, Places count = 9, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 96053
# Executing SA2 Code 212031308
# Subset size = 270, Places count = 5, Property count = 54
# To Place Distance Grand List, Normal Branch, length = 96323
# Executing SA2 Code 215011394
# Subset size = 3618, Places count = 67, Property count = 54
# To Place Distance Grand List, Slice Branch, length = 98132
# To Place Distance Grand List, Slice Branch, length = 99941
# Executing SA2 Code 211021262
# Subset size = 216, Places count = 12, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 100157
# Executing SA2 Code 209031214
# Subset size = 204, Places count = 6, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 100361
# Executing SA2 Code 211031265
# Subset size = 598, Places count = 23, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 100959
# Executing SA2 Code 204021063
# Subset size = 84, Places count = 7, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 101043
# Executing SA2 Code 204021064
# Subset size = 783, Places count = 27, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 101826
# Executing SA2 Code 201011481
# Subset size = 1098, Places count = 18, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 102924
# Executing SA2 Code 201011482
# Subset size = 1476, Places count = 18, Property count = 82
# To Place Distance Grand List, Normal Branch, length = 104400
# Executing SA2 Code 217041480
# Subset size = 1144, Places count = 26, Property count = 44
# To Place Distance Grand List, Normal Branch, length = 105544
# Executing SA2 Code 208031183
# Subset size = 54, Places count = 3, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 105598
# Executing SA2 Code 208031184
# Subset size = 2, Places count = 1, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 105600
# Executing SA2 Code 209011204
# Subset size = 120, Places count = 8, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 105720
# Executing SA2 Code 203011036
# Subset size = 608, Places count = 32, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 106328
# Executing SA2 Code 203011034
# Subset size = 12, Places count = 2, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 106340
# Executing SA2 Code 205051104
# Subset size = 1980, Places count = 45, Property count = 44
# To Place Distance Grand List, Normal Branch, length = 108320
# Executing SA2 Code 216011410
# Subset size = 529, Places count = 23, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 108849
# Executing SA2 Code 210021232
# Subset size = 264, Places count = 11, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 109113
# Executing SA2 Code 210041539
# Subset size = 21, Places count = 3, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 109134
# Executing SA2 Code 210051245
# Subset size = 525, Places count = 15, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 109659
# Executing SA2 Code 208021182
# Subset size = 483, Places count = 7, Property count = 69
# To Place Distance Grand List, Normal Branch, length = 110142
# Executing SA2 Code 208021176
# Subset size = 505, Places count = 5, Property count = 101
# To Place Distance Grand List, Normal Branch, length = 110647
# Executing SA2 Code 208041194
# Subset size = 3360, Places count = 28, Property count = 120
# To Place Distance Grand List, Normal Branch, length = 114007
# Executing SA2 Code 212051322
# Subset size = 1116, Places count = 12, Property count = 93
# To Place Distance Grand List, Normal Branch, length = 115123
# Executing SA2 Code 212051321
# Subset size = 1102, Places count = 19, Property count = 58
# To Place Distance Grand List, Normal Branch, length = 116225
# Executing SA2 Code 204011062
# Subset size = 322, Places count = 23, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 116547
# Executing SA2 Code 202011018
# Subset size = 7290, Places count = 27, Property count = 270
# To Place Distance Grand List, Slice Branch, length = 118977
# To Place Distance Grand List, Slice Branch, length = 121407
# To Place Distance Grand List, Slice Branch, length = 123837
# Executing SA2 Code 202011020
# Subset size = 558, Places count = 6, Property count = 93
# To Place Distance Grand List, Normal Branch, length = 124395
# Executing SA2 Code 202011021
# Subset size = 792, Places count = 9, Property count = 88
# To Place Distance Grand List, Normal Branch, length = 125187
# Executing SA2 Code 210021235
# Subset size = 180, Places count = 10, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 125367
# Executing SA2 Code 208021426
# Subset size = 252, Places count = 6, Property count = 42
# To Place Distance Grand List, Normal Branch, length = 125619
# Executing SA2 Code 208021427
# Subset size = 378, Places count = 14, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 125997
# Executing SA2 Code 208021174
# Subset size = 396, Places count = 6, Property count = 66
# To Place Distance Grand List, Normal Branch, length = 126393
# Executing SA2 Code 212021553
# Subset size = 276, Places count = 6, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 126669
# Executing SA2 Code 212021554
# Subset size = 52, Places count = 1, Property count = 52
# To Place Distance Grand List, Normal Branch, length = 126721
# Executing SA2 Code 212031457
# Subset size = 10, Places count = 2, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 126731
# Executing SA2 Code 201031017
# Subset size = 525, Places count = 35, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 127256
# Executing SA2 Code 205021085
# Subset size = 1656, Places count = 69, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 128912
# Executing SA2 Code 202011022
# Subset size = 1364, Places count = 22, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 130276
# Executing SA2 Code 215031400
# Subset size = 3965, Places count = 61, Property count = 65
# To Place Distance Grand List, Slice Branch, length = 132228
# To Place Distance Grand List, Slice Branch, length = 134241
# Executing SA2 Code 208011173
# Subset size = 1302, Places count = 21, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 135543
# Executing SA2 Code 207031161
# Subset size = 1403, Places count = 23, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 136946
# Executing SA2 Code 207031162
# Subset size = 207, Places count = 9, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 137153
# Executing SA2 Code 201021009
# Subset size = 168, Places count = 12, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 137321
# Executing SA2 Code 206071139
# Subset size = 336, Places count = 7, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 137657
# Executing SA2 Code 206031501
# Subset size = 637, Places count = 13, Property count = 49
# To Place Distance Grand List, Normal Branch, length = 138294
# Executing SA2 Code 203031049
# Subset size = 322, Places count = 14, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 138616
# Executing SA2 Code 210011226
# Subset size = 238, Places count = 7, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 138854
# Executing SA2 Code 213011333
# Subset size = 240, Places count = 16, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 139094
# Executing SA2 Code 206051512
# Subset size = 372, Places count = 6, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 139466
# Executing SA2 Code 213011328
# Subset size = 465, Places count = 15, Property count = 31
# To Place Distance Grand List, Normal Branch, length = 139931
# Executing SA2 Code 201011001
# Subset size = 360, Places count = 3, Property count = 120
# To Place Distance Grand List, Normal Branch, length = 140291
# Executing SA2 Code 206021110
# Subset size = 185, Places count = 5, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 140476
# Executing SA2 Code 213021342
# Subset size = 1725, Places count = 23, Property count = 75
# To Place Distance Grand List, Normal Branch, length = 142201
# Executing SA2 Code 213021343
# Subset size = 2112, Places count = 32, Property count = 66
# To Place Distance Grand List, Normal Branch, length = 144313
# Executing SA2 Code 213021344
# Subset size = 4485, Places count = 39, Property count = 115
# To Place Distance Grand List, Slice Branch, length = 146536
# To Place Distance Grand List, Slice Branch, length = 148798
# Executing SA2 Code 213021341
# Subset size = 3042, Places count = 39, Property count = 78
# To Place Distance Grand List, Normal Branch, length = 151840
# Executing SA2 Code 202021026
# Subset size = 304, Places count = 16, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 152144
# Executing SA2 Code 203021040
# Subset size = 4686, Places count = 33, Property count = 142
# To Place Distance Grand List, Slice Branch, length = 154487
# To Place Distance Grand List, Slice Branch, length = 156830
# Executing SA2 Code 213051579
# Subset size = 23, Places count = 1, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 156853
# Executing SA2 Code 213051590
# Subset size = 40, Places count = 4, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 156893
# Executing SA2 Code 217031476
# Subset size = 216, Places count = 18, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 157109
# Executing SA2 Code 213031349
# Subset size = 1027, Places count = 13, Property count = 79
# To Place Distance Grand List, Normal Branch, length = 158136
# Executing SA2 Code 203021485
# Subset size = 156, Places count = 3, Property count = 52
# To Place Distance Grand List, Normal Branch, length = 158292
# Executing SA2 Code 201031016
# Subset size = 340, Places count = 34, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 158632
# Executing SA2 Code 214021384
# Subset size = 4234, Places count = 29, Property count = 146
# To Place Distance Grand List, Slice Branch, length = 160749
# To Place Distance Grand List, Slice Branch, length = 162866
# Executing SA2 Code 204011061
# Subset size = 2, Places count = 2, Property count = 1
# To Place Distance Grand List, Normal Branch, length = 162868
# Executing SA2 Code 210051247
# Subset size = 80, Places count = 4, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 162948
# Executing SA2 Code 205031087
# Subset size = 1512, Places count = 42, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 164460
# Executing SA2 Code 206041506
# Subset size = 1284, Places count = 12, Property count = 107
# To Place Distance Grand List, Normal Branch, length = 165744
# Executing SA2 Code 206041118
# Subset size = 944, Places count = 16, Property count = 59
# To Place Distance Grand List, Normal Branch, length = 166688
# Executing SA2 Code 209031215
# Subset size = 196, Places count = 14, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 166884
# Executing SA2 Code 201031013
# Subset size = 650, Places count = 25, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 167534
# Executing SA2 Code 203021487
# Subset size = 660, Places count = 20, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 168194
# Executing SA2 Code 202031033
# Subset size = 2678, Places count = 103, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 170872
# Executing SA2 Code 217031474
# Subset size = 1575, Places count = 45, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 172447
# Executing SA2 Code 202021028
# Subset size = 1504, Places count = 32, Property count = 47
# To Place Distance Grand List, Normal Branch, length = 173951
# Executing SA2 Code 201011008
# Subset size = 1037, Places count = 17, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 174988
# Executing SA2 Code 201011002
# Subset size = 2499, Places count = 21, Property count = 119
# To Place Distance Grand List, Normal Branch, length = 177487
# Executing SA2 Code 213051368
# Subset size = 432, Places count = 18, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 177919
# Executing SA2 Code 213051467
# Subset size = 832, Places count = 13, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 178751
# Executing SA2 Code 213051468
# Subset size = 378, Places count = 14, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 179129
# Executing SA2 Code 213031351
# Subset size = 455, Places count = 13, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 179584
# Executing SA2 Code 213031348
# Subset size = 2184, Places count = 28, Property count = 78
# To Place Distance Grand List, Normal Branch, length = 181768
# Executing SA2 Code 206041510
# Subset size = 306, Places count = 6, Property count = 51
# To Place Distance Grand List, Normal Branch, length = 182074
# Executing SA2 Code 204031073
# Subset size = 2040, Places count = 68, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 184114
# Executing SA2 Code 203031490
# Subset size = 483, Places count = 23, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 184597
# Executing SA2 Code 212051327
# Subset size = 624, Places count = 16, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 185221
# Executing SA2 Code 212051325
# Subset size = 570, Places count = 10, Property count = 57
# To Place Distance Grand List, Normal Branch, length = 185791
# Executing SA2 Code 202011025
# Subset size = 688, Places count = 16, Property count = 43
# To Place Distance Grand List, Normal Branch, length = 186479
# Executing SA2 Code 203021045
# Subset size = 714, Places count = 34, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 187193
# Executing SA2 Code 213041353
# Subset size = 380, Places count = 19, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 187573
# Executing SA2 Code 217011420
# Subset size = 4736, Places count = 74, Property count = 64
# To Place Distance Grand List, Slice Branch, length = 189941
# To Place Distance Grand List, Slice Branch, length = 192309
# Executing SA2 Code 215011392
# Subset size = 1849, Places count = 43, Property count = 43
# To Place Distance Grand List, Normal Branch, length = 194158
# Executing SA2 Code 207011147
# Subset size = 1491, Places count = 21, Property count = 71
# To Place Distance Grand List, Normal Branch, length = 195649
# Executing SA2 Code 213011569
# Subset size = 504, Places count = 18, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 196153
# Executing SA2 Code 201011006
# Subset size = 65, Places count = 5, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 196218
# Executing SA2 Code 213011331
# Subset size = 90, Places count = 6, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 196308
# Executing SA2 Code 213011570
# Subset size = 120, Places count = 8, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 196428
# Executing SA2 Code 210041540
# Subset size = 319, Places count = 11, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 196747
# Executing SA2 Code 215011390
# Subset size = 1734, Places count = 51, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 198481
# Executing SA2 Code 212041313
# Subset size = 48, Places count = 8, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 198529
# Executing SA2 Code 215031405
# Subset size = 1836, Places count = 51, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 200365
# Executing SA2 Code 205031089
# Subset size = 1088, Places count = 32, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 201453
# Executing SA2 Code 210031538
# Subset size = 1216, Places count = 16, Property count = 76
# To Place Distance Grand List, Normal Branch, length = 202669
# Executing SA2 Code 210031537
# Subset size = 220, Places count = 11, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 202889
# Executing SA2 Code 210051246
# Subset size = 136, Places count = 8, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 203025
# Executing SA2 Code 212051326
# Subset size = 1134, Places count = 14, Property count = 81
# To Place Distance Grand List, Normal Branch, length = 204159
# Executing SA2 Code 212011546
# Subset size = 252, Places count = 12, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 204411
# Executing SA2 Code 212011552
# Subset size = 280, Places count = 8, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 204691
# Executing SA2 Code 216031594
# Subset size = 901, Places count = 17, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 205592
# Executing SA2 Code 204031075
# Subset size = 264, Places count = 12, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 205856
# Executing SA2 Code 215021398
# Subset size = 55, Places count = 55, Property count = 1
# To Place Distance Grand List, Normal Branch, length = 205911
# Executing SA2 Code 212011551
# Subset size = 44, Places count = 2, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 205955
# Executing SA2 Code 212011550
# Subset size = 16, Places count = 2, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 205971
# Executing SA2 Code 212011549
# Subset size = 48, Places count = 3, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 206019
# Executing SA2 Code 212011547
# Subset size = 450, Places count = 18, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 206469
# Executing SA2 Code 211021261
# Subset size = 210, Places count = 15, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 206679
# Executing SA2 Code 206051513
# Subset size = 592, Places count = 8, Property count = 74
# To Place Distance Grand List, Normal Branch, length = 207271
# Executing SA2 Code 208031193
# Subset size = 1342, Places count = 22, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 208613
# Executing SA2 Code 206041124
# Subset size = 128, Places count = 8, Property count = 16
# To Place Distance Grand List, Normal Branch, length = 208741
# Executing SA2 Code 212041459
# Subset size = 830, Places count = 10, Property count = 83
# To Place Distance Grand List, Normal Branch, length = 209571
# Executing SA2 Code 212041460
# Subset size = 632, Places count = 8, Property count = 79
# To Place Distance Grand List, Normal Branch, length = 210203
# Executing SA2 Code 212041565
# Subset size = 255, Places count = 17, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 210458
# Executing SA2 Code 203021488
# Subset size = 748, Places count = 17, Property count = 44
# To Place Distance Grand List, Normal Branch, length = 211206
# Executing SA2 Code 203021047
# Subset size = 5285, Places count = 35, Property count = 151
# To Place Distance Grand List, Slice Branch, length = 213831
# To Place Distance Grand List, Slice Branch, length = 216491
# Executing SA2 Code 215011386
# Subset size = 399, Places count = 21, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 216890
# Executing SA2 Code 208011169
# Subset size = 2277, Places count = 23, Property count = 99
# To Place Distance Grand List, Normal Branch, length = 219167
# Executing SA2 Code 206021500
# Subset size = 429, Places count = 13, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 219596
# Executing SA2 Code 206021499
# Subset size = 560, Places count = 10, Property count = 56
# To Place Distance Grand List, Normal Branch, length = 220156
# Executing SA2 Code 212051324
# Subset size = 960, Places count = 12, Property count = 80
# To Place Distance Grand List, Normal Branch, length = 221116
# Executing SA2 Code 201011484
# Subset size = 585, Places count = 9, Property count = 65
# To Place Distance Grand List, Normal Branch, length = 221701
# Executing SA2 Code 209021525
# Subset size = 200, Places count = 8, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 221901
# Executing SA2 Code 209021524
# Subset size = 108, Places count = 12, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 222009
# Executing SA2 Code 209021526
# Subset size = 416, Places count = 13, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 222425
# Executing SA2 Code 209021523
# Subset size = 405, Places count = 9, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 222830
# Executing SA2 Code 206071517
# Subset size = 1428, Places count = 14, Property count = 102
# To Place Distance Grand List, Normal Branch, length = 224258
# Executing SA2 Code 206071518
# Subset size = 1054, Places count = 17, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 225312
# Executing SA2 Code 210021234
# Subset size = 9, Places count = 3, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 225321
# Executing SA2 Code 211031267
# Subset size = 1014, Places count = 26, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 226335
# Executing SA2 Code 211031268
# Subset size = 224, Places count = 16, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 226559
# Executing SA2 Code 211031266
# Subset size = 1672, Places count = 22, Property count = 76
# To Place Distance Grand List, Normal Branch, length = 228231
# Executing SA2 Code 206051134
# Subset size = 171, Places count = 9, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 228402
# Executing SA2 Code 209041432
# Subset size = 350, Places count = 10, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 228752
# Executing SA2 Code 209041431
# Subset size = 175, Places count = 7, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 228927
# Executing SA2 Code 209041433
# Subset size = 33, Places count = 1, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 228960
# Executing SA2 Code 205011077
# Subset size = 1020, Places count = 34, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 229980
# Executing SA2 Code 210011230
# Subset size = 184, Places count = 8, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 230164
# Executing SA2 Code 206031502
# Subset size = 871, Places count = 13, Property count = 67
# To Place Distance Grand List, Normal Branch, length = 231035
# Executing SA2 Code 212021295
# Subset size = 216, Places count = 27, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 231251
# Executing SA2 Code 213041573
# Subset size = 4, Places count = 1, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 231255
# Executing SA2 Code 210031237
# Subset size = 288, Places count = 16, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 231543
# Executing SA2 Code 211011447
# Subset size = 425, Places count = 17, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 231968
# Executing SA2 Code 211011448
# Subset size = 225, Places count = 15, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 232193
# Executing SA2 Code 211051282
# Subset size = 1188, Places count = 27, Property count = 44
# To Place Distance Grand List, Normal Branch, length = 233381
# Executing SA2 Code 214021383
# Subset size = 3995, Places count = 47, Property count = 85
# To Place Distance Grand List, Slice Branch, length = 235355
# To Place Distance Grand List, Slice Branch, length = 237376
# Executing SA2 Code 206071143
# Subset size = 600, Places count = 10, Property count = 60
# To Place Distance Grand List, Normal Branch, length = 237976
# Executing SA2 Code 206071142
# Subset size = 560, Places count = 7, Property count = 80
# To Place Distance Grand List, Normal Branch, length = 238536
# Executing SA2 Code 201011007
# Subset size = 36, Places count = 6, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 238572
# Executing SA2 Code 217031471
# Subset size = 68, Places count = 17, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 238640
# Executing SA2 Code 201011483
# Subset size = 3160, Places count = 20, Property count = 158
# To Place Distance Grand List, Normal Branch, length = 241800
# Executing SA2 Code 207011155
# Subset size = 1166, Places count = 22, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 242966
# Executing SA2 Code 214021378
# Subset size = 468, Places count = 26, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 243434
# Executing SA2 Code 215021399
# Subset size = 418, Places count = 22, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 243852
# Executing SA2 Code 206071140
# Subset size = 588, Places count = 7, Property count = 84
# To Place Distance Grand List, Normal Branch, length = 244440
# Executing SA2 Code 206041117
# Subset size = 737, Places count = 11, Property count = 67
# To Place Distance Grand List, Normal Branch, length = 245177
# Executing SA2 Code 213041360
# Subset size = 87, Places count = 3, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 245264
# Executing SA2 Code 213041359
# Subset size = 60, Places count = 5, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 245324
# Executing SA2 Code 214021385
# Subset size = 2016, Places count = 56, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 247340
# Executing SA2 Code 211031263
# Subset size = 140, Places count = 7, Property count = 20
# To Place Distance Grand List, Normal Branch, length = 247480
# Executing SA2 Code 211011251
# Subset size = 360, Places count = 12, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 247840
# Executing SA2 Code 216021413
# Subset size = 1530, Places count = 45, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 249370
# Executing SA2 Code 201031014
# Subset size = 672, Places count = 32, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 250042
# Executing SA2 Code 208011168
# Subset size = 342, Places count = 9, Property count = 38
# To Place Distance Grand List, Normal Branch, length = 250384
# Executing SA2 Code 204031068
# Subset size = 165, Places count = 11, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 250549
# Executing SA2 Code 203031053
# Subset size = 2880, Places count = 30, Property count = 96
# To Place Distance Grand List, Normal Branch, length = 253429
# Executing SA2 Code 209011199
# Subset size = 803, Places count = 11, Property count = 73
# To Place Distance Grand List, Normal Branch, length = 254232
# Executing SA2 Code 203021037
# Subset size = 750, Places count = 30, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 254982
# Executing SA2 Code 213031347
# Subset size = 1696, Places count = 32, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 256678
# Executing SA2 Code 210011533
# Subset size = 150, Places count = 6, Property count = 25
# To Place Distance Grand List, Normal Branch, length = 256828
# Executing SA2 Code 203021039
# Subset size = 3230, Places count = 38, Property count = 85
# To Place Distance Grand List, Normal Branch, length = 260058
# Executing SA2 Code 209011202
# Subset size = 528, Places count = 16, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 260586
# Executing SA2 Code 208011170
# Subset size = 960, Places count = 12, Property count = 80
# To Place Distance Grand List, Normal Branch, length = 261546
# Executing SA2 Code 208011172
# Subset size = 897, Places count = 13, Property count = 69
# To Place Distance Grand List, Normal Branch, length = 262443
# Executing SA2 Code 210051242
# Subset size = 725, Places count = 25, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 263168
# Executing SA2 Code 213041571
# Subset size = 6, Places count = 1, Property count = 6
# To Place Distance Grand List, Normal Branch, length = 263174
# Executing SA2 Code 206011106
# Subset size = 225, Places count = 15, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 263399
# Executing SA2 Code 206011495
# Subset size = 306, Places count = 9, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 263705
# Executing SA2 Code 206011496
# Subset size = 1092, Places count = 26, Property count = 42
# To Place Distance Grand List, Normal Branch, length = 264797
# Executing SA2 Code 206011107
# Subset size = 1404, Places count = 18, Property count = 78
# To Place Distance Grand List, Normal Branch, length = 266201
# Executing SA2 Code 204011058
# Subset size = 345, Places count = 15, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 266546
# Executing SA2 Code 202021029
# Subset size = 72, Places count = 8, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 266618
# Executing SA2 Code 202031032
# Subset size = 322, Places count = 23, Property count = 14
# To Place Distance Grand List, Normal Branch, length = 266940
# Executing SA2 Code 205021081
# Subset size = 1650, Places count = 30, Property count = 55
# To Place Distance Grand List, Normal Branch, length = 268590
# Executing SA2 Code 203021043
# Subset size = 1189, Places count = 29, Property count = 41
# To Place Distance Grand List, Normal Branch, length = 269779
# Executing SA2 Code 207011148
# Subset size = 990, Places count = 18, Property count = 55
# To Place Distance Grand List, Normal Branch, length = 270769
# Executing SA2 Code 216011408
# Subset size = 105, Places count = 21, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 270874
# Executing SA2 Code 204031491
# Subset size = 1620, Places count = 27, Property count = 60
# To Place Distance Grand List, Normal Branch, length = 272494
# Executing SA2 Code 212041564
# Subset size = 9, Places count = 9, Property count = 1
# To Place Distance Grand List, Normal Branch, length = 272503
# Executing SA2 Code 212041566
# Subset size = 110, Places count = 10, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 272613
# Executing SA2 Code 205021086
# Subset size = 424, Places count = 8, Property count = 53
# To Place Distance Grand List, Normal Branch, length = 273037
# Executing SA2 Code 209041225
# Subset size = 88, Places count = 8, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 273125
# Executing SA2 Code 215011387
# Subset size = 520, Places count = 52, Property count = 10
# To Place Distance Grand List, Normal Branch, length = 273645
# Executing SA2 Code 213051363
# Subset size = 1040, Places count = 20, Property count = 52
# To Place Distance Grand List, Normal Branch, length = 274685
# Executing SA2 Code 206051511
# Subset size = 42, Places count = 6, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 274727
# Executing SA2 Code 213021346
# Subset size = 3978, Places count = 34, Property count = 117
# To Place Distance Grand List, Slice Branch, length = 276699
# To Place Distance Grand List, Slice Branch, length = 278705
# Executing SA2 Code 204031492
# Subset size = 5740, Places count = 82, Property count = 70
# To Place Distance Grand List, Slice Branch, length = 281575
# To Place Distance Grand List, Slice Branch, length = 284445
# Executing SA2 Code 209041437
# Subset size = 6, Places count = 2, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 284451
# Executing SA2 Code 215011389
# Subset size = 1248, Places count = 52, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 285699
# Executing SA2 Code 207021424
# Subset size = 204, Places count = 6, Property count = 34
# To Place Distance Grand List, Normal Branch, length = 285903
# Executing SA2 Code 207021425
# Subset size = 423, Places count = 9, Property count = 47
# To Place Distance Grand List, Normal Branch, length = 286326
# Executing SA2 Code 207021157
# Subset size = 649, Places count = 11, Property count = 59
# To Place Distance Grand List, Normal Branch, length = 286975
# Executing SA2 Code 207021160
# Subset size = 380, Places count = 10, Property count = 38
# ...
# To Place Distance Grand List, Normal Branch, length = 420962
# Executing SA2 Code 208031188
# Subset size = 1144, Places count = 13, Property count = 88
# To Place Distance Grand List, Normal Branch, length = 422106
# Executing SA2 Code 208011171
# Subset size = 310, Places count = 10, Property count = 31
# To Place Distance Grand List, Normal Branch, length = 422416
# Executing SA2 Code 208031191
# Subset size = 784, Places count = 16, Property count = 49
# To Place Distance Grand List, Normal Branch, length = 423200
# Executing SA2 Code 211051281
# Subset size = 580, Places count = 20, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 423780
# Executing SA2 Code 216031415
# Subset size = 336, Places count = 12, Property count = 28
# To Place Distance Grand List, Normal Branch, length = 424116
# Executing SA2 Code 214021591
# Subset size = 1296, Places count = 36, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 425412
# Executing SA2 Code 214021592
# Subset size = 1215, Places count = 27, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 426627
# Executing SA2 Code 205041096
# Subset size = 2405, Places count = 37, Property count = 65
# To Place Distance Grand List, Normal Branch, length = 429032
# Executing SA2 Code 213051582
# Subset size = 5, Places count = 1, Property count = 5
# To Place Distance Grand List, Normal Branch, length = 429037
# Executing SA2 Code 214021381
# Subset size = 2624, Places count = 41, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 431661
# Executing SA2 Code 213041575
# Subset size = 528, Places count = 24, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 432189
# Executing SA2 Code 213011339
# Subset size = 868, Places count = 14, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 433057
# Executing SA2 Code 213051362
# Subset size = 651, Places count = 7, Property count = 93
# To Place Distance Grand List, Normal Branch, length = 433708
# Executing SA2 Code 213051361
# Subset size = 315, Places count = 5, Property count = 63
# To Place Distance Grand List, Normal Branch, length = 434023
# Executing SA2 Code 208021180
# Subset size = 195, Places count = 5, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 434218
# Executing SA2 Code 209031210
# Subset size = 290, Places count = 10, Property count = 29
# To Place Distance Grand List, Normal Branch, length = 434508
# Executing SA2 Code 209011201
# Subset size = 88, Places count = 8, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 434596
# Executing SA2 Code 209011200
# Subset size = 804, Places count = 12, Property count = 67
# To Place Distance Grand List, Normal Branch, length = 435400
# Executing SA2 Code 211041270
# Subset size = 798, Places count = 14, Property count = 57
# To Place Distance Grand List, Normal Branch, length = 436198
# Executing SA2 Code 212011547
# Subset size = 1134, Places count = 18, Property count = 63
# To Place Distance Grand List, Normal Branch, length = 437332
# Executing SA2 Code 207031167
# Subset size = 350, Places count = 7, Property count = 50
# To Place Distance Grand List, Normal Branch, length = 437682
# Executing SA2 Code 211051280
# Subset size = 42, Places count = 6, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 437724
# Executing SA2 Code 206031116
# Subset size = 909, Places count = 9, Property count = 101
# To Place Distance Grand List, Normal Branch, length = 438633
# Executing SA2 Code 207011152
# Subset size = 1936, Places count = 16, Property count = 121
# To Place Distance Grand List, Normal Branch, length = 440569
# Executing SA2 Code 207011520
# Subset size = 1312, Places count = 16, Property count = 82
# To Place Distance Grand List, Normal Branch, length = 441881
# Executing SA2 Code 207011519
# Subset size = 546, Places count = 14, Property count = 39
# To Place Distance Grand List, Normal Branch, length = 442427
# Executing SA2 Code 211051283
# Subset size = 189, Places count = 9, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 442616
# Executing SA2 Code 214021382
# Subset size = 1296, Places count = 36, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 443912
# Executing SA2 Code 212051323
# Subset size = 675, Places count = 15, Property count = 45
# To Place Distance Grand List, Normal Branch, length = 444587
# Executing SA2 Code 212051325
# Subset size = 640, Places count = 10, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 445227
# Executing SA2 Code 208021181
# Subset size = 432, Places count = 9, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 445659
# Executing SA2 Code 210041540
# Subset size = 444, Places count = 12, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 446103
# Executing SA2 Code 210041541
# Subset size = 184, Places count = 8, Property count = 23
# To Place Distance Grand List, Normal Branch, length = 446287
# Executing SA2 Code 213011337
# Subset size = 658, Places count = 14, Property count = 47
# To Place Distance Grand List, Normal Branch, length = 446945
# Executing SA2 Code 213011336
# Subset size = 2178, Places count = 22, Property count = 99
# To Place Distance Grand List, Normal Branch, length = 449123
# Executing SA2 Code 215031404
# Subset size = 700, Places count = 20, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 449823
# Executing SA2 Code 204011060
# Subset size = 28, Places count = 7, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 449851
# Executing SA2 Code 209041217
# Subset size = 192, Places count = 4, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 450043
# Executing SA2 Code 210031440
# Subset size = 95, Places count = 5, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 450138
# Executing SA2 Code 217011421
# Subset size = 256, Places count = 32, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 450394
# Executing SA2 Code 212031561
# Subset size = 123, Places count = 3, Property count = 41
# To Place Distance Grand List, Normal Branch, length = 450517
# Executing SA2 Code 212031562
# Subset size = 250, Places count = 5, Property count = 50
# To Place Distance Grand List, Normal Branch, length = 450767
# Executing SA2 Code 212021299
# Subset size = 28, Places count = 14, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 450795
# Executing SA2 Code 216011408
# Subset size = 63, Places count = 21, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 450858
# Executing SA2 Code 205041493
# Subset size = 450, Places count = 15, Property count = 30
# To Place Distance Grand List, Normal Branch, length = 451308
# Executing SA2 Code 205041494
# Subset size = 540, Places count = 15, Property count = 36
# To Place Distance Grand List, Normal Branch, length = 451848
# Executing SA2 Code 206031115
# Subset size = 820, Places count = 10, Property count = 82
# To Place Distance Grand List, Normal Branch, length = 452668
# Executing SA2 Code 213051588
# Subset size = 52, Places count = 2, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 452720
# Executing SA2 Code 213051586
# Subset size = 9, Places count = 1, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 452729
# Executing SA2 Code 210051250
# Subset size = 144, Places count = 3, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 452873
# Executing SA2 Code 216021412
# Subset size = 300, Places count = 20, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 453173
# Executing SA2 Code 205041098
# Subset size = 784, Places count = 16, Property count = 49
# To Place Distance Grand List, Normal Branch, length = 453957
# Executing SA2 Code 207021156
# Subset size = 234, Places count = 9, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 454191
# Executing SA2 Code 209011196
# Subset size = 370, Places count = 10, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 454561
# Executing SA2 Code 209041216
# Subset size = 122, Places count = 2, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 454683
# Executing SA2 Code 203021044
# Subset size = 144, Places count = 18, Property count = 8
# To Place Distance Grand List, Normal Branch, length = 454827
# Executing SA2 Code 212041318
# Subset size = 14, Places count = 14, Property count = 1
# To Place Distance Grand List, Normal Branch, length = 454841
# Executing SA2 Code 213021345
# Subset size = 72, Places count = 3, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 454913
# Executing SA2 Code 214011375
# Subset size = 1680, Places count = 28, Property count = 60
# To Place Distance Grand List, Normal Branch, length = 456593
# Executing SA2 Code 214011372
# Subset size = 3471, Places count = 39, Property count = 89
# To Place Distance Grand List, Slice Branch, length = 458309
# To Place Distance Grand List, Slice Branch, length = 460064
# Executing SA2 Code 213031350
# Subset size = 183, Places count = 3, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 460247
# Executing SA2 Code 213031352
# Subset size = 3014, Places count = 22, Property count = 137
# To Place Distance Grand List, Normal Branch, length = 463261
# Executing SA2 Code 216031416
# Subset size = 2352, Places count = 28, Property count = 84
# To Place Distance Grand List, Normal Branch, length = 465613
# Executing SA2 Code 213011332
# Subset size = 1254, Places count = 19, Property count = 66
# To Place Distance Grand List, Normal Branch, length = 466867
# Executing SA2 Code 210011534
# Subset size = 363, Places count = 11, Property count = 33
# To Place Distance Grand List, Normal Branch, length = 467230
# Executing SA2 Code 214011376
# Subset size = 64, Places count = 1, Property count = 64
# To Place Distance Grand List, Normal Branch, length = 467294
# Executing SA2 Code 201011007
# Subset size = 24, Places count = 6, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 467318
# Executing SA2 Code 206041509
# Subset size = 20, Places count = 5, Property count = 4
# To Place Distance Grand List, Normal Branch, length = 467338
# Executing SA2 Code 206051511
# Subset size = 126, Places count = 7, Property count = 18
# To Place Distance Grand List, Normal Branch, length = 467464
# Executing SA2 Code 209041436
# Subset size = 9, Places count = 3, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 467473
# Executing SA2 Code 209041435
# Subset size = 21, Places count = 3, Property count = 7
# To Place Distance Grand List, Normal Branch, length = 467494
# Executing SA2 Code 206051130
# Subset size = 783, Places count = 9, Property count = 87
# To Place Distance Grand List, Normal Branch, length = 468277
# Executing SA2 Code 217011422
# Subset size = 1020, Places count = 20, Property count = 51
# To Place Distance Grand List, Normal Branch, length = 469297
# Executing SA2 Code 209021429
# Subset size = 488, Places count = 8, Property count = 61
# To Place Distance Grand List, Normal Branch, length = 469785
# Executing SA2 Code 209021428
# Subset size = 2000, Places count = 20, Property count = 100
# To Place Distance Grand List, Normal Branch, length = 471785
# Executing SA2 Code 215031403
# Subset size = 15, Places count = 5, Property count = 3
# To Place Distance Grand List, Normal Branch, length = 471800
# Executing SA2 Code 211011256
# Subset size = 612, Places count = 9, Property count = 68
# To Place Distance Grand List, Normal Branch, length = 472412
# Executing SA2 Code 211011258
# Subset size = 222, Places count = 6, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 472634
# Executing SA2 Code 211011257
# Subset size = 51, Places count = 3, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 472685
# Executing SA2 Code 210051544
# Subset size = 217, Places count = 7, Property count = 31
# To Place Distance Grand List, Normal Branch, length = 472902
# Executing SA2 Code 210051545
# Subset size = 24, Places count = 2, Property count = 12
# To Place Distance Grand List, Normal Branch, length = 472926
# Executing SA2 Code 214021377
# Subset size = 440, Places count = 20, Property count = 22
# To Place Distance Grand List, Normal Branch, length = 473366
# Executing SA2 Code 216011407
# Subset size = 740, Places count = 20, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 474106
# Executing SA2 Code 209041530
# Subset size = 294, Places count = 7, Property count = 42
# To Place Distance Grand List, Normal Branch, length = 474400
# Executing SA2 Code 209041529
# Subset size = 156, Places count = 6, Property count = 26
# To Place Distance Grand List, Normal Branch, length = 474556
# Executing SA2 Code 206041121
# Subset size = 1498, Places count = 14, Property count = 107
# To Place Distance Grand List, Normal Branch, length = 476054
# Executing SA2 Code 215031402
# Subset size = 144, Places count = 6, Property count = 24
# To Place Distance Grand List, Normal Branch, length = 476198
# Executing SA2 Code 207011154
# Subset size = 63, Places count = 7, Property count = 9
# To Place Distance Grand List, Normal Branch, length = 476261
# Executing SA2 Code 207011522
# Subset size = 624, Places count = 13, Property count = 48
# To Place Distance Grand List, Normal Branch, length = 476885
# Executing SA2 Code 212041565
# Subset size = 357, Places count = 17, Property count = 21
# To Place Distance Grand List, Normal Branch, length = 477242
# Executing SA2 Code 212041566
# Subset size = 132, Places count = 12, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 477374
# Executing SA2 Code 216031593
# Subset size = 75, Places count = 5, Property count = 15
# To Place Distance Grand List, Normal Branch, length = 477449
# Executing SA2 Code 211051277
# Subset size = 228, Places count = 12, Property count = 19
# To Place Distance Grand List, Normal Branch, length = 477677
# Executing SA2 Code 211031450
# Subset size = 966, Places count = 21, Property count = 46
# To Place Distance Grand List, Normal Branch, length = 478643
# Executing SA2 Code 211041269
# Subset size = 135, Places count = 5, Property count = 27
# To Place Distance Grand List, Normal Branch, length = 478778
# Executing SA2 Code 214011373
# Subset size = 629, Places count = 17, Property count = 37
# To Place Distance Grand List, Normal Branch, length = 479407
# Executing SA2 Code 214011371
# Subset size = 2862, Places count = 27, Property count = 106
# To Place Distance Grand List, Normal Branch, length = 482269
# Executing SA2 Code 213051584
# Subset size = 4, Places count = 2, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 482273
# Executing SA2 Code 213051585
# Subset size = 6, Places count = 3, Property count = 2
# To Place Distance Grand List, Normal Branch, length = 482279
# Executing SA2 Code 207021159
# Subset size = 350, Places count = 10, Property count = 35
# To Place Distance Grand List, Normal Branch, length = 482629
# Executing SA2 Code 211011449
# Subset size = 160, Places count = 5, Property count = 32
# To Place Distance Grand List, Normal Branch, length = 482789
# Executing SA2 Code 209041223
# Subset size = 869, Places count = 11, Property count = 79
# To Place Distance Grand List, Normal Branch, length = 483658
# Executing SA2 Code 211031452
# Subset size = 52, Places count = 4, Property count = 13
# To Place Distance Grand List, Normal Branch, length = 483710
# Executing SA2 Code 211031451
# Subset size = 425, Places count = 25, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 484135
# Executing SA2 Code 210031535
# Subset size = 1258, Places count = 17, Property count = 74
# To Place Distance Grand List, Normal Branch, length = 485393
# Executing SA2 Code 207011146
# Subset size = 645, Places count = 15, Property count = 43
# To Place Distance Grand List, Normal Branch, length = 486038
# Executing SA2 Code 216021414
# Subset size = 121, Places count = 11, Property count = 11
# To Place Distance Grand List, Normal Branch, length = 486159
# Year 2021 completed, distance added dataset has shape (486159, 25)
