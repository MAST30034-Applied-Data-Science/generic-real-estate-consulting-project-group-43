# %% [markdown]
# ### Use ``Open Route Service API`` to retrieve distance matrix (Single Call version)
# #### Quota 500 per day, approx 1 year of merged rental-place dataset per day.
# #### Specify the ``year`` of rental and place dataset before running
# #### The following processes 2022 separately since no place data is available for 2022, by assumption we use the most recent 2021 instead

# %%
import pandas as pd
import sys
import os
# caution: path[0] is reserved for script path (or '' in REPL)
sys.path.insert(1, '../../scripts/')
import openrouteservice as ors
from dotenv import load_dotenv
load_dotenv()
from add_distance import add_distance_time

# %%
PLACE_COLS = ['Place_Names', 'latitude', 'longitude', 'year', 'place_type', 'SA2_CODE']
place_df = pd.read_csv('../../data/curated/features_of_interst/result_place_all_with_sa2.csv')[PLACE_COLS]
print(place_df.shape)
# Out:
# (75786, 6)

# %% [markdown]
# ### Alter the place and property dataframes for specific year (2013, 2014, ... 2022)

# %%
place_df = place_df[place_df['year'] == 2021]
place_df = place_df.drop_duplicates(subset=['Place_Names', 'latitude']).reset_index(drop=True)
print(place_df.shape)
place_df.head(10)
# Out:
# (9283, 6)
#               Place_Names  latitude  longitude  year place_type   SA2_CODE
# 0   WEST MELBOURNE MARKET -37.81040  144.92237  2021     market  206041127
# 1         LILYDALE MARKET -37.76040  145.34931  2021     market  211051278
# 2          PRESTON MARKET -37.73790  145.00264  2021     market  209021428
# 3          PRAHRAN MARKET -37.84615  144.99235  2021     market  206061516
# 4         VICTORIA MARKET -37.80651  144.95653  2021     market  206041504
# 5  SOUTH MELBOURNE MARKET -37.83263  144.95681  2021     market  206051512
# 6          CROYDON MARKET -37.79374  145.27820  2021     market  211031451
# 7      SWAN HILL HOSPITAL -35.34040  143.55626  2021   hospital  215031404
# 8         CLUNES HOSPITAL -37.30179  143.78265  2021   hospital  201021010
# 9         MALDON HOSPITAL -36.99270  144.06400  2021   hospital  202021028

# %%
PROPERTY_COLS = ['address', 'latitude', 'longitude', 'nbed', 'nbath', 'ncar', 'weekly_rent', 'postcode', 'year', 'month', 'residence_type', 'SA2_CODE']
property_df = pd.read_csv('../../data/curated/property_all_with_SA2_classified/2022_property_with_SA2_classified.csv')[PROPERTY_COLS]
# 2022 example
print(property_df.shape)
property_df.head(10)
# Out:
# (73107, 12)
#                             address   latitude   longitude  nbed  nbath  ncar  \
# 0        27 BARKLY STREET, CHILTERN -36.154880  146.605010   3.0    1.0     2
# 1          17 PARK STREET, CHILTERN -36.148025  146.608721   3.0    2.0     0
# 2       3/1 OXFORD STREET, CHILTERN -36.150694  146.606488   2.0    1.0     1
# 3    2/20 NICKLESS STREET, CHILTERN -36.154038  146.602977   2.0    1.0     2
# 4        1/3 BURKE STREET, CHILTERN -36.153004  146.607465   2.0    1.0     0
# 5        590 KENNEDYS LANE, CHINTIN -37.414852  144.825852   4.0    2.0     7
# 6   4 SHERWOOD ROAD, CHIRNSIDE PARK -37.747341  145.332546   4.0    2.0     2
# 7   4 SHERWOOD ROAD, CHIRNSIDE PARK -37.747341  145.332546   4.0    2.0     2
# 8  4 GLENDALE DRIVE, CHIRNSIDE PARK -37.751383  145.312411   4.0    2.0     2
# 9  4 GLENDALE DRIVE, CHIRNSIDE PARK -37.751383  145.312411   4.0    2.0     2
#
#    weekly_rent  postcode  year  month residence_type   SA2_CODE
# 0          400      3683  2022      9          House  204031070
# 1          350      3683  2022      8          House  204031070
# 2          300      3683  2022      4      Apartment  204031070
# 3          350      3683  2022      4      Apartment  204031070
# 4          240      3683  2022      2      Apartment  204031070
# 5          850      3756  2022      8          House  210021235
# 6          680      3116  2022      8          House  211051275
# 7          680      3116  2022      9          House  211051275
# 8          480      3116  2022      8          House  211051275
# 9          480      3116  2022      9          House  211051275

# %%
merged_df = property_df.merge(place_df, how='inner', on='SA2_CODE')
print(f"shape = {merged_df.shape}")
print(f"Distinct sa2 codes = {merged_df['SA2_CODE'].nunique()}")
merged_df = merged_df.rename(columns={'latitude_x': 'latitude_ori', 'longitude_x': 'longitude_ori', 'latitude_y': 'latitude_des', 'longitude_y': 'longitude_des', 'year_x': 'year'})
merged_df.drop('year_y', axis=1, inplace=True)
merged_df.head(15)
# Out:
# shape = (1351949, 17)
# Distinct sa2 codes = 502
#                        address  latitude_ori  longitude_ori  nbed  nbath  \
# 0   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 1   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 2   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 3   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 4   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 5   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 6   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 7   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 8   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 9   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 10    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 11    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 12    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 13    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 14    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
#
#     ncar  weekly_rent  postcode  year  month residence_type   SA2_CODE  \
# 0      2          400      3683  2022      9          House  204031070
# 1      2          400      3683  2022      9          House  204031070
# 2      2          400      3683  2022      9          House  204031070
# 3      2          400      3683  2022      9          House  204031070
# 4      2          400      3683  2022      9          House  204031070
# 5      2          400      3683  2022      9          House  204031070
# 6      2          400      3683  2022      9          House  204031070
# 7      2          400      3683  2022      9          House  204031070
# 8      2          400      3683  2022      9          House  204031070
# 9      2          400      3683  2022      9          House  204031070
# 10     0          350      3683  2022      8          House  204031070
# 11     0          350      3683  2022      8          House  204031070
# 12     0          350      3683  2022      8          House  204031070
# 13     0          350      3683  2022      8          House  204031070
# 14     0          350      3683  2022      8          House  204031070
#
#                            Place_Names  latitude_des  longitude_des place_type
# 0              CHILTERN POLICE STATION     -36.14815      146.61057     police
# 1              CHILTERN PRIMARY SCHOOL     -36.14707      146.60660    primary
# 2         MIDDLE INDIGO PRIMARY SCHOOL     -36.15601      146.72484    primary
# 3           BARNAWARTHA PRIMARY SCHOOL     -36.10131      146.67589    primary
# 4                    ST JOSEPHS SCHOOL     -36.14598      146.60707    primary
# 5                             CHILTERN     -36.15566      146.61138    station
# 6                          BARNAWARTHA     -36.10280      146.67959    station
# 7             CHILTERN RAILWAY STATION     -36.15540      146.61181    station
# 8   CHILTERN VALLEY RECREATION RESERVE     -36.14293      146.54548       park
# 9                        CHILTERN PARK     -36.12429      146.55681       park
# 10             CHILTERN POLICE STATION     -36.14815      146.61057     police
# 11             CHILTERN PRIMARY SCHOOL     -36.14707      146.60660    primary
# 12        MIDDLE INDIGO PRIMARY SCHOOL     -36.15601      146.72484    primary
# 13          BARNAWARTHA PRIMARY SCHOOL     -36.10131      146.67589    primary
# 14                   ST JOSEPHS SCHOOL     -36.14598      146.60707    primary

# %% [markdown]
# ### Create the directory to store merged distance data

# %%
if not os.path.exists('../../data/featured'):
    os.makedirs('../../data/featured')

# %% [markdown]
# #### Specify the ``client`` and ``year`` here, as well as adding a mode of testing/saving

# %%
ors_key = os.getenv('CLIENT_ORS9') # Phikho-caz's api key 2500, back up for at least 4 full year
client = ors.Client(ors_key) 
ors_key
# Out:
# '5b3ce3597851110001cf6248ce6c95ac96814219a4c3a7741f323b73'

# %%
added_distance_merged_df = add_distance_time(merged_df, 2022, client, 'saving') # specify the year here, client id, and mode of running (testing or saving)
#added_distance_merged_df = add_distance_time(subset, 2013)
# Out:
# Executing SA2 Code 204031070
# Subset size = 170, Places count = 10, Property count = 17
# To Place Distance Grand List, Normal Branch, length = 170
# Executing SA2 Code 210021235
# Subset size = 1079, Places count = 13, Property count = 83
# To Place Distance Grand List, Normal Branch, length = 1249
# Executing SA2 Code 211051275
# Subset size = 186, Places count = 3, Property count = 62
# To Place Distance Grand List, Normal Branch, length = 1435
# Executing SA2 Code 211051278
# Subset size = 3640, Places count = 20, Property count = 182
# To Place Distance Grand List, Slice Branch, length = 3255
# To Place Distance Grand List, Slice Branch, length = 5075
# Executing SA2 Code 211051276
# Subset size = 2325, Places count = 25, Property count = 93

# %%
added_distance_merged_df.head(20)
# Out:
#                        address  latitude_ori  longitude_ori  nbed  nbath  \
# 0   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 1   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 2   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 3   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 4   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 5   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 6   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 7   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 8   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 9   27 BARKLY STREET, CHILTERN    -36.154880     146.605010   3.0    1.0
# 10    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 11    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 12    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 13    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 14    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 15    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 16    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
# 17    17 PARK STREET, CHILTERN    -36.148025     146.608721   3.0    2.0
